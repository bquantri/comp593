# %% [markdown]
# <a href="https://colab.research.google.com/github/bquantri/comp593/blob/main/COMP593-Lab3-BenQuantrill.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # LAB 3: WORKING WITH DATABASES

# %% [markdown]
# ## Introduction
#
# During this lab, we will experiment with using a few different libararies and modules to connect to and interact with an SQLite database. After creating and configuring our testing database, we will populate it with Fake data and run some queries to see what kind of information we can retreive. For context, we will be creating RSSN, the "Really Simple Social Network".

# %% [markdown]
# ## Creating a SQLite Database
#
# We will be utilizing the `sqlite3` library to create our database file, as it offers the convienience of creating our database file automatically in the event that it cannot find an existing file at the path specified.
#
# **Before you run the below code:**
# On the left of the notebook, select the file folder icon. Then, after you run the code block, you should be able to observe the creation of the database file. If it doesn't appear, try clicking the "Refresh" button above the list of folders.

# %%
import sqlite3

#When we retreive a Connection object, a new database will be created for us if it doesn't already exist. 
myConnection = sqlite3.connect('social_network.db')
print(sqlite3.version)
# Out:
# 2.6.0

# %% [markdown]
# ## Creating a Table

# %% [markdown]
# We'll use the below code to create a table called `people` within our database.

# %%
import sqlite3

#Retreive the Connection object
myConnection = sqlite3.connect('social_network.db')

#Once we have a Connection object, we can generate a Cursor object, and use that to run our SQL Queries
myCursor = myConnection.cursor()

#Let's define the SQL Query we will use to create our first table:
createPeopleTable = """ CREATE TABLE IF NOT EXISTS people (
                          id integer PRIMARY KEY,
                          name text NOT NULL,
                          email text NOT NULL,
                          address text NOT NULL,
                          city text NOT NULL,
                          province text NOT NULL,
                          country text NOT NULL,
                          phone text,
                          bio text,
                          dob date NOT NULL,
                          heatmap integer,
                          created_at datetime NOT NULL,
                          updated_at datetime NOT NULL,
                          ipv4 text
                        );"""

#Now that we have the string to create our table,
#Cursor objects have an execute() method which will accept an SQL string and perform the operations described.

myCursor.execute(createPeopleTable)

#We can confirm if our table was created successfully by running the following SQL Query
#pragma_table_info is an internal SQLite function that will retun information about a table
myCursor.execute("SELECT group_concat(name, ', ') FROM pragma_table_info('people')")
print(myCursor.fetchone())

#We use to the commit() method on the database Connection object to persist our changes
myConnection.commit()

#It is always a good idea to close a connection when it will no longer be used
myConnection.close()
# Out:
# ('id, name, email, address, city, province, country, phone, bio, dob, heatmap, created_at, updated_at, ipv4',)

# %% [markdown]
# If you received a tuple containing the names of the columns, awesome! We have successfully created our database table.
# ```
# ('id, name, email, address, city, province, country, phone, bio, created_at, updated_at',)
# ```
#
# Run the below code block to add our first entry.

# %%
import sqlite3
from pprint import pprint #Outputs data in a slightly easier to read format
from datetime import datetime #For generating dates and times

#Retreive the Connection object
myConnection = sqlite3.connect('social_network.db')

#Once we have a Connection object, we can generate a Cursor object, and use that to run our SQL Queries
myCursor = myConnection.cursor()

#Let's define the SQL Query we will use to create our first entry:
addPersonQuery = """INSERT INTO people (name, 
                      email, 
                      address, 
                      city, 
                      province, 
                      country, 
                      phone, 
                      bio,
                      dob,
                      heatmap,
                      created_at, 
                      updated_at, 
                      ipv4)
                  VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?);"""

"""
The ?'s are placeholders that we can fill in when we use the execute() method.
This is really handy for code reuse, as we can pass those values are variables in a tuple
Instead of hard coding them into the statement.
"""

myPerson = ("John Doe", 
            "johndoe@anon.null", 
            "123 Fake St.", 
            "Fakesville", 
            "Fakesdom", 
            "Fakopolis", 
            None, 
            None,
            "1967-09-12",
            0,
            datetime.now(), 
            datetime.now(),
            None)

myCursor.execute(addPersonQuery, myPerson)

#We can confirm if our table was created successfully by running the following SQL Query
#pragma_table_info is an internal SQLite function that will retun information about a table
myCursor.execute("SELECT * FROM people")
pprint(myCursor.fetchall())

# If you run this code block a few times, you will see that you only have 1 entry,
# If you uncomment the below lines and run the block a few more times, you will begin to see multiple entries.
myConnection.commit()
myConnection.close()
# Out:
# [(1,
#   'John Doe',
#   'johndoe@anon.null',
#   '123 Fake St.',
#   'Fakesville',
#   'Fakesdom',
#   'Fakopolis',
#   None,
#   None,
#   '1967-09-12',
#   0,
#   '2022-02-24 04:59:21.502027',
#   '2022-02-24 04:59:21.502041',
#   None)]

# %% [markdown]
# # Lab Submission

# %% [markdown]
# We're going to build our experience with working with Libraries and examining documentation by populating our 'People' table with data provided to us by the `Faker` library. `Faker` is used to generate fake data and is very helpful for the rapid generation of databases for the purposes of testing. Run the two blocks below to install faker and get an idea of what it can do.

# %%
# !pip install faker
# Out:
# Collecting faker
#   Downloading Faker-13.2.0-py3-none-any.whl (1.5 MB)
#      |████████████████████████████████| 1.5 MB 4.9 MB/s
# Requirement already satisfied: python-dateutil>=2.4 in /usr/local/lib/python3.7/dist-packages (from faker) (2.8.2)
# Requirement already satisfied: typing-extensions>=3.10.0.2 in /usr/local/lib/python3.7/dist-packages (from faker) (3.10.0.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.4->faker) (1.15.0)
# Installing collected packages: faker
# Successfully installed faker-13.2.0

# %%
from faker import Faker

fake = Faker()

for _ in range(10):
  print('{} || {}'.format( fake.name(), fake.state() ) )
# Out:
# Nicholas Davis || Utah
# Aaron Carpenter || Alabama
# Kevin Martin || Oregon
# Matthew Pearson || Maryland
# Barry Kelley || Minnesota
# Andrea Montoya || Wyoming
# Shelby Jones || Colorado
# Christopher Carroll || Montana
# Kenneth Hinton || South Carolina
# Daniel Brown || Tennessee

# %% [markdown]
# Very cool! Faker has tons of `providers` that can all be used to populate fake data. The [list of providers](https://faker.readthedocs.io/en/stable/providers.html) in the Faker documentation will help you fill out the columns for our People table.
#
# The goal of this script is to populate the people table with 1000 entries, with the following constraints:
#
# 1. The `heatmap` column must contain a random number between `999` and `2500`
# 2. The `created_at` and `updated_at` columns must use the `datetime` object (see examples above)
# 2. Use `Faker` to generate all other fields.
#
# *Hint: Each of the methods contained in the provider can be called directly from the base Faker object, for example, one can call the `file_name()` method from `faker.providers.file` by calling `Faker().file_name()`*

# %%
import sqlite3
from faker import Faker
from datetime import datetime #For generating dates and times
#Don't forget to import the module to generate random numbers!
from random import randint

#Retreive the Connection object
myConnection = sqlite3.connect('social_network.db')

#Once we have a Connection object, we can generate a Cursor object, and use that to run our SQL Queries
myCursor = myConnection.cursor()

#This is the same syntax as the above example:
addPersonQuery = """INSERT INTO people (name, 
                      email, 
                      address, 
                      city, 
                      province, 
                      country, 
                      phone, 
                      bio,
                      dob,
                      heatmap,
                      created_at, 
                      updated_at, 
                      ipv4)
                  VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?);"""

fake = Faker("en_CA")


for i in range(1000):
  myPerson = (fake.name(), 
            fake.email(), 
            fake.address(), 
            fake.city(), 
            fake.administrative_unit(), 
            fake.country(), 
            fake.phone_number(), 
            fake.paragraph(nb_sentences=3),
            fake.date(),
            fake.random_int(min=999, max=2500),
            datetime.now(), 
            datetime.now(),
            fake.ipv4())
  myCursor.execute(addPersonQuery, myPerson)
i += 1









#Ideally, you will want to create a loop that will iterate 1000 times,
#Observe the example in the earlier code block showing the parameter tuple `myPerson`
#You can duplicate that inside your loop and replace those fields with calls to the appropriate faker provider method
#Execute your statement inside the loop,
#But, don't forget to commit and close your connection when you have finished!
myCursor.execute("SELECT * FROM people")
pprint(myCursor.fetchall())

myConnection.commit()


myConnection.close()
# Out:
# Streaming output truncated to the last 5000 lines.
#   '1998-04-11',
#   1126,
#   '2022-02-24 05:00:20.380923',
#   '2022-02-24 05:00:20.380924',
#   '19.136.132.166'),
#  (668,
#   'Alexander Sanders',
#   'stuartmary@example.org',
#   '302 Vargas Stream\nWest Juliabury, NU Y6M6T8',
#   'Smithport',
#   'Newfoundland and Labrador',
#   'Algeria',
#   '667-664-3393',
#   'Animi soluta animi numquam accusantium provident ea. Fugit velit aspernatur '
#   'explicabo impedit nam.',
#   '1997-05-12',
#   1181,
#   '2022-02-24 05:00:20.382199',
#   '2022-02-24 05:00:20.382201',
#   '152.16.25.91'),
#  (669,
#   'Debra Russell',
#   'ucervantes@example.org',
#   '7047 Crystal Path Apt. 220\nTonyastad, PE G7R2E4',
#   'North Michael',
#   'Quebec',
#   'Antarctica (the territory South of 60 deg S)',
#   '(490) 150-2011 x773',
#   'Ut nam harum ratione ad. Rerum placeat eligendi quae et ducimus '
#   'voluptatibus. Necessitatibus totam voluptate odio cumque sapiente.',
#   '1981-02-18',
#   1172,
#   '2022-02-24 05:00:20.383109',
#   '2022-02-24 05:00:20.383110',
#   '12.15.234.2'),
#  (670,
#   'Diana Patterson',
#   'williamsryan@example.org',
#   '652 Bobby Springs\nByrdbury, PE Y1V3H8',
#   'Angelicaside',
#   'Nunavut',
#   'Bahrain',
#   '(469) 793-0302 x724',
#   'Officia occaecati doloribus velit ipsum cumque reprehenderit odio. Iste '
#   'nemo dolorum voluptas quo cumque suscipit. Dolorum veniam suscipit.',
#   '2004-03-22',
#   1123,
#   '2022-02-24 05:00:20.384156',
#   '2022-02-24 05:00:20.384158',
#   '58.116.34.245'),
#  (671,
#   'Jeffrey Sexton',
#   'martinaustin@example.net',
#   '946 Damon Mountain\nNew Amberberg, NU L9C 2A5',
#   'North Amber',
#   'British Columbia',
#   'Mali',
#   '265 512 9899',
#   'Dolore velit aliquid. Ab consequatur at nemo tempore optio. Laboriosam '
#   'distinctio quis magni nemo laborum.',
#   '1978-02-21',
#   1015,
#   '2022-02-24 05:00:20.385075',
#   '2022-02-24 05:00:20.385077',
#   '104.185.121.131'),
#  (672,
#   'Diane Carey',
#   'gabrielalvarez@example.com',
#   '719 Christopher Circles\nRobinsonburgh, BC A9L 3N7',
#   'Port Shanemouth',
#   'Ontario',
#   'Nepal',
#   '+1 (544) 696-1195',
#   'Corporis aliquid impedit harum officiis enim quis corporis. Excepturi '
#   'expedita corporis sed.',
#   '2007-12-21',
#   1526,
#   '2022-02-24 05:00:20.385990',
#   '2022-02-24 05:00:20.385991',
#   '87.26.204.105'),
#  (673,
#   'Michael Haley',
#   'jonathan32@example.net',
#   '606 James Canyon Suite 117\nSouth William, SK C5N5Y9',
#   'Hallborough',
#   'Saskatchewan',
#   'Netherlands Antilles',
#   '524-700-7821',
#   'Minus sunt temporibus placeat impedit. Officiis neque ex mollitia. Saepe '
#   'eaque excepturi nam iure.',
#   '1991-10-13',
#   1043,
#   '2022-02-24 05:00:20.386858',
#   '2022-02-24 05:00:20.386860',
#   '76.104.39.153'),
#  (674,
#   'Meredith Jennings',
#   'bgarrett@example.net',
#   '458 Kirsten Walks Apt. 165\nDiazton, PE R8K 8S2',
#   'North Angie',
#   'British Columbia',
#   'Russian Federation',
#   '+1 (663) 452-7078',
#   'Cupiditate a non aperiam alias labore voluptas.',
#   '1997-03-07',
#   2480,
#   '2022-02-24 05:00:20.387712',
#   '2022-02-24 05:00:20.387713',
#   '202.83.128.154'),
#  (675,
#   'Victoria Moore',
#   'melissathompson@example.com',
#   '382 Shelton Port\nEast Lorraine, PE V2T9T1',
#   'Lake Alyssaland',
#   'Newfoundland and Labrador',
#   'Uganda',
#   '(904) 073-1306 x736',
#   'Eos autem eius veniam eveniet sunt. Neque ut laboriosam dolorum nam aliquam '
#   'quae.',
#   '1988-03-02',
#   2485,
#   '2022-02-24 05:00:20.388621',
#   '2022-02-24 05:00:20.388622',
#   '164.139.52.151'),
#  (676,
#   'Ryan Cross',
#   'ethan25@example.org',
#   '4162 Hensley Circle Apt. 841\nEdwardhaven, SK C5J 4X3',
#   'Patrickville',
#   'British Columbia',
#   'Estonia',
#   '1-901-547-5767',
#   'Tenetur voluptates eius illo doloremque quaerat. Suscipit sed suscipit '
#   'omnis dicta. Quo perspiciatis architecto similique.',
#   '1999-12-31',
#   2290,
#   '2022-02-24 05:00:20.389463',
#   '2022-02-24 05:00:20.389464',
#   '186.218.47.5'),
#  (677,
#   'Nathan Miller',
#   'jean32@example.net',
#   '702 Short Stravenue Apt. 983\nAliborough, YT L9B7S5',
#   'South James',
#   'Northwest Territories',
#   'Botswana',
#   '(251) 806-5294 x251',
#   'Rem saepe voluptates voluptatum. Iste error deserunt repellat. Iste laborum '
#   'praesentium quas. Repellat commodi pariatur qui laborum.',
#   '2018-09-05',
#   1028,
#   '2022-02-24 05:00:20.390333',
#   '2022-02-24 05:00:20.390334',
#   '68.237.111.218'),
#  (678,
#   'Cody Woodward',
#   'amycox@example.org',
#   '067 Danielle Locks Suite 322\nNew Brentchester, NL B3S6A8',
#   'Michaelbury',
#   'Alberta',
#   'Pitcairn Islands',
#   '188-305-2825',
#   'Illo ullam debitis facilis vel doloribus doloribus exercitationem. Nam '
#   'nobis harum. Incidunt minima dolorem placeat veniam accusantium dolor.',
#   '1987-02-08',
#   1953,
#   '2022-02-24 05:00:20.391199',
#   '2022-02-24 05:00:20.391200',
#   '136.19.29.216'),
#  (679,
#   'Dustin Johnson',
#   'larry35@example.net',
#   '64466 Darryl Alley Suite 111\nRichardside, NB X5T 9N9',
#   'Sonyaview',
#   'Nunavut',
#   'Poland',
#   '(774) 266-7864 x052',
#   'Maiores voluptatem perspiciatis. Officia eius dignissimos numquam aut '
#   'repellendus.',
#   '1980-08-08',
#   1557,
#   '2022-02-24 05:00:20.392013',
#   '2022-02-24 05:00:20.392014',
#   '114.180.208.193'),
#  (680,
#   'Lisa Richards',
#   'kelly10@example.net',
#   '24010 Osborne Curve\nWest Thomas, NU X2B8J9',
#   'Michelefurt',
#   'Ontario',
#   'Kuwait',
#   '1 (756) 089-0748',
#   'Architecto cum odio. Facere quaerat nobis explicabo ipsa.',
#   '1987-05-18',
#   1208,
#   '2022-02-24 05:00:20.392830',
#   '2022-02-24 05:00:20.392831',
#   '40.228.26.92'),
#  (681,
#   'Mark Perez',
#   'morgankaren@example.org',
#   '6113 Owens Cliff\nKatherinechester, NS X8J 9H9',
#   'East Vincentmouth',
#   'Alberta',
#   'Singapore',
#   '348-652-9460',
#   'Libero consequatur voluptates illo minus impedit. Accusamus cupiditate quo '
#   'eaque. Quisquam facilis ut maiores iste repudiandae.',
#   '1989-06-04',
#   1139,
#   '2022-02-24 05:00:20.393729',
#   '2022-02-24 05:00:20.393730',
#   '119.209.202.25'),
#  (682,
#   'Mary Williams',
#   'zthomas@example.com',
#   '5574 Scott Road Apt. 605\nNew Alicia, PE R8M1T9',
#   'Lake Amy',
#   'Manitoba',
#   'Libyan Arab Jamahiriya',
#   '(296) 194-9505 x674',
#   'Modi fugit sint voluptatibus quaerat. Esse debitis facere atque.',
#   '1987-01-01',
#   1702,
#   '2022-02-24 05:00:20.394826',
#   '2022-02-24 05:00:20.394827',
#   '45.157.143.128'),
#  (683,
#   'Lisa Stephens',
#   'curtis18@example.com',
#   '2420 Paul Shoals Suite 833\nBenjaminfort, QC R7H8N6',
#   'Oliverstad',
#   'Yukon Territory',
#   'Denmark',
#   '892-420-0570',
#   'Consectetur consequatur deleniti numquam. Consequatur laudantium '
#   'consequuntur facilis eos consectetur. Tempore delectus cum veniam.',
#   '2002-02-14',
#   1768,
#   '2022-02-24 05:00:20.395722',
#   '2022-02-24 05:00:20.395723',
#   '130.14.131.94'),
#  (684,
#   'Monica Smith',
#   'larasteven@example.com',
#   '295 Jessica Mount\nTonyaberg, NT M3M 5J3',
#   'Christinemouth',
#   'Prince Edward Island',
#   'Jordan',
#   '490-693-1659',
#   'Libero dignissimos dolore. Id dolor exercitationem. Autem ea tempore '
#   'tenetur pariatur error quisquam reiciendis.',
#   '2003-10-17',
#   2267,
#   '2022-02-24 05:00:20.396629',
#   '2022-02-24 05:00:20.396630',
#   '41.63.95.35'),
#  (685,
#   'Debra Moore',
#   'matthew64@example.org',
#   '620 Johnson Mountain\nEricton, NL M4E 5K2',
#   'Patrickchester',
#   'Alberta',
#   "Cote d'Ivoire",
#   '1-709-530-3339',
#   'Iusto sapiente dignissimos veniam laudantium. Blanditiis adipisci soluta '
#   'hic aliquid odio. Similique nam cumque.',
#   '1973-04-03',
#   1023,
#   '2022-02-24 05:00:20.397484',
#   '2022-02-24 05:00:20.397485',
#   '157.189.140.246'),
#  (686,
#   'Erik Scott',
#   'michelledeleon@example.com',
#   '3815 Hernandez Squares Apt. 364\nLaurenfurt, PE R8L 7E5',
#   'Nathanburgh',
#   'Prince Edward Island',
#   'Pitcairn Islands',
#   '(148) 906-6891 x514',
#   'Ab optio eveniet reiciendis molestiae dolor dolorum. Voluptatibus aut quia '
#   'deserunt ratione nihil. Eaque esse cupiditate quibusdam assumenda '
#   'consequatur architecto deserunt.',
#   '1984-12-28',
#   1283,
#   '2022-02-24 05:00:20.398830',
#   '2022-02-24 05:00:20.398831',
#   '86.180.126.94'),
#  (687,
#   'Monica Morgan',
#   'xschneider@example.net',
#   '361 Bailey Ridges\nSouth Dean, NU H6T6P5',
#   'West John',
#   'Prince Edward Island',
#   'Nigeria',
#   '661-659-7716 x552',
#   'Nulla accusantium mollitia magni. Nisi voluptates odit laudantium.',
#   '1999-05-10',
#   2323,
#   '2022-02-24 05:00:20.399772',
#   '2022-02-24 05:00:20.399773',
#   '58.137.73.178'),
#  (688,
#   'Paul Lucas',
#   'samuel04@example.net',
#   '669 Monica Locks Suite 959\nPort Heather, NB X9M 4K6',
#   'Jessicabury',
#   'Alberta',
#   'Congo',
#   '862.150.7293',
#   'Voluptatum sequi ipsam eius. Doloribus numquam eveniet cumque rem optio '
#   'consectetur.',
#   '1974-07-26',
#   2453,
#   '2022-02-24 05:00:20.400609',
#   '2022-02-24 05:00:20.400610',
#   '142.237.175.244'),
#  (689,
#   'Jacob Brown',
#   'guzmanjacqueline@example.org',
#   '35227 Sanders Stravenue\nLewismouth, ON K7M5L4',
#   'Jamiechester',
#   'Manitoba',
#   'Montserrat',
#   '1-542-267-8139',
#   'Accusantium voluptas nesciunt. Exercitationem cupiditate inventore '
#   'perspiciatis atque. Itaque doloribus incidunt eum quisquam ad voluptatem.',
#   '1992-10-13',
#   2037,
#   '2022-02-24 05:00:20.401573',
#   '2022-02-24 05:00:20.401574',
#   '60.170.96.152'),
#  (690,
#   'Andrew Chaney',
#   'derek87@example.org',
#   '28871 Bray Squares\nSouth Jill, YT M4P1T7',
#   'New Sandra',
#   'Alberta',
#   'Japan',
#   '399-106-7099',
#   'Cupiditate iure in consectetur. Explicabo soluta atque quia doloremque. '
#   'Fugit mollitia atque nemo nihil blanditiis.',
#   '1995-05-06',
#   2462,
#   '2022-02-24 05:00:20.402414',
#   '2022-02-24 05:00:20.402415',
#   '113.128.201.135'),
#  (691,
#   'Martin Gilmore',
#   'allison84@example.net',
#   '9360 Amanda Brook\nEast Rebeccaview, PE S9G 8M5',
#   'West Richardmouth',
#   'Ontario',
#   'Malta',
#   '450 753 2130',
#   'Ad ipsa dolorum accusantium. Maxime labore maxime blanditiis natus sed nemo '
#   'nobis. Consequuntur neque aut perspiciatis.',
#   '1974-10-05',
#   1147,
#   '2022-02-24 05:00:20.403247',
#   '2022-02-24 05:00:20.403248',
#   '133.180.32.8'),
#  (692,
#   'Michael Valdez',
#   'fayers@example.com',
#   '30325 Janet Locks\nNew Mackenziemouth, YT M6Y3R1',
#   'Dillonmouth',
#   'Manitoba',
#   'Honduras',
#   '556.406.4353',
#   'Deleniti nobis voluptatibus excepturi. Consequuntur voluptas illum modi '
#   'molestias voluptatum eius.',
#   '1975-08-15',
#   1286,
#   '2022-02-24 05:00:20.404111',
#   '2022-02-24 05:00:20.404112',
#   '151.33.211.88'),
#  (693,
#   'Mr. Ricky Mason',
#   'ucase@example.org',
#   '868 Donna Locks Apt. 254\nRonaldside, NB H6M 8Y9',
#   'Alexanderport',
#   'Nunavut',
#   'Bahamas',
#   '+1 (108) 979-6729',
#   'Nam fuga adipisci assumenda. Sequi minus facilis eveniet expedita beatae '
#   'cupiditate velit. Cupiditate odio aperiam.',
#   '2013-03-23',
#   1550,
#   '2022-02-24 05:00:20.404945',
#   '2022-02-24 05:00:20.404947',
#   '142.155.87.123'),
#  (694,
#   'Tyler Ortega',
#   'ashleysantos@example.org',
#   '866 Swanson Roads\nNicholasmouth, ON J9X 2J3',
#   'Gibsonstad',
#   'New Brunswick',
#   'Hong Kong',
#   '1-356-722-4308',
#   'Suscipit minima maxime sunt. Ipsam odio unde ab est. Atque omnis alias esse '
#   'ducimus repellat error consequatur.',
#   '1995-04-22',
#   1853,
#   '2022-02-24 05:00:20.405851',
#   '2022-02-24 05:00:20.405852',
#   '115.21.32.119'),
#  (695,
#   'Melissa Stephens MD',
#   'lindsay22@example.org',
#   '88639 Thomas Tunnel Suite 454\nLindseyfurt, PE R6V 9S6',
#   'Meltonview',
#   'Alberta',
#   'Myanmar',
#   '728.944.8909',
#   'Cum voluptate ratione impedit.',
#   '2004-09-01',
#   1230,
#   '2022-02-24 05:00:20.406696',
#   '2022-02-24 05:00:20.406697',
#   '214.80.126.21'),
#  (696,
#   'Darryl Davis',
#   'michaelsimmons@example.org',
#   '54213 Stacy Trafficway Apt. 165\nLisastad, NS Y9G8B3',
#   'Lamville',
#   'British Columbia',
#   'Barbados',
#   '(481) 534-6699',
#   'Similique velit praesentium omnis ad doloremque incidunt. Incidunt ipsum '
#   'ullam vero natus.',
#   '1976-10-29',
#   1843,
#   '2022-02-24 05:00:20.407605',
#   '2022-02-24 05:00:20.407606',
#   '222.18.53.136'),
#  (697,
#   'Thomas King',
#   'james52@example.org',
#   '864 Wayne Mission\nWest Victoriaside, NT H2B 3J5',
#   'Bowersmouth',
#   'Northwest Territories',
#   'Slovakia (Slovak Republic)',
#   '+1 (901) 993-2569',
#   'Sequi nesciunt eum est cum aut repellendus. Dolor id sed nostrum. '
#   'Blanditiis nam tenetur ipsum fugit.',
#   '2016-06-04',
#   1554,
#   '2022-02-24 05:00:20.408421',
#   '2022-02-24 05:00:20.408422',
#   '94.149.237.216'),
#  (698,
#   'Stacy Kidd',
#   'hmurray@example.org',
#   '11405 Miller Isle Suite 316\nSouth Mark, SK E6X5V9',
#   'Jacksonside',
#   'Prince Edward Island',
#   'Mexico',
#   '1-268-122-2931',
#   'Porro expedita tenetur et cum consequuntur. Optio sequi unde distinctio '
#   'eaque harum ea.',
#   '1977-11-30',
#   1879,
#   '2022-02-24 05:00:20.409275',
#   '2022-02-24 05:00:20.409276',
#   '86.44.18.199'),
#  (699,
#   'Alicia Rowe',
#   'garrettbridges@example.net',
#   '752 Rodriguez Freeway\nSouth Alexandria, ON V8P 9J1',
#   'Cochranfurt',
#   'Northwest Territories',
#   'Luxembourg',
#   '659.488.9652',
#   'Dolorem doloremque porro quasi quae eum expedita. Asperiores porro neque '
#   'unde consectetur suscipit quia.',
#   '1983-09-11',
#   1574,
#   '2022-02-24 05:00:20.410183',
#   '2022-02-24 05:00:20.410184',
#   '51.195.134.34'),
#  (700,
#   'Lauren Zhang',
#   'nlane@example.net',
#   '7055 Kimberly Extensions Apt. 634\nGutierrezview, NL V9N7C4',
#   'West Philipton',
#   'Alberta',
#   'Slovenia',
#   '766-977-8922',
#   'At officia est dolor fugiat quod quas repellendus. Aliquid magni occaecati '
#   'iste repellat. Odit necessitatibus recusandae repellat cum nam.',
#   '1989-08-04',
#   1461,
#   '2022-02-24 05:00:20.411067',
#   '2022-02-24 05:00:20.411069',
#   '218.40.188.187'),
#  (701,
#   'Rachel Wall',
#   'renee04@example.org',
#   '861 Joseph Village\nCherylmouth, MB C8M9M6',
#   'Howellborough',
#   'Alberta',
#   'Belize',
#   '216 538 5472',
#   'Voluptatibus mollitia commodi eaque. At quaerat perspiciatis necessitatibus '
#   'labore ratione quae. Cupiditate eum iusto quo ipsa ipsa.',
#   '2015-04-25',
#   2342,
#   '2022-02-24 05:00:20.411903',
#   '2022-02-24 05:00:20.411904',
#   '41.84.40.195'),
#  (702,
#   'Sherri Harris',
#   'michelleorozco@example.com',
#   '9741 Stevens Motorway\nNew Lonnieshire, MB H7Y6N5',
#   'Port Sharon',
#   'Manitoba',
#   'Estonia',
#   '+1 (139) 180-6188',
#   'Mollitia perspiciatis expedita veniam aut aperiam praesentium. Quam beatae '
#   'at quasi libero.',
#   '1971-02-28',
#   2468,
#   '2022-02-24 05:00:20.412794',
#   '2022-02-24 05:00:20.412795',
#   '81.121.83.117'),
#  (703,
#   'Joel Young',
#   'kylehill@example.com',
#   '87834 Jonathon Glen Apt. 436\nRogerton, NT P3V 5H5',
#   'Port Katherine',
#   'Nova Scotia',
#   'Panama',
#   '475-411-7596 x483',
#   'Incidunt aliquam harum repellendus modi eveniet dolorem. Sapiente maxime '
#   'deserunt sit tempora natus.',
#   '1985-06-19',
#   2432,
#   '2022-02-24 05:00:20.413658',
#   '2022-02-24 05:00:20.413659',
#   '208.2.70.50'),
#  (704,
#   'Jody Campbell',
#   'hroman@example.com',
#   '9664 Collins Road Apt. 292\nSarahbury, QC X6X9P8',
#   'Aprilside',
#   'Alberta',
#   'Equatorial Guinea',
#   '+1 (464) 489-5483',
#   'Cum dolorem earum possimus eius iusto. Debitis possimus magnam.',
#   '1981-04-28',
#   2490,
#   '2022-02-24 05:00:20.414496',
#   '2022-02-24 05:00:20.414497',
#   '18.128.39.130'),
#  (705,
#   'Kevin Tran',
#   'timothyrojas@example.com',
#   '2512 Cook Junctions Suite 763\nFowlerbury, NB H3A 9R6',
#   'Campbellmouth',
#   'Nunavut',
#   'El Salvador',
#   '826-748-4632 x086',
#   'Magnam quo provident aliquid fugit quo. Tempore tenetur alias labore sed ad '
#   'corrupti. Aliquam nulla expedita libero excepturi eaque praesentium.',
#   '1990-06-22',
#   2096,
#   '2022-02-24 05:00:20.415436',
#   '2022-02-24 05:00:20.415437',
#   '110.44.238.63'),
#  (706,
#   'David Cox',
#   'adamlindsey@example.org',
#   '414 Adriana Rapid Apt. 902\nGreenburgh, NT B5Y 5S8',
#   'Harrischester',
#   'Saskatchewan',
#   'Czech Republic',
#   '+1 (719) 993-1009',
#   'Totam debitis sed consequuntur laudantium modi voluptas. Deleniti sed ipsum '
#   'reiciendis dolor autem vitae quibusdam.',
#   '1978-05-07',
#   1697,
#   '2022-02-24 05:00:20.416363',
#   '2022-02-24 05:00:20.416365',
#   '212.225.125.1'),
#  (707,
#   'Kayla Lynch',
#   'matthew95@example.com',
#   '76968 Miller Garden Suite 610\nScottmouth, YT T8B5A2',
#   'Lake Danielchester',
#   'Prince Edward Island',
#   'Guyana',
#   '914.232.5951',
#   'Vitae tenetur perferendis tempore accusantium ad. Distinctio nam ducimus '
#   'libero ratione ipsam. Debitis commodi voluptate vel quisquam recusandae '
#   'doloremque.',
#   '1987-03-16',
#   2428,
#   '2022-02-24 05:00:20.417237',
#   '2022-02-24 05:00:20.417238',
#   '184.17.4.177'),
#  (708,
#   'Jennifer Mahoney',
#   'rodgerssean@example.org',
#   '67341 Simmons Estates\nLake Kayla, QC G7K3A6',
#   'Allenview',
#   'Newfoundland and Labrador',
#   'United States Virgin Islands',
#   '731 633 5022',
#   'Blanditiis corporis tempore temporibus. Facere distinctio fuga eum '
#   'asperiores. Rerum harum atque dolores occaecati eum.',
#   '2003-09-25',
#   1603,
#   '2022-02-24 05:00:20.418189',
#   '2022-02-24 05:00:20.418190',
#   '13.237.75.95'),
#  (709,
#   'Timothy Velazquez',
#   'christopherdaniel@example.com',
#   '160 Hughes Green Apt. 531\nPort Cody, NU T1N 8X3',
#   'North Elizabethhaven',
#   'Newfoundland and Labrador',
#   'Lithuania',
#   '583-408-3111 x317',
#   'Vitae quia natus recusandae eaque magnam consectetur non. Modi voluptates '
#   'corporis quod cupiditate laborum adipisci. Pariatur eligendi fugiat '
#   'corporis quam soluta.',
#   '1973-06-19',
#   1049,
#   '2022-02-24 05:00:20.419099',
#   '2022-02-24 05:00:20.419100',
#   '190.8.206.88'),
#  (710,
#   'James Smith',
#   'melanieday@example.net',
#   '14295 Bowers Springs Suite 710\nJennyland, NS H1A 9N8',
#   'West Samuel',
#   'Saskatchewan',
#   'Congo',
#   '(940) 399-3228',
#   'Eum consequuntur veniam quidem odio earum. Earum harum ad possimus '
#   'voluptatem iusto. Pariatur nulla sed beatae reprehenderit provident.',
#   '2011-07-19',
#   1960,
#   '2022-02-24 05:00:20.419989',
#   '2022-02-24 05:00:20.419991',
#   '188.147.40.126'),
#  (711,
#   'Ashley Davis',
#   'alyssa39@example.com',
#   '3925 Schaefer Canyon\nSouth Aliciachester, SK E2A3R5',
#   'Maynardfurt',
#   'British Columbia',
#   'Nigeria',
#   '570.937.4412',
#   'Nisi necessitatibus dolore laudantium dicta. Dolorum aliquid sint '
#   'blanditiis. Debitis id error ex unde.',
#   '1983-02-18',
#   1043,
#   '2022-02-24 05:00:20.420838',
#   '2022-02-24 05:00:20.420839',
#   '65.58.149.12'),
#  (712,
#   'Victoria Baldwin DVM',
#   'brandon48@example.com',
#   '75021 Nicholson Course\nLake Elizabeth, NL K5R3P9',
#   'South Kurtberg',
#   'Alberta',
#   'Turkey',
#   '(460) 946-1747 x522',
#   'Recusandae reprehenderit dicta eveniet nostrum. Nihil facilis quia. Aliquam '
#   'distinctio quod consequatur enim dolorem.',
#   '2020-01-10',
#   1616,
#   '2022-02-24 05:00:20.421689',
#   '2022-02-24 05:00:20.421690',
#   '161.177.89.97'),
#  (713,
#   'Heather Kane',
#   'laurenibarra@example.com',
#   '740 Thornton Plains\nKeithmouth, SK E3K4X8',
#   'Pinedastad',
#   'New Brunswick',
#   'Peru',
#   '(144) 363-3135',
#   'Neque pariatur sint dolorem sint laboriosam neque. Distinctio doloribus '
#   'doloremque. Soluta nobis ratione possimus quis architecto. Necessitatibus '
#   'illo numquam nobis ad culpa distinctio.',
#   '2016-02-29',
#   2077,
#   '2022-02-24 05:00:20.422603',
#   '2022-02-24 05:00:20.422604',
#   '58.120.44.170'),
#  (714,
#   'Kiara Solomon',
#   'hperez@example.org',
#   '859 Heidi Groves Apt. 075\nAmyfurt, QC G7V7Y7',
#   'West Lindsayborough',
#   'Nunavut',
#   'Marshall Islands',
#   '601 055 7556',
#   'Quos asperiores quam aut nobis. Dignissimos ducimus quisquam accusantium '
#   'nemo consectetur tempora. A neque eum sed eaque molestiae.',
#   '1981-10-27',
#   2353,
#   '2022-02-24 05:00:20.423432',
#   '2022-02-24 05:00:20.423433',
#   '50.76.45.42'),
#  (715,
#   'Trevor Walters',
#   'james02@example.com',
#   '824 Hill Motorway\nEast Justinchester, ON S4S9J9',
#   'Kristenview',
#   'Northwest Territories',
#   'Australia',
#   '+1 (693) 696-3611',
#   'Distinctio doloremque veniam dicta temporibus voluptatem esse. Iure '
#   'dignissimos porro quod maxime. Nam voluptas ipsum modi nobis totam '
#   'adipisci.',
#   '1995-10-18',
#   2120,
#   '2022-02-24 05:00:20.424229',
#   '2022-02-24 05:00:20.424230',
#   '144.161.168.97'),
#  (716,
#   'Omar Osborne',
#   'williambishop@example.org',
#   '114 Rice Expressway Suite 129\nSullivanborough, SK A2J4C7',
#   'East Williammouth',
#   'Prince Edward Island',
#   'Wallis and Futuna',
#   '+1 (164) 571-1327',
#   'Distinctio hic modi mollitia laborum doloremque.',
#   '2007-04-23',
#   1592,
#   '2022-02-24 05:00:20.425118',
#   '2022-02-24 05:00:20.425119',
#   '83.193.123.36'),
#  (717,
#   'Christina Acosta',
#   'kgutierrez@example.net',
#   '66884 Brown Ports Apt. 888\nEast Shaunview, NU T6L 5V9',
#   'New Alishaborough',
#   'Northwest Territories',
#   'Papua New Guinea',
#   '+1 (423) 530-6052',
#   'Veniam voluptatem placeat accusantium. Veniam repudiandae itaque ipsa ipsum '
#   'error. Impedit quos alias dignissimos.',
#   '1980-11-21',
#   1513,
#   '2022-02-24 05:00:20.425967',
#   '2022-02-24 05:00:20.425968',
#   '62.52.156.105'),
#  (718,
#   'Scott Neal',
#   'jamiedurham@example.org',
#   '66843 Taylor Port Apt. 732\nSouth Gabriellemouth, NS L8H4S7',
#   'Greenfurt',
#   'Saskatchewan',
#   'Hong Kong',
#   '989.100.5343',
#   'Vitae optio in deserunt nemo. Nihil quisquam perferendis accusantium '
#   'voluptate voluptate corrupti.',
#   '2005-05-28',
#   1218,
#   '2022-02-24 05:00:20.426883',
#   '2022-02-24 05:00:20.426884',
#   '176.37.48.206'),
#  (719,
#   'Hailey Leach',
#   'modonnell@example.org',
#   '0081 Porter Hollow Apt. 672\nWest James, QC E3C4H5',
#   'Hullmouth',
#   'Nova Scotia',
#   'Uzbekistan',
#   '(902) 810-2023 x767',
#   'Reprehenderit quas veniam quisquam nobis doloremque. Beatae illum eligendi '
#   'doloremque tempore quis at.',
#   '1995-03-10',
#   1699,
#   '2022-02-24 05:00:20.427930',
#   '2022-02-24 05:00:20.427932',
#   '121.143.157.139'),
#  (720,
#   'Christine Weaver',
#   'jeffrey58@example.org',
#   '74209 Sherry Hills Suite 920\nNorth Kathleen, MB S2C 9M8',
#   'Ricardomouth',
#   'Northwest Territories',
#   'Tonga',
#   '1 (955) 607-8413',
#   'Voluptas quasi iste architecto similique alias facere. Occaecati ullam sunt '
#   'voluptate dolores sapiente atque.',
#   '2021-07-12',
#   2392,
#   '2022-02-24 05:00:20.428784',
#   '2022-02-24 05:00:20.428785',
#   '106.138.204.86'),
#  (721,
#   'Erin Smith',
#   'pstephens@example.com',
#   '95896 Kenneth Harbors\nSouth Troymouth, NS K4Y 3L9',
#   'West Sean',
#   'Yukon Territory',
#   'Malta',
#   '+1 (470) 408-3732',
#   'Odit quo quod maxime distinctio. Neque perspiciatis laborum ex inventore et '
#   'nulla voluptas. Dicta quae accusamus eaque maxime ipsa.',
#   '2014-04-03',
#   2423,
#   '2022-02-24 05:00:20.429940',
#   '2022-02-24 05:00:20.429941',
#   '125.2.7.198'),
#  (722,
#   'Veronica Melton',
#   'coxfrancis@example.net',
#   '52071 Mark Cove\nRodriguezmouth, NL J4J6T1',
#   'Suarezmouth',
#   'Nova Scotia',
#   'Myanmar',
#   '+1 (321) 554-3007',
#   'Mollitia vitae voluptatibus quibusdam. Consectetur recusandae similique. '
#   'Fugit est veniam odio.',
#   '1979-09-22',
#   1328,
#   '2022-02-24 05:00:20.430975',
#   '2022-02-24 05:00:20.430976',
#   '198.122.137.154'),
#  (723,
#   'Bethany Hayes',
#   'ericaoneill@example.net',
#   '8113 Adam Vista\nSouth Alexandraton, AB A5J 3P5',
#   'Beckyburgh',
#   'Yukon Territory',
#   'Brazil',
#   '(567) 355-9209 x363',
#   'Consequatur fugit eos reiciendis voluptatem deserunt. Commodi quae optio '
#   'maxime numquam cumque. Nulla expedita a ut.',
#   '1991-06-29',
#   2312,
#   '2022-02-24 05:00:20.431931',
#   '2022-02-24 05:00:20.431932',
#   '14.115.250.180'),
#  (724,
#   'Brenda Hardy',
#   'davispatrick@example.org',
#   '582 Nichole Avenue Apt. 736\nFloreshaven, NS B6P 2T7',
#   'North Sherrifort',
#   'Northwest Territories',
#   'Papua New Guinea',
#   '1-260-495-9174',
#   'Tempore quasi nulla deserunt aspernatur officia eius. Pariatur amet dolorum '
#   'laborum dolorem blanditiis.',
#   '1988-01-31',
#   1764,
#   '2022-02-24 05:00:20.432891',
#   '2022-02-24 05:00:20.432892',
#   '20.187.87.227'),
#  (725,
#   'Andrew Tucker',
#   'adriannoble@example.org',
#   '709 Mccall Falls\nNew Nancyland, AB R1J1C9',
#   'Jamesmouth',
#   'Manitoba',
#   'Mexico',
#   '1 (743) 192-5609',
#   'Consequatur omnis inventore sed eligendi unde. Incidunt aperiam repellendus '
#   'quaerat officiis.',
#   '1995-01-02',
#   1878,
#   '2022-02-24 05:00:20.433797',
#   '2022-02-24 05:00:20.433798',
#   '201.90.159.100'),
#  (726,
#   'Joseph Bell',
#   'jenniferdavis@example.org',
#   '798 Mahoney Stream\nNorth Carolynburgh, AB P1P 2A2',
#   'Boydmouth',
#   'Manitoba',
#   'Fiji',
#   '1-425-612-5914',
#   'Iste distinctio pariatur.',
#   '2011-07-22',
#   2019,
#   '2022-02-24 05:00:20.434709',
#   '2022-02-24 05:00:20.434710',
#   '99.6.215.215'),
#  (727,
#   'Melissa Robertson',
#   'justin51@example.net',
#   '7264 Carl Groves Apt. 583\nDavidsonfort, NU H9A 6H2',
#   'Kimberlyborough',
#   'Quebec',
#   'Romania',
#   '726-028-1682',
#   'Ex adipisci magni reiciendis. Suscipit architecto molestiae praesentium '
#   'sit.',
#   '1997-01-13',
#   1722,
#   '2022-02-24 05:00:20.435539',
#   '2022-02-24 05:00:20.435540',
#   '53.47.91.78'),
#  (728,
#   'Samantha Brewer',
#   'ruizerin@example.org',
#   '67452 Savage Vista Suite 040\nKeithfurt, QC H7T2H1',
#   'Elizabethstad',
#   'Ontario',
#   'Pitcairn Islands',
#   '1-558-910-7837',
#   'Laboriosam assumenda molestiae sapiente mollitia. Harum odio velit. '
#   'Doloribus voluptatibus natus architecto ratione explicabo culpa aut.',
#   '1981-05-04',
#   2169,
#   '2022-02-24 05:00:20.436444',
#   '2022-02-24 05:00:20.436445',
#   '158.46.10.166'),
#  (729,
#   'Amanda Moore',
#   'jaredreed@example.org',
#   '88440 Anthony Ferry\nWest Kayla, SK B3E 2S1',
#   'North Robertside',
#   'Prince Edward Island',
#   'Saint Kitts and Nevis',
#   '1 (221) 458-4262',
#   'Alias quas nihil fugiat asperiores assumenda quod. Harum assumenda '
#   'doloremque totam eum.',
#   '1993-04-14',
#   1896,
#   '2022-02-24 05:00:20.437298',
#   '2022-02-24 05:00:20.437313',
#   '115.146.234.28'),
#  (730,
#   'Brian Morris',
#   'lopezrobert@example.net',
#   '383 Alyssa Streets\nSouth Joseph, BC R2A 9J2',
#   'Port Deborah',
#   'Nova Scotia',
#   'Djibouti',
#   '1-487-267-0558',
#   'Quis perferendis perferendis officia. Optio ad beatae iure vero. Ex et '
#   'dolorum doloremque ipsa ipsa.',
#   '1999-09-12',
#   1740,
#   '2022-02-24 05:00:20.438188',
#   '2022-02-24 05:00:20.438190',
#   '168.25.174.188'),
#  (731,
#   'Dawn Green',
#   'ryanmoore@example.net',
#   '43945 Kristopher Passage Apt. 397\nStanleyville, NT G9A3K5',
#   'Lake Morgan',
#   'Nova Scotia',
#   'Jordan',
#   '255 903 7963',
#   'Laudantium nihil voluptates sed saepe. Itaque eos iure.',
#   '2013-08-22',
#   1951,
#   '2022-02-24 05:00:20.439235',
#   '2022-02-24 05:00:20.439237',
#   '93.74.75.140'),
#  (732,
#   'Richard Davis',
#   'shellypruitt@example.net',
#   '4146 Joseph Prairie Suite 634\nPort Marcus, NB P5G9Y1',
#   'Johnsonfort',
#   'Alberta',
#   'Canada',
#   '1 (860) 030-7304',
#   'Vitae inventore aperiam. Molestiae odit sunt expedita odit eos '
#   'reprehenderit consequatur. Qui esse sapiente ad animi tempora explicabo '
#   'voluptatibus.',
#   '1984-02-09',
#   1798,
#   '2022-02-24 05:00:20.440435',
#   '2022-02-24 05:00:20.440436',
#   '180.217.219.241'),
#  (733,
#   'Samantha Barnes',
#   'francisamanda@example.net',
#   '0378 Rodney Lock\nMooneyburgh, PE A1C5X7',
#   'West Christinaview',
#   'Yukon Territory',
#   'Sierra Leone',
#   '1-478-657-1573',
#   'Corporis illum dolores illum amet voluptas nobis fuga.',
#   '1994-08-20',
#   1783,
#   '2022-02-24 05:00:20.441419',
#   '2022-02-24 05:00:20.441420',
#   '138.154.150.209'),
#  (734,
#   'Mark Barr',
#   'joyce41@example.com',
#   '9567 Robert Vista\nNew Steven, MB P7L 1Y8',
#   'Smithbury',
#   'Prince Edward Island',
#   'Pakistan',
#   '1-769-592-6148',
#   'Odit quo est illo officiis tenetur rem. Iste repellendus facilis esse '
#   'quisquam iusto. Natus autem beatae exercitationem error id quis.',
#   '1995-06-19',
#   1041,
#   '2022-02-24 05:00:20.442275',
#   '2022-02-24 05:00:20.442276',
#   '66.164.226.6'),
#  (735,
#   'Felicia Kim',
#   'karen70@example.org',
#   '11285 Adams Knoll\nPort Eric, MB N6H1P2',
#   'Johnsonmouth',
#   'British Columbia',
#   'Lebanon',
#   '431.264.1369',
#   'Non illo nesciunt mollitia ipsum vitae. Minus exercitationem at maiores '
#   'architecto laboriosam fugiat. Voluptatibus vel neque dolorem.',
#   '1990-03-21',
#   1369,
#   '2022-02-24 05:00:20.443167',
#   '2022-02-24 05:00:20.443169',
#   '116.135.181.203'),
#  (736,
#   'Kevin Walters',
#   'lisacole@example.net',
#   '05438 Murillo Isle Suite 993\nNew Andrea, MB T9K6K3',
#   'Lake Vincentport',
#   'British Columbia',
#   'Pakistan',
#   '403 358 5650',
#   'Sapiente dolorum quae cupiditate. Dolorem consequatur minus quam '
#   'voluptatum. Error doloribus hic incidunt impedit.',
#   '2001-10-16',
#   1370,
#   '2022-02-24 05:00:20.444093',
#   '2022-02-24 05:00:20.444094',
#   '148.219.217.79'),
#  (737,
#   'Morgan Curry',
#   'mjennings@example.org',
#   '259 Carl Squares\nWest Ashley, SK N4A 5Y1',
#   'Michaelbury',
#   'Saskatchewan',
#   'Serbia',
#   '884.515.2679',
#   'Dicta quaerat ullam fugiat. Dicta est vel commodi quo atque. Voluptatibus '
#   'sapiente saepe quam velit.',
#   '1985-02-14',
#   2338,
#   '2022-02-24 05:00:20.444917',
#   '2022-02-24 05:00:20.444919',
#   '138.29.113.205'),
#  (738,
#   'Lisa Myers',
#   'kevinlee@example.org',
#   '507 Washington Lock Apt. 155\nJamesburgh, PE J8S5B1',
#   'South Patrickburgh',
#   'Newfoundland and Labrador',
#   'Bolivia',
#   '119.335.5987',
#   'Hic quidem voluptatum. Numquam provident iste illum molestiae ipsam '
#   'perspiciatis. Impedit assumenda accusantium molestiae.',
#   '2014-11-17',
#   1329,
#   '2022-02-24 05:00:20.445912',
#   '2022-02-24 05:00:20.445913',
#   '124.139.187.93'),
#  (739,
#   'Dana Bentley',
#   'larry05@example.net',
#   '469 Michele Parks Apt. 000\nEast Jennifertown, BC M6K 2C4',
#   'Hayesberg',
#   'Northwest Territories',
#   'Angola',
#   '1-318-786-7604',
#   'Dolorum culpa dolorem veritatis cum veniam. Sunt vel aspernatur voluptatum '
#   'in temporibus. Impedit tenetur ea nihil soluta minus possimus.',
#   '1977-02-17',
#   1785,
#   '2022-02-24 05:00:20.446842',
#   '2022-02-24 05:00:20.446843',
#   '11.98.62.136'),
#  (740,
#   'Pamela Becker',
#   'ashleysantiago@example.net',
#   '2147 Allison Land Apt. 955\nLake Stephanie, PE T2M 2L7',
#   'Baxterview',
#   'New Brunswick',
#   'Philippines',
#   '652 523 1946',
#   'Soluta laboriosam saepe delectus fugiat nobis numquam. Rem blanditiis harum '
#   'optio cupiditate nam.',
#   '2000-08-13',
#   2328,
#   '2022-02-24 05:00:20.447750',
#   '2022-02-24 05:00:20.447751',
#   '98.166.2.168'),
#  (741,
#   'Steven Bautista',
#   'lopezanna@example.com',
#   '67600 White Run\nRogerton, NT C7S6L4',
#   'Porterburgh',
#   'Nunavut',
#   'French Southern Territories',
#   '+1 (755) 377-8107',
#   'At excepturi eum corrupti a. Vel consequatur vero dolorem velit.',
#   '1983-05-05',
#   1050,
#   '2022-02-24 05:00:20.448660',
#   '2022-02-24 05:00:20.448661',
#   '107.129.31.89'),
#  (742,
#   'Brian Moody',
#   'savannah81@example.com',
#   '240 Justin Overpass Apt. 395\nSmithville, BC B1P 3P7',
#   'North Charles',
#   'Nova Scotia',
#   'Northern Mariana Islands',
#   '867.073.2680',
#   'Unde blanditiis autem maiores at.',
#   '1999-10-01',
#   1177,
#   '2022-02-24 05:00:20.449546',
#   '2022-02-24 05:00:20.449547',
#   '54.224.88.192'),
#  (743,
#   'Kelli Rangel',
#   'richard71@example.org',
#   '98051 Christine Unions\nPort Lindashire, NL V4N 8S8',
#   'Jillport',
#   'Northwest Territories',
#   'Holy See (Vatican City State)',
#   '346-524-9694 x992',
#   'Recusandae placeat odio explicabo eligendi veritatis. Nobis voluptatem '
#   'consequuntur perferendis nam consequatur. Neque perspiciatis officia. Animi '
#   'voluptate reiciendis optio totam.',
#   '2001-03-05',
#   2269,
#   '2022-02-24 05:00:20.450384',
#   '2022-02-24 05:00:20.450385',
#   '108.78.5.184'),
#  (744,
#   'Robert Madden',
#   'schroedermadison@example.net',
#   '66830 Arthur Turnpike Suite 278\nPort Brenda, MB R7X 9G7',
#   'Richardberg',
#   'Quebec',
#   'Guinea',
#   '(329) 641-2176',
#   'Repudiandae nisi necessitatibus voluptas architecto. Totam numquam '
#   'accusamus accusantium.',
#   '1988-01-06',
#   2420,
#   '2022-02-24 05:00:20.451250',
#   '2022-02-24 05:00:20.451252',
#   '71.115.218.99'),
#  (745,
#   'Ronald Maddox',
#   'laurajones@example.com',
#   '383 Henry Estates\nNorth Josephbury, NB L7Y5A6',
#   'Huberchester',
#   'Alberta',
#   'Iran',
#   '(470) 298-0348',
#   'Aliquid deleniti eum molestias suscipit dolorem. Ratione laudantium cumque '
#   'nobis nisi. Tenetur necessitatibus vitae voluptas adipisci sed. Architecto '
#   'fuga quaerat vero quam quasi corporis.',
#   '1999-06-16',
#   1325,
#   '2022-02-24 05:00:20.452165',
#   '2022-02-24 05:00:20.452166',
#   '158.134.176.109'),
#  (746,
#   'Jenna Harris',
#   'dthompson@example.org',
#   '86228 Stewart Crescent Apt. 024\nJessemouth, NL G2N1E3',
#   'Wrightfurt',
#   'New Brunswick',
#   'Kenya',
#   '(299) 172-8570',
#   'Dicta officia ex. Vero placeat saepe illum voluptatem voluptatum possimus.',
#   '2017-11-18',
#   1748,
#   '2022-02-24 05:00:20.453049',
#   '2022-02-24 05:00:20.453050',
#   '137.128.21.156'),
#  (747,
#   'Kristine Russell',
#   'robertflores@example.com',
#   '804 Bowers Falls Apt. 451\nPort Suzanneberg, NT H8A 9S1',
#   'Williamstown',
#   'Ontario',
#   'Oman',
#   '529.049.2831',
#   'Eius consequuntur dolore. Repudiandae sunt tempore repellat rem. Aspernatur '
#   'et velit eaque qui dicta ea.',
#   '2004-02-22',
#   1693,
#   '2022-02-24 05:00:20.453984',
#   '2022-02-24 05:00:20.453985',
#   '184.31.40.134'),
#  (748,
#   'Juan Wise',
#   'wbarnett@example.com',
#   '7961 Ronald Place\nSouth Pennyshire, MB T4T 7B3',
#   'East Christopher',
#   'Prince Edward Island',
#   'Guadeloupe',
#   '(999) 188-8170',
#   'Facere ipsam ad nesciunt. Ad debitis quam excepturi saepe quos.',
#   '2021-04-27',
#   2298,
#   '2022-02-24 05:00:20.454789',
#   '2022-02-24 05:00:20.454790',
#   '33.112.205.212'),
#  (749,
#   'Jacob Mclaughlin',
#   'andrewskatie@example.org',
#   '3419 Fernandez Overpass Suite 916\nNew Tiffany, MB R2P 2H8',
#   'New Christopher',
#   'Alberta',
#   'Tonga',
#   '(339) 912-9454 x160',
#   'Neque maiores quae assumenda voluptate beatae.',
#   '1993-08-21',
#   1031,
#   '2022-02-24 05:00:20.455698',
#   '2022-02-24 05:00:20.455699',
#   '171.82.191.6'),
#  (750,
#   'Amber Lawson',
#   'vbarnes@example.com',
#   '29968 Jennifer Flat Suite 039\nNorth Hailey, BC V1V1S3',
#   'Landryhaven',
#   'Ontario',
#   'Norway',
#   '(371) 679-2525',
#   'Tenetur sint quod voluptate recusandae possimus ratione. Perferendis veniam '
#   'velit eum ex. Saepe ea temporibus.',
#   '2008-08-22',
#   1819,
#   '2022-02-24 05:00:20.456680',
#   '2022-02-24 05:00:20.456681',
#   '145.100.58.193'),
#  (751,
#   'Lisa Gibbs',
#   'victor20@example.net',
#   '19582 Wade Locks\nVincenthaven, PE A8J5J1',
#   'Sherihaven',
#   'Yukon Territory',
#   'Wallis and Futuna',
#   '1-323-487-7983',
#   'Id perferendis commodi nulla. Repudiandae animi tempore quos. Impedit '
#   'numquam repellat alias.',
#   '1970-04-09',
#   1921,
#   '2022-02-24 05:00:20.457525',
#   '2022-02-24 05:00:20.457526',
#   '119.55.58.211'),
#  (752,
#   'Rebecca Craig',
#   'angela50@example.com',
#   '7490 Morgan Estates\nEast Sabrina, NU X4K 7H9',
#   'Leslieshire',
#   'Prince Edward Island',
#   'Guadeloupe',
#   '(622) 334-6687',
#   'Amet praesentium facilis officiis. Non repellat maxime cum repellendus '
#   'quasi laborum. Numquam corporis harum doloribus velit.',
#   '2007-01-06',
#   2345,
#   '2022-02-24 05:00:20.458379',
#   '2022-02-24 05:00:20.458381',
#   '177.255.234.225'),
#  (753,
#   'Vanessa Escobar',
#   'fhawkins@example.org',
#   '9602 Veronica Fields Apt. 828\nHobbsview, MB R1S 7X9',
#   'Tiffanychester',
#   'British Columbia',
#   'Bulgaria',
#   '123 323 0038',
#   'Aliquid accusantium sunt recusandae aperiam perferendis nemo. Ut dolores ut '
#   'fugit nulla aliquid. Soluta inventore soluta nesciunt ad ipsam minima.',
#   '2019-05-25',
#   1730,
#   '2022-02-24 05:00:20.459748',
#   '2022-02-24 05:00:20.459750',
#   '94.178.125.31'),
#  (754,
#   'Aaron Brown',
#   'orozcoalyssa@example.org',
#   '56965 Torres Throughway\nEast Erin, BC L6J 9J5',
#   'Port Daniel',
#   'Nova Scotia',
#   'Bouvet Island (Bouvetoya)',
#   '1 (812) 955-0616',
#   'Nemo fuga maiores pariatur. Iste et ex. Asperiores velit consequatur '
#   'molestias ut.',
#   '2000-12-17',
#   2448,
#   '2022-02-24 05:00:20.461073',
#   '2022-02-24 05:00:20.461074',
#   '115.26.137.225'),
#  (755,
#   'Lawrence Miller',
#   'kjohnson@example.net',
#   '857 Matthew Parks Apt. 080\nWest Johnton, BC E6N5N3',
#   'South Patrick',
#   'Alberta',
#   'Nauru',
#   '370.285.2399',
#   'Ipsa veritatis libero qui aspernatur dolore maxime. Rem assumenda deleniti '
#   'qui occaecati quos.',
#   '2005-09-22',
#   1490,
#   '2022-02-24 05:00:20.462045',
#   '2022-02-24 05:00:20.462047',
#   '149.212.0.189'),
#  (756,
#   'Deborah Schmidt',
#   'johnhall@example.net',
#   '64322 Savannah Square\nSouth Evanberg, YT R9L 1A9',
#   'Donaldborough',
#   'New Brunswick',
#   'Gambia',
#   '(621) 635-2264',
#   'Ad accusamus provident nam ad possimus ea. Beatae omnis esse necessitatibus '
#   'veniam temporibus fugit. Magnam porro aliquid aperiam quam rem hic.',
#   '2015-02-19',
#   1828,
#   '2022-02-24 05:00:20.463511',
#   '2022-02-24 05:00:20.463512',
#   '143.0.196.225'),
#  (757,
#   'Luke Torres',
#   'josephsimmons@example.org',
#   '965 Rodriguez Viaduct\nKristinfurt, SK L1A5R6',
#   'New Sandra',
#   'Yukon Territory',
#   'China',
#   '747-812-9454 x724',
#   'Sint soluta possimus quia quod. Deleniti possimus nesciunt placeat '
#   'inventore et laboriosam. Possimus occaecati voluptatum ipsum minus '
#   'recusandae nostrum. Accusantium deleniti labore facilis harum.',
#   '2009-11-09',
#   1267,
#   '2022-02-24 05:00:20.464841',
#   '2022-02-24 05:00:20.464843',
#   '221.200.149.202'),
#  (758,
#   'Karen Woods',
#   'duncansteven@example.net',
#   '127 Brown Pike Suite 503\nWest Kristamouth, NB G7S 4L4',
#   'Jordanhaven',
#   'Ontario',
#   'Kazakhstan',
#   '770 137 3921',
#   'Aliquid at dolore ratione possimus rerum.',
#   '1988-03-13',
#   1384,
#   '2022-02-24 05:00:20.466077',
#   '2022-02-24 05:00:20.466079',
#   '9.211.19.132'),
#  (759,
#   'Ruth Archer',
#   'ajensen@example.com',
#   '10083 Renee Burgs\nGarciastad, NS M4V 4J2',
#   'New Seanborough',
#   'Ontario',
#   'Libyan Arab Jamahiriya',
#   '532.636.5849',
#   'Nam repellendus voluptatibus inventore recusandae laudantium esse. Sunt '
#   'atque eos saepe explicabo ipsam. Aliquid harum harum explicabo corporis '
#   'quaerat sapiente.',
#   '1981-11-08',
#   2462,
#   '2022-02-24 05:00:20.467155',
#   '2022-02-24 05:00:20.467157',
#   '10.165.120.17'),
#  (760,
#   'David Cole',
#   'samueljenkins@example.com',
#   '11118 Julie Springs\nMatthewfort, NU H2P2X2',
#   'Lake Alicia',
#   'Alberta',
#   'Taiwan',
#   '333 240 1195',
#   'Culpa dolor impedit at neque doloremque. Rem odit harum deserunt. Iste '
#   'quidem voluptatibus suscipit eligendi.',
#   '1983-03-27',
#   1785,
#   '2022-02-24 05:00:20.468662',
#   '2022-02-24 05:00:20.468664',
#   '109.113.87.54'),
#  (761,
#   'Andrew Hurley',
#   'andersonjohn@example.com',
#   '14463 Martin Cliffs Suite 115\nWalshview, NT K9R 8E6',
#   'Simonburgh',
#   'Nova Scotia',
#   'United Kingdom',
#   '(406) 829-4548',
#   'Totam dignissimos occaecati. Fugiat unde debitis expedita. Eaque facere '
#   'quasi ad tenetur corporis dicta cupiditate.',
#   '2014-11-10',
#   2088,
#   '2022-02-24 05:00:20.470131',
#   '2022-02-24 05:00:20.470133',
#   '212.45.35.236'),
#  (762,
#   'Tina Nguyen',
#   'jeffharrison@example.com',
#   '19723 Katelyn Islands\nWest Austin, SK M6R7J2',
#   'Elizabethborough',
#   'Nova Scotia',
#   'United Arab Emirates',
#   '(977) 422-3925 x844',
#   'Possimus ducimus voluptas perferendis. Deleniti saepe aliquid quod. Quaerat '
#   'a quae iste. Eveniet autem illum nesciunt nemo sunt error vero.',
#   '2010-10-09',
#   1363,
#   '2022-02-24 05:00:20.471077',
#   '2022-02-24 05:00:20.471078',
#   '206.22.66.163'),
#  (763,
#   'Erin Rodriguez',
#   'ryan78@example.net',
#   '1024 Vang Fords Suite 966\nKathyshire, ON A5S 6T6',
#   'Yolandaport',
#   'Northwest Territories',
#   'Seychelles',
#   '268-745-9956 x235',
#   'Itaque sint aliquid non non adipisci beatae. Facilis ut magni corporis '
#   'doloremque.',
#   '1994-11-20',
#   2330,
#   '2022-02-24 05:00:20.471943',
#   '2022-02-24 05:00:20.471944',
#   '141.6.226.193'),
#  (764,
#   'Carol Stevens',
#   'qwilliams@example.net',
#   '507 Howell Island\nLake Katherineside, PE C4M6B1',
#   'West Janice',
#   'Newfoundland and Labrador',
#   'Armenia',
#   '447 549 7803',
#   'Non minus delectus. Voluptatibus ratione delectus voluptates commodi ea.',
#   '1978-02-01',
#   2149,
#   '2022-02-24 05:00:20.472781',
#   '2022-02-24 05:00:20.472782',
#   '221.180.250.25'),
#  (765,
#   'Ana Wright',
#   'jamesfowler@example.com',
#   '32011 Castro Ville Apt. 469\nEast Jamesview, QC V5S 8V8',
#   'East Cory',
#   'Quebec',
#   'Georgia',
#   '+1 (536) 608-4608',
#   'Cum quaerat voluptates sit. Ullam voluptatibus temporibus sunt.',
#   '1973-01-26',
#   2471,
#   '2022-02-24 05:00:20.473685',
#   '2022-02-24 05:00:20.473687',
#   '18.69.128.246'),
#  (766,
#   'Alice Wright',
#   'patrick30@example.net',
#   '3816 Trujillo Ford Apt. 506\nWest Jeffrey, NB M9S9P6',
#   'Scottville',
#   'Prince Edward Island',
#   'Guadeloupe',
#   '616-625-5980',
#   'Dolorum nobis temporibus fugit repellendus quos iure. Iste deleniti sequi '
#   'iste accusamus.',
#   '2016-03-22',
#   1241,
#   '2022-02-24 05:00:20.474501',
#   '2022-02-24 05:00:20.474502',
#   '200.151.113.110'),
#  (767,
#   'Lori Lawson',
#   'lopezdonald@example.net',
#   '03863 Hansen Circles\nNorth Jeffery, SK G4N 1K2',
#   'Pattonshire',
#   'Saskatchewan',
#   'Mayotte',
#   '1 (600) 464-1950',
#   'Nisi asperiores quae adipisci. Mollitia placeat vero vitae. Facilis '
#   'perferendis aspernatur a vero tenetur quasi ipsum. Excepturi sit rerum '
#   'impedit.',
#   '2007-05-07',
#   1654,
#   '2022-02-24 05:00:20.475476',
#   '2022-02-24 05:00:20.475477',
#   '138.78.185.139'),
#  (768,
#   'Erica Nielsen',
#   'samuelwilson@example.net',
#   '36250 Owen Grove Suite 161\nWest Roberthaven, NL C8J 8S3',
#   'Sarahport',
#   'Alberta',
#   'Sudan',
#   '1-773-798-2807',
#   'Saepe quia sint recusandae alias. Quia delectus tenetur rerum. Dignissimos '
#   'omnis ad necessitatibus. Tenetur quaerat eligendi eaque quod assumenda '
#   'alias.',
#   '2008-06-25',
#   1001,
#   '2022-02-24 05:00:20.476410',
#   '2022-02-24 05:00:20.476411',
#   '30.29.106.153'),
#  (769,
#   'Steve Garcia',
#   'julie19@example.org',
#   '9890 Mitchell Islands\nWest Annshire, NU P8G1N1',
#   'Rebeccaport',
#   'Quebec',
#   'Portugal',
#   '790 982 7866',
#   'Facilis placeat eaque accusamus. Omnis magnam dignissimos rerum at.',
#   '1985-02-03',
#   2477,
#   '2022-02-24 05:00:20.477214',
#   '2022-02-24 05:00:20.477215',
#   '68.1.111.181'),
#  (770,
#   'Ashley Trujillo',
#   'ryansmith@example.org',
#   '66822 William Pine\nSouth Kimberlyview, NB T4H 8Y8',
#   'Kellyburgh',
#   'Ontario',
#   'Czech Republic',
#   '(605) 212-4186',
#   'Qui ea exercitationem vero officia nemo. Excepturi ab ipsum.',
#   '2019-08-23',
#   1455,
#   '2022-02-24 05:00:20.478095',
#   '2022-02-24 05:00:20.478096',
#   '83.63.17.90'),
#  (771,
#   'Stephanie Booker',
#   'marywagner@example.com',
#   '1663 Mary River\nWilliamstad, BC J9K 7K4',
#   'Chelseabury',
#   'Quebec',
#   'Turkey',
#   '+1 (743) 961-5602',
#   'Optio eaque itaque explicabo sequi iusto voluptas dignissimos. Expedita '
#   'placeat consectetur totam iure similique.',
#   '2010-06-21',
#   2403,
#   '2022-02-24 05:00:20.478937',
#   '2022-02-24 05:00:20.478938',
#   '218.207.73.58'),
#  (772,
#   'Kristy Wright',
#   'nancymiller@example.net',
#   '00105 Richards Wells Suite 301\nPort Alexandra, SK Y1P 1C7',
#   'West Benjamin',
#   'Saskatchewan',
#   'Zimbabwe',
#   '178-673-8454 x715',
#   'Accusamus nostrum laudantium architecto. Nesciunt suscipit nobis delectus '
#   'laudantium. Beatae cumque ducimus dolorum libero.',
#   '1986-01-02',
#   1395,
#   '2022-02-24 05:00:20.479838',
#   '2022-02-24 05:00:20.479840',
#   '89.36.7.39'),
#  (773,
#   'Brett Banks',
#   'breannasolomon@example.com',
#   '184 Andersen Alley\nMaureenmouth, YT H6H7H9',
#   'South Yvonnebury',
#   'Saskatchewan',
#   'Antigua and Barbuda',
#   '1-645-252-7662',
#   'Adipisci repellat neque ullam corporis quaerat. Eum mollitia sed '
#   'architecto. Eos modi sit illo blanditiis rem.',
#   '2019-01-10',
#   2079,
#   '2022-02-24 05:00:20.480732',
#   '2022-02-24 05:00:20.480733',
#   '223.83.141.150'),
#  (774,
#   'Gregory King',
#   'jonescrystal@example.net',
#   '9579 Andre Vista Suite 081\nNelsonberg, QC T2A 1E6',
#   'Michaelton',
#   'Manitoba',
#   'Bosnia and Herzegovina',
#   '(254) 381-7728',
#   'Labore neque veritatis perferendis.',
#   '1984-10-04',
#   1120,
#   '2022-02-24 05:00:20.481605',
#   '2022-02-24 05:00:20.481606',
#   '124.64.223.186'),
#  (775,
#   'Miss Deborah Gomez',
#   'hillmary@example.com',
#   '7855 Adriana Cliffs\nNew Melanie, YT L5P5S5',
#   'Port Kellymouth',
#   'Ontario',
#   'United Arab Emirates',
#   '638 285 7540',
#   'Libero fuga reiciendis deserunt animi quasi eaque repudiandae. Ipsum cum '
#   'doloribus delectus animi. Ut dolores quisquam blanditiis quas.',
#   '1981-05-30',
#   1849,
#   '2022-02-24 05:00:20.482499',
#   '2022-02-24 05:00:20.482500',
#   '34.75.142.26'),
#  (776,
#   'Christopher Velazquez',
#   'qsantiago@example.net',
#   '033 Albert Light\nNew Nathaniel, ON N6T 5J7',
#   'New Jacquelinemouth',
#   'Quebec',
#   'Gabon',
#   '1 (459) 748-0749',
#   'Veritatis commodi soluta rem reprehenderit. Repudiandae ratione repudiandae '
#   'quas doloribus numquam modi aliquid.',
#   '2014-08-12',
#   1573,
#   '2022-02-24 05:00:20.483286',
#   '2022-02-24 05:00:20.483287',
#   '214.176.89.102'),
#  (777,
#   'Luis Richard',
#   'holmessherry@example.com',
#   '0978 Rios Harbors\nCurrymouth, AB X2G8G4',
#   'Williamston',
#   'Nunavut',
#   'Papua New Guinea',
#   '(143) 355-7254',
#   'Temporibus quaerat impedit ullam reprehenderit nulla sapiente vel.',
#   '1972-12-22',
#   1614,
#   '2022-02-24 05:00:20.484190',
#   '2022-02-24 05:00:20.484191',
#   '174.242.156.85'),
#  (778,
#   'Nathaniel Johnson',
#   'james99@example.org',
#   '18549 Robert Ridges\nKristiburgh, NT P6K6C4',
#   'Victoriaside',
#   'Alberta',
#   'Barbados',
#   '+1 (791) 582-1078',
#   'Eveniet minus reiciendis totam. Cum ea molestias illum dicta aliquid '
#   'asperiores.',
#   '1974-07-26',
#   1896,
#   '2022-02-24 05:00:20.484956',
#   '2022-02-24 05:00:20.484957',
#   '117.152.3.156'),
#  (779,
#   'Michael Simpson',
#   'elainetaylor@example.net',
#   '3783 Raymond Green Suite 206\nNew Mary, NS H5K 3P6',
#   'Butlerville',
#   'Manitoba',
#   'Bolivia',
#   '182.093.8185',
#   'Sed vel architecto at vitae molestiae vel totam.',
#   '1996-03-04',
#   1759,
#   '2022-02-24 05:00:20.485829',
#   '2022-02-24 05:00:20.485830',
#   '153.138.182.77'),
#  (780,
#   'Isaiah Hall',
#   'mark49@example.org',
#   '1169 Alexander Forest Apt. 157\nJessicafort, NT M1X3T7',
#   'East Ashleyhaven',
#   'New Brunswick',
#   'Moldova',
#   '+1 (615) 251-5967',
#   'Autem magnam soluta et ipsum sit consequatur. Aspernatur vero iure '
#   'voluptate. Veritatis nemo optio itaque voluptates eveniet.',
#   '1988-11-14',
#   1388,
#   '2022-02-24 05:00:20.486658',
#   '2022-02-24 05:00:20.486659',
#   '37.47.83.16'),
#  (781,
#   'Carla Gross',
#   'randy91@example.com',
#   '379 Olivia Stream Apt. 733\nHurstfurt, NU N3E6Y9',
#   'East Alexis',
#   'Yukon Territory',
#   'Panama',
#   '(866) 982-0791',
#   'Ut fuga eius eaque aspernatur. Praesentium velit quis. Dolores reiciendis '
#   'vel fugit officia officiis quis.',
#   '2010-07-27',
#   2417,
#   '2022-02-24 05:00:20.487487',
#   '2022-02-24 05:00:20.487488',
#   '1.125.33.215'),
#  (782,
#   'Isabella Lynch',
#   'ygraves@example.org',
#   '6229 Patrick Streets\nLake Michael, ON G6K 9N5',
#   'Amymouth',
#   'Saskatchewan',
#   'Trinidad and Tobago',
#   '551 524 5195',
#   'Iure numquam eligendi quo possimus adipisci animi. Officia laudantium nobis '
#   'dolor repellat natus. Alias sunt sapiente magni pariatur assumenda a.',
#   '2012-03-31',
#   2258,
#   '2022-02-24 05:00:20.488282',
#   '2022-02-24 05:00:20.488283',
#   '146.212.49.30'),
#  (783,
#   'Christopher Lutz',
#   'jessica52@example.org',
#   '654 Jamie Curve\nLake Christinaburgh, PE K2P 3V2',
#   'Georgeton',
#   'Quebec',
#   'Afghanistan',
#   '808.416.9717',
#   'Dolore molestiae hic unde vero porro. Placeat praesentium eaque.',
#   '1973-12-27',
#   2409,
#   '2022-02-24 05:00:20.489073',
#   '2022-02-24 05:00:20.489075',
#   '65.235.208.60'),
#  (784,
#   'Randy Torres',
#   'danieldaniel@example.org',
#   '2574 Benjamin Crest\nKarenville, NL X2G1B5',
#   'Floresfurt',
#   'Nova Scotia',
#   'Guadeloupe',
#   '1 (396) 278-9365',
#   'Debitis quaerat occaecati voluptatum. Amet qui error autem corporis modi. '
#   'Enim necessitatibus exercitationem saepe alias dolore.',
#   '1997-06-27',
#   2335,
#   '2022-02-24 05:00:20.489940',
#   '2022-02-24 05:00:20.489942',
#   '170.133.0.223'),
#  (785,
#   'Darius Vasquez',
#   'raymondsmith@example.org',
#   '63792 Glass Key\nLake Adrian, NU R9N 3G7',
#   'Smithborough',
#   'British Columbia',
#   'Mexico',
#   '236-104-9045 x567',
#   'Omnis dolor asperiores accusamus molestias vel. Exercitationem iste '
#   'doloremque voluptatibus ipsum dolor ipsam.',
#   '1974-01-20',
#   2176,
# ...
#   'exercitationem.',
#   '1995-10-20',
#   1132,
#   '2022-02-24 05:00:20.665192',
#   '2022-02-24 05:00:20.665193',
#   '158.174.47.8'),
#  (963,
#   'Tony Bond',
#   'jason42@example.org',
#   '2027 Stephens Dale\nSouth Mark, NB V1V2H4',
#   'Tylerbury',
#   'Alberta',
#   'French Southern Territories',
#   '1 (662) 653-2163',
#   'Quidem voluptatibus soluta excepturi ipsum doloremque similique. Ipsam eum '
#   'temporibus explicabo.',
#   '2008-06-01',
#   1186,
#   '2022-02-24 05:00:20.666009',
#   '2022-02-24 05:00:20.666010',
#   '24.143.90.19'),
#  (964,
#   'Chelsea Ferrell',
#   'bautistajamie@example.org',
#   '7733 Sean Skyway Apt. 770\nNorth Gloria, NT X5X2N3',
#   'Maynardchester',
#   'Nova Scotia',
#   'Montenegro',
#   '(231) 990-8044',
#   'Aut totam tempore voluptatum nesciunt quod.',
#   '1996-07-27',
#   2351,
#   '2022-02-24 05:00:20.666899',
#   '2022-02-24 05:00:20.666900',
#   '207.97.227.102'),
#  (965,
#   'Katie Petty',
#   'stephen94@example.org',
#   '81061 Michael Squares\nSteeletown, NU B6X4S3',
#   'Christinaport',
#   'Nunavut',
#   'American Samoa',
#   '432-392-0066',
#   'Neque reiciendis ea enim debitis. Dolor quis odio magni similique tempora '
#   'explicabo illum. Dolore officia debitis repellat aut voluptatem magnam. Non '
#   'accusamus odio nam ea.',
#   '1980-05-06',
#   2087,
#   '2022-02-24 05:00:20.667796',
#   '2022-02-24 05:00:20.667797',
#   '111.142.225.197'),
#  (966,
#   'Jeffrey Day',
#   'jessica33@example.org',
#   '7975 Carter Mount\nEast Maurice, SK T9B4S4',
#   'Welchport',
#   'Nova Scotia',
#   'Cook Islands',
#   '906 575 7667',
#   'Facilis quis esse ipsum. Occaecati explicabo aperiam deserunt sequi '
#   'nesciunt veritatis.',
#   '2009-06-29',
#   2006,
#   '2022-02-24 05:00:20.668645',
#   '2022-02-24 05:00:20.668647',
#   '198.73.227.219'),
#  (967,
#   'Christopher Moore',
#   'tammy85@example.net',
#   '2103 Perkins Crossing\nJordanberg, NS B5L 5X1',
#   'North Catherineport',
#   'Saskatchewan',
#   'Micronesia',
#   '1 (283) 254-2165',
#   'Porro voluptatem expedita ad. Minus asperiores exercitationem aperiam ex '
#   'sint.',
#   '2006-07-24',
#   1049,
#   '2022-02-24 05:00:20.669449',
#   '2022-02-24 05:00:20.669450',
#   '217.3.10.109'),
#  (968,
#   'Joshua Moreno',
#   'utaylor@example.com',
#   '9745 Jennifer Fields Apt. 264\nLake Robertstad, ON H1A 6T1',
#   'Marshside',
#   'Newfoundland and Labrador',
#   'Tonga',
#   '1-714-415-3740',
#   'Adipisci dolorem saepe ea.',
#   '2006-12-03',
#   2139,
#   '2022-02-24 05:00:20.670287',
#   '2022-02-24 05:00:20.670288',
#   '189.235.218.204'),
#  (969,
#   'Mary Lopez',
#   'maxwelldaniel@example.net',
#   '0530 Moses Shores Apt. 401\nNorth Douglas, QC V2L6X1',
#   'South Jonathan',
#   'Nunavut',
#   'Switzerland',
#   '1-992-944-3195',
#   'Quo voluptatum aut nam delectus quis occaecati.',
#   '2012-11-17',
#   1126,
#   '2022-02-24 05:00:20.671163',
#   '2022-02-24 05:00:20.671164',
#   '66.96.68.7'),
#  (970,
#   'Christina Rojas MD',
#   'clarence65@example.org',
#   '668 John Isle Apt. 230\nLake Lukebury, ON P4V 2R6',
#   'Erikaview',
#   'Ontario',
#   'Yemen',
#   '+1 (275) 109-0512',
#   'Odio sint quisquam. Dolorum pariatur praesentium deserunt repellendus '
#   'similique harum.',
#   '1998-03-18',
#   1054,
#   '2022-02-24 05:00:20.671967',
#   '2022-02-24 05:00:20.671968',
#   '90.188.39.146'),
#  (971,
#   'Christine Torres',
#   'abush@example.net',
#   '34030 Norris Bypass\nPattersonstad, QC P3B4G9',
#   'West Brianshire',
#   'Northwest Territories',
#   'Jamaica',
#   '+1 (607) 222-0266',
#   'Veniam nisi suscipit similique ratione totam. Incidunt voluptas doloremque '
#   'et in velit. Quod ipsa deserunt praesentium aliquid labore.',
#   '1999-08-09',
#   1718,
#   '2022-02-24 05:00:20.672816',
#   '2022-02-24 05:00:20.672817',
#   '67.45.189.27'),
#  (972,
#   'Shirley Harris',
#   'howard12@example.net',
#   '22670 Melinda Field Suite 194\nBarbaraton, QC A1B5J7',
#   'Port Nathaniel',
#   'Manitoba',
#   'Nauru',
#   '(612) 803-3570 x532',
#   'Impedit recusandae perferendis praesentium alias ullam possimus modi. '
#   'Consequuntur provident hic similique delectus.',
#   '1989-11-18',
#   1435,
#   '2022-02-24 05:00:20.673617',
#   '2022-02-24 05:00:20.673618',
#   '153.255.152.194'),
#  (973,
#   'Katelyn Morris',
#   'rrussell@example.net',
#   '793 Cummings Knolls\nNorth Edward, NL S4A 5A3',
#   'North James',
#   'Newfoundland and Labrador',
#   'Bermuda',
#   '1 (696) 196-7098',
#   'Rerum voluptas voluptate possimus. Rerum expedita blanditiis pariatur earum '
#   'inventore. Hic rerum dolorem. Aliquam sint pariatur voluptate.',
#   '1992-07-03',
#   2393,
#   '2022-02-24 05:00:20.674466',
#   '2022-02-24 05:00:20.674467',
#   '171.13.25.195'),
#  (974,
#   'James Hardy',
#   'chelsea04@example.net',
#   '7552 Amanda Island Apt. 852\nLewisshire, QC P9E1C5',
#   'Barbarastad',
#   'Quebec',
#   'Cambodia',
#   '+1 (799) 879-1486',
#   'Commodi cumque similique saepe consequuntur iste eum. Non maxime veniam '
#   'aliquam. Neque officiis provident temporibus sequi corporis.',
#   '1990-11-20',
#   1109,
#   '2022-02-24 05:00:20.675284',
#   '2022-02-24 05:00:20.675285',
#   '70.2.139.56'),
#  (975,
#   'Charles Gonzalez',
#   'michellegentry@example.org',
#   '2156 Hall Ford\nNorth Josephborough, PE A8X7L9',
#   'Welchmouth',
#   'Northwest Territories',
#   'Mayotte',
#   '661-892-7985',
#   'Enim nam sit voluptate optio saepe.',
#   '1979-08-05',
#   1113,
#   '2022-02-24 05:00:20.676196',
#   '2022-02-24 05:00:20.676197',
#   '206.240.87.101'),
#  (976,
#   'Shawn Sandoval',
#   'cindy75@example.org',
#   '9940 Rice Locks\nPort Cassidy, SK Y1T 3R2',
#   'Troystad',
#   'Prince Edward Island',
#   'Nicaragua',
#   '638-881-5159',
#   'Natus repudiandae eveniet. Tempore id itaque amet.',
#   '1985-05-26',
#   1982,
#   '2022-02-24 05:00:20.676993',
#   '2022-02-24 05:00:20.676994',
#   '193.57.164.222'),
#  (977,
#   'Christopher Little',
#   'kennethcook@example.net',
#   '614 Michael Dale\nWest Michelle, NL J8Y3K9',
#   'Port Dawnberg',
#   'New Brunswick',
#   'Cuba',
#   '865.068.1839',
#   'Placeat eaque officia. Quam unde unde quaerat dolores.',
#   '1989-11-11',
#   1428,
#   '2022-02-24 05:00:20.677828',
#   '2022-02-24 05:00:20.677829',
#   '206.104.227.193'),
#  (978,
#   'Sarah Lin',
#   'mackenziesmith@example.net',
#   '67479 Jason Landing Suite 731\nRyanton, NT B8G 1J7',
#   'South John',
#   'Manitoba',
#   'Ghana',
#   '641 002 3070',
#   'Quas et deleniti hic perspiciatis sequi ducimus. Velit deleniti id pariatur '
#   'facere. Ullam explicabo velit deleniti reprehenderit.',
#   '1991-05-09',
#   1881,
#   '2022-02-24 05:00:20.678739',
#   '2022-02-24 05:00:20.678741',
#   '80.68.17.107'),
#  (979,
#   'Kristy Evans',
#   'michelle70@example.com',
#   '1294 Lamb Streets\nEast Victormouth, NU P8V 1K2',
#   'West Michael',
#   'Yukon Territory',
#   'Nepal',
#   '1-595-029-1034',
#   'Maxime ut quod hic ipsa quaerat vel. Unde nostrum accusantium reprehenderit '
#   'natus temporibus.',
#   '1980-08-31',
#   2352,
#   '2022-02-24 05:00:20.679599',
#   '2022-02-24 05:00:20.679600',
#   '25.164.112.100'),
#  (980,
#   'Lindsey Murray',
#   'craig53@example.org',
#   '00271 Reynolds Points\nSouth Stephen, NB N6J 9T6',
#   'New Christinaville',
#   'Alberta',
#   'Palestinian Territory',
#   '398-000-7968',
#   'Deleniti veritatis suscipit dolores maiores. Enim suscipit molestiae quos '
#   'adipisci.',
#   '1978-09-04',
#   1769,
#   '2022-02-24 05:00:20.680413',
#   '2022-02-24 05:00:20.680414',
#   '28.206.236.202'),
#  (981,
#   'Jessica Lopez',
#   'william62@example.net',
#   '015 Eric Glens\nParkerbury, NL N3H 9G1',
#   'Port Oliviaport',
#   'Yukon Territory',
#   'Hong Kong',
#   '(320) 576-5990',
#   'Iure voluptas facere aperiam adipisci quam. Ullam recusandae quibusdam '
#   'error fugiat nostrum ducimus. Optio sunt veritatis eius sunt perspiciatis '
#   'odit.',
#   '2000-11-28',
#   1349,
#   '2022-02-24 05:00:20.681203',
#   '2022-02-24 05:00:20.681204',
#   '83.170.64.44'),
#  (982,
#   'Joseph Harris',
#   'tgallagher@example.net',
#   '18060 Tammy Island Suite 458\nWashingtonchester, NB S6Y1S3',
#   'Lake Katherine',
#   'Nova Scotia',
#   'French Polynesia',
#   '+1 (221) 677-8221',
#   'Molestias reprehenderit nulla cum nisi. Consequatur cupiditate pariatur '
#   'molestias quaerat aperiam. A hic occaecati quaerat commodi. Ipsam ex '
#   'voluptatem.',
#   '1977-03-12',
#   2323,
#   '2022-02-24 05:00:20.682065',
#   '2022-02-24 05:00:20.682067',
#   '63.65.162.15'),
#  (983,
#   'Kevin Anderson',
#   'briana76@example.net',
#   '5524 Ward Plains\nSimpsonburgh, YT N9B 8T4',
#   'New Timothy',
#   'Prince Edward Island',
#   'Peru',
#   '890-361-2880 x539',
#   'Dolor amet architecto omnis eum deserunt. Id repellat blanditiis '
#   'necessitatibus excepturi. Vitae fuga dolore numquam eos deserunt.',
#   '2002-07-28',
#   2412,
#   '2022-02-24 05:00:20.682894',
#   '2022-02-24 05:00:20.682895',
#   '21.190.233.191'),
#  (984,
#   'James Pineda',
#   'anthonyanderson@example.com',
#   '18922 Beck Skyway Apt. 018\nTownsendport, ON S1G 7P9',
#   'Crystaltown',
#   'Nunavut',
#   'Bangladesh',
#   '(551) 088-0676 x760',
#   'Dignissimos quos eveniet harum. Explicabo ad accusamus aut assumenda. Eaque '
#   'officia explicabo quidem ipsum.',
#   '2006-04-11',
#   2163,
#   '2022-02-24 05:00:20.684229',
#   '2022-02-24 05:00:20.684231',
#   '126.141.129.105'),
#  (985,
#   'Michael Small',
#   'katie89@example.org',
#   '8707 Macias Valley\nMichellehaven, SK H4N 8A9',
#   'New Mark',
#   'Quebec',
#   'Sudan',
#   '+1 (531) 670-5995',
#   'Harum commodi praesentium earum consectetur cupiditate laudantium '
#   'perspiciatis.',
#   '1985-12-26',
#   1733,
#   '2022-02-24 05:00:20.685084',
#   '2022-02-24 05:00:20.685085',
#   '110.0.25.174'),
#  (986,
#   'Angela Russell',
#   'gstewart@example.com',
#   '8356 Stephanie Lock\nWest Johnside, NB C6A 9R5',
#   'Jamesfurt',
#   'Northwest Territories',
#   'El Salvador',
#   '1 (838) 416-2543',
#   'Commodi a dignissimos. Modi molestias voluptas consectetur accusamus. Culpa '
#   'aliquid deleniti repudiandae.',
#   '1975-09-08',
#   1235,
#   '2022-02-24 05:00:20.685951',
#   '2022-02-24 05:00:20.685952',
#   '189.93.227.205'),
#  (987,
#   'Samantha Cameron',
#   'brooke14@example.net',
#   '29230 Pamela Dale\nWest Danielland, NL E9V 1N2',
#   'West Mark',
#   'Ontario',
#   'Tokelau',
#   '+1 (578) 681-5879',
#   'Error unde repellendus odio maiores saepe nulla. Vel harum placeat nemo. '
#   'Harum magni possimus dolore error.',
#   '1988-02-15',
#   1098,
#   '2022-02-24 05:00:20.687162',
#   '2022-02-24 05:00:20.687164',
#   '86.185.191.109'),
#  (988,
#   'Robin Jones',
#   'goodwincindy@example.org',
#   '1911 Valerie Fall Apt. 319\nLake Leon, NT P7Y4M7',
#   'Cuevasville',
#   'Ontario',
#   'Mali',
#   '+1 (150) 171-6158',
#   'Facilis qui aliquam placeat incidunt. Ut facilis et aut illo.',
#   '1974-03-25',
#   1521,
#   '2022-02-24 05:00:20.688681',
#   '2022-02-24 05:00:20.688684',
#   '195.207.121.156'),
#  (989,
#   'Angelica Randall',
#   'rhondahopkins@example.com',
#   '93282 Ryan Road Suite 672\nLisaland, NL M3P5G7',
#   'Port Cherylburgh',
#   'Yukon Territory',
#   'Guinea',
#   '+1 (719) 764-4785',
#   'Aperiam tempore hic ea possimus fugit est. Inventore qui repellendus ut.',
#   '1997-05-24',
#   2463,
#   '2022-02-24 05:00:20.690145',
#   '2022-02-24 05:00:20.690147',
#   '186.92.196.21'),
#  (990,
#   'Daniel Fisher',
#   'wongjames@example.net',
#   '4387 Robert Ford\nKevinton, ON L2J8S1',
#   'South Jenna',
#   'New Brunswick',
#   'Puerto Rico',
#   '1-898-028-8627',
#   'Perspiciatis possimus impedit ipsum aperiam.',
#   '1984-07-25',
#   2245,
#   '2022-02-24 05:00:20.691571',
#   '2022-02-24 05:00:20.691573',
#   '168.244.54.76'),
#  (991,
#   'Elizabeth Allen',
#   'sherri24@example.org',
#   '606 Joshua Trail Apt. 850\nJosephchester, YT K1P 2R8',
#   'South Megan',
#   'Manitoba',
#   'Equatorial Guinea',
#   '(672) 274-8329 x597',
#   'Labore ab tempora. Architecto ullam minima ipsam. Aliquam ducimus veritatis '
#   'esse nihil magnam.',
#   '2016-12-08',
#   1464,
#   '2022-02-24 05:00:20.692892',
#   '2022-02-24 05:00:20.692893',
#   '167.209.223.217'),
#  (992,
#   'Joseph Holloway',
#   'beth85@example.org',
#   '575 Black Walks\nSouth Tinahaven, NL J9G 7G1',
#   'Hoffmanmouth',
#   'Saskatchewan',
#   'Antigua and Barbuda',
#   '(181) 065-5971',
#   'Magni consequuntur beatae dicta ut unde.',
#   '1976-09-19',
#   1544,
#   '2022-02-24 05:00:20.694190',
#   '2022-02-24 05:00:20.694191',
#   '77.40.208.129'),
#  (993,
#   'Jodi Proctor',
#   'davismary@example.org',
#   '981 Smith Views\nMariomouth, NL A3A 2L9',
#   'New Shawnstad',
#   'British Columbia',
#   'Liechtenstein',
#   '650-869-0389',
#   'Doloribus fugiat consequatur impedit at debitis. Eius ex nulla officiis '
#   'quisquam quaerat. Fugit optio voluptatum quaerat.',
#   '2014-07-04',
#   2357,
#   '2022-02-24 05:00:20.695123',
#   '2022-02-24 05:00:20.695124',
#   '87.83.37.94'),
#  (994,
#   'Madison Stone',
#   'eringrimes@example.com',
#   '0742 Nicholas Glens Suite 460\nPort Patriciabury, NL J4A 9R5',
#   'Jeremyland',
#   'Manitoba',
#   'Slovenia',
#   '695 730 5085',
#   'Voluptatum rem ipsum consectetur vero assumenda eligendi veniam. Recusandae '
#   'tenetur similique ullam voluptatem.',
#   '2010-12-20',
#   1308,
#   '2022-02-24 05:00:20.696058',
#   '2022-02-24 05:00:20.696059',
#   '57.163.9.89'),
#  (995,
#   'Vincent Miller',
#   'blevinstheresa@example.net',
#   '8624 Jeff Way Suite 462\nNew Travisside, NT B5X 2N1',
#   'Johnton',
#   'Yukon Territory',
#   'Venezuela',
#   '666-140-4654',
#   'Doloribus incidunt reprehenderit veritatis cupiditate. Neque laborum '
#   'adipisci nisi.',
#   '2003-08-02',
#   1654,
#   '2022-02-24 05:00:20.697091',
#   '2022-02-24 05:00:20.697093',
#   '142.43.222.213'),
#  (996,
#   'Peter Murphy',
#   'anthony20@example.org',
#   '1907 Donna Land\nSouth Mary, AB M2T 1N6',
#   'Kathleenland',
#   'Newfoundland and Labrador',
#   'Macao',
#   '589-240-6388 x409',
#   'Odio ipsam sed suscipit libero cumque laboriosam. Sed optio quod et. Saepe '
#   'eligendi quas labore nulla quasi minima commodi.',
#   '1985-01-29',
#   1658,
#   '2022-02-24 05:00:20.698477',
#   '2022-02-24 05:00:20.698479',
#   '190.251.6.5'),
#  (997,
#   'Christopher Sanchez',
#   'howelljack@example.com',
#   '2046 Manuel Club Apt. 258\nNew Taylor, YT P6K 7K7',
#   'Underwoodtown',
#   'Manitoba',
#   'Bahamas',
#   '1 (474) 640-4019',
#   'Inventore totam soluta vitae ut. Magni laudantium labore enim et. Molestiae '
#   'delectus optio saepe minima amet.',
#   '1992-04-17',
#   1531,
#   '2022-02-24 05:00:20.700224',
#   '2022-02-24 05:00:20.700226',
#   '34.192.66.73'),
#  (998,
#   'Keith Chapman',
#   'eric09@example.net',
#   '5489 Cabrera Ramp Apt. 980\nJuanberg, NU A6X3M8',
#   'Melissaborough',
#   'New Brunswick',
#   'Djibouti',
#   '1 (316) 263-7614',
#   'Excepturi explicabo eum nostrum recusandae fugit ut. Architecto modi fugit '
#   'a reprehenderit quas. Veritatis at ex placeat sit possimus est.',
#   '1979-12-29',
#   1330,
#   '2022-02-24 05:00:20.701670',
#   '2022-02-24 05:00:20.701672',
#   '94.186.226.54'),
#  (999,
#   'Tanya Rodriguez',
#   'petermorales@example.net',
#   '5869 Debra Route Suite 385\nLake Abigail, SK V8X5J2',
#   'Lake Angelicaside',
#   'Ontario',
#   'Andorra',
#   '(281) 876-2974',
#   'Accusantium tempora animi molestias possimus. Ullam qui impedit quibusdam '
#   'eveniet tenetur.',
#   '1977-05-16',
#   2135,
#   '2022-02-24 05:00:20.703220',
#   '2022-02-24 05:00:20.703222',
#   '102.235.169.83'),
#  (1000,
#   'Shannon Kelly',
#   'frenchjacqueline@example.com',
#   '1887 Juan Freeway\nEast Tammymouth, MB B4B3N4',
#   'West Rebecca',
#   'Northwest Territories',
#   'Liechtenstein',
#   '146.392.6902',
#   'Quos ducimus cupiditate et impedit. Sed distinctio eius qui in quidem '
#   'debitis.',
#   '2021-01-23',
#   1783,
#   '2022-02-24 05:00:20.704330',
#   '2022-02-24 05:00:20.704332',
#   '77.109.210.148'),
#  (1001,
#   'Kayla Bryan',
#   'adamshayley@example.com',
#   '27796 Sawyer Extensions\nRaymondtown, SK S4S8R4',
#   'North Amyborough',
#   'New Brunswick',
#   'Mauritania',
#   '352-183-2824',
#   'Fugiat rerum natus nisi magnam id. Deleniti adipisci eaque delectus '
#   'aspernatur accusantium.',
#   '1984-06-30',
#   1602,
#   '2022-02-24 05:00:20.705569',
#   '2022-02-24 05:00:20.705571',
#   '143.205.23.2'),
#  (1002,
#   'Brittany Spencer',
#   'salvarez@example.com',
#   '88640 Jensen Knoll\nPort Sarahtown, SK T2S 2N4',
#   'New Christopher',
#   'Prince Edward Island',
#   "Cote d'Ivoire",
#   '(438) 709-5266 x792',
#   'Recusandae sed minima perferendis culpa ipsum voluptate. Nihil assumenda '
#   'eveniet consectetur vero itaque quae. Adipisci in eligendi a quisquam dolor '
#   'illum.',
#   '1974-06-28',
#   2157,
#   '2022-02-24 05:00:20.706786',
#   '2022-02-24 05:00:20.706788',
#   '155.148.207.129')]

# %% [markdown]
# Finally, the last step,
# Using the code block below, combined with what you have learned above, and the Lecture notes,
# Craft a SQL Query that will return the `name` of no more than `20` `people` with a `heatmap` greater than `1500`

# %%
import sqlite3
import pprint
#Retreive the Connection object
myConnection = sqlite3.connect('social_network.db')

#Once we have a Connection object, we can generate a Cursor object, and use that to run our SQL Queries
myCursor = myConnection.cursor()

selectStatement = """SELECT ... """

#myCursor.execute( ... )
#results = myCursor.fetchall()
#pprint(results)

# %% [markdown]
# Your submission will contain, as usual, a link to your completed colab notebook, but in addition to that, you will download a copy of your social_network.db file and upload it to D2L. To download the file, right click it from the Files menu on the left of the Notebook.
