# %% [markdown]
# <a href="https://colab.research.google.com/github/bquantri/comp593/blob/main/COMP593-Lab3-BenQuantrill.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # LAB 3: WORKING WITH DATABASES

# %% [markdown]
# ## Introduction
#
# During this lab, we will experiment with using a few different libararies and modules to connect to and interact with an SQLite database. After creating and configuring our testing database, we will populate it with Fake data and run some queries to see what kind of information we can retreive. For context, we will be creating RSSN, the "Really Simple Social Network".

# %% [markdown]
# ## Creating a SQLite Database
#
# We will be utilizing the `sqlite3` library to create our database file, as it offers the convienience of creating our database file automatically in the event that it cannot find an existing file at the path specified.
#
# **Before you run the below code:**
# On the left of the notebook, select the file folder icon. Then, after you run the code block, you should be able to observe the creation of the database file. If it doesn't appear, try clicking the "Refresh" button above the list of folders.

# %%
import sqlite3

#When we retreive a Connection object, a new database will be created for us if it doesn't already exist. 
myConnection = sqlite3.connect('social_network.db')
print(sqlite3.version)
# Out:
# 2.6.0

# %% [markdown]
# ## Creating a Table

# %% [markdown]
# We'll use the below code to create a table called `people` within our database.

# %%
import sqlite3

#Retreive the Connection object
myConnection = sqlite3.connect('social_network.db')

#Once we have a Connection object, we can generate a Cursor object, and use that to run our SQL Queries
myCursor = myConnection.cursor()

#Let's define the SQL Query we will use to create our first table:
createPeopleTable = """ CREATE TABLE IF NOT EXISTS people (
                          id integer PRIMARY KEY,
                          name text NOT NULL,
                          email text NOT NULL,
                          address text NOT NULL,
                          city text NOT NULL,
                          province text NOT NULL,
                          country text NOT NULL,
                          phone text,
                          bio text,
                          dob date NOT NULL,
                          heatmap integer,
                          created_at datetime NOT NULL,
                          updated_at datetime NOT NULL,
                          ipv4 text
                        );"""

#Now that we have the string to create our table,
#Cursor objects have an execute() method which will accept an SQL string and perform the operations described.

myCursor.execute(createPeopleTable)

#We can confirm if our table was created successfully by running the following SQL Query
#pragma_table_info is an internal SQLite function that will retun information about a table
myCursor.execute("SELECT group_concat(name, ', ') FROM pragma_table_info('people')")
print(myCursor.fetchone())

#We use to the commit() method on the database Connection object to persist our changes
myConnection.commit()

#It is always a good idea to close a connection when it will no longer be used
myConnection.close()
# Out:
# ('id, name, email, address, city, province, country, phone, bio, dob, heatmap, created_at, updated_at, ipv4',)

# %% [markdown]
# If you received a tuple containing the names of the columns, awesome! We have successfully created our database table.
# ```
# ('id, name, email, address, city, province, country, phone, bio, created_at, updated_at',)
# ```
#
# Run the below code block to add our first entry.

# %%
import sqlite3
from pprint import pprint #Outputs data in a slightly easier to read format
from datetime import datetime #For generating dates and times

#Retreive the Connection object
myConnection = sqlite3.connect('social_network.db')

#Once we have a Connection object, we can generate a Cursor object, and use that to run our SQL Queries
myCursor = myConnection.cursor()

#Let's define the SQL Query we will use to create our first entry:
addPersonQuery = """INSERT INTO people (name, 
                      email, 
                      address, 
                      city, 
                      province, 
                      country, 
                      phone, 
                      bio,
                      dob,
                      heatmap,
                      created_at, 
                      updated_at, 
                      ipv4)
                  VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?);"""

"""
The ?'s are placeholders that we can fill in when we use the execute() method.
This is really handy for code reuse, as we can pass those values are variables in a tuple
Instead of hard coding them into the statement.
"""

myPerson = ("John Doe", 
            "johndoe@anon.null", 
            "123 Fake St.", 
            "Fakesville", 
            "Fakesdom", 
            "Fakopolis", 
            None, 
            None,
            "1967-09-12",
            0,
            datetime.now(), 
            datetime.now(),
            None)

myCursor.execute(addPersonQuery, myPerson)

#We can confirm if our table was created successfully by running the following SQL Query
#pragma_table_info is an internal SQLite function that will retun information about a table
myCursor.execute("SELECT * FROM people")
pprint(myCursor.fetchall())

# If you run this code block a few times, you will see that you only have 1 entry,
# If you uncomment the below lines and run the block a few more times, you will begin to see multiple entries.
myConnection.commit()
myConnection.close()
# Out:
# [(1,
#   'John Doe',
#   'johndoe@anon.null',
#   '123 Fake St.',
#   'Fakesville',
#   'Fakesdom',
#   'Fakopolis',
#   None,
#   None,
#   '1967-09-12',
#   0,
#   '2022-02-24 02:47:22.384379',
#   '2022-02-24 02:47:22.384391',
#   None),
#  (2,
#   'John Doe',
#   'johndoe@anon.null',
#   '123 Fake St.',
#   'Fakesville',
#   'Fakesdom',
#   'Fakopolis',
#   None,
#   None,
#   '1967-09-12',
#   0,
#   '2022-02-24 02:47:24.560960',
#   '2022-02-24 02:47:24.560971',
#   None)]

# %% [markdown]
# # Lab Submission

# %% [markdown]
# We're going to build our experience with working with Libraries and examining documentation by populating our 'People' table with data provided to us by the `Faker` library. `Faker` is used to generate fake data and is very helpful for the rapid generation of databases for the purposes of testing. Run the two blocks below to install faker and get an idea of what it can do.

# %%
# !pip install faker
# Out:
# Collecting faker
#   Downloading Faker-13.2.0-py3-none-any.whl (1.5 MB)
#      |████████████████████████████████| 1.5 MB 4.9 MB/s
# Requirement already satisfied: python-dateutil>=2.4 in /usr/local/lib/python3.7/dist-packages (from faker) (2.8.2)
# Requirement already satisfied: typing-extensions>=3.10.0.2 in /usr/local/lib/python3.7/dist-packages (from faker) (3.10.0.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.4->faker) (1.15.0)
# Installing collected packages: faker
# Successfully installed faker-13.2.0

# %%
from faker import Faker

fake = Faker()

for _ in range(10):
  print('{} || {}'.format( fake.name(), fake.state() ) )
# Out:
# Nicholas Davis || Utah
# Aaron Carpenter || Alabama
# Kevin Martin || Oregon
# Matthew Pearson || Maryland
# Barry Kelley || Minnesota
# Andrea Montoya || Wyoming
# Shelby Jones || Colorado
# Christopher Carroll || Montana
# Kenneth Hinton || South Carolina
# Daniel Brown || Tennessee

# %% [markdown]
# Very cool! Faker has tons of `providers` that can all be used to populate fake data. The [list of providers](https://faker.readthedocs.io/en/stable/providers.html) in the Faker documentation will help you fill out the columns for our People table.
#
# The goal of this script is to populate the people table with 1000 entries, with the following constraints:
#
# 1. The `heatmap` column must contain a random number between `999` and `2500`
# 2. The `created_at` and `updated_at` columns must use the `datetime` object (see examples above)
# 2. Use `Faker` to generate all other fields.
#
# *Hint: Each of the methods contained in the provider can be called directly from the base Faker object, for example, one can call the `file_name()` method from `faker.providers.file` by calling `Faker().file_name()`*

# %%
import sqlite3
from faker import Faker
from datetime import datetime #For generating dates and times
#Don't forget to import the module to generate random numbers!
from random import randint

#Retreive the Connection object
myConnection = sqlite3.connect('social_network.db')

#Once we have a Connection object, we can generate a Cursor object, and use that to run our SQL Queries
myCursor = myConnection.cursor()

#This is the same syntax as the above example:
addPersonQuery = """INSERT INTO people (name, 
                      email, 
                      address, 
                      city, 
                      province, 
                      country, 
                      phone, 
                      bio,
                      dob,
                      heatmap,
                      created_at, 
                      updated_at, 
                      ipv4)
                  VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?);"""

fake = Faker("en_CA")

i = 1
for i in range(1000):
  myPerson = (fake.name(), 
            fake.email(), 
            fake.address(), 
            fake.city(), 
            fake.administrative_unit(), 
            fake.country(), 
            fake.phone_number(), 
            fake.paragraph(nb_sentences=3),
            fake.date(),
            fake.random_int(min=999, max=2500),
            datetime.now(), 
            datetime.now(),
            fake.ipv4())
myCursor.execute(addPersonQuery, myPerson)
i += 1
print(myPerson)







#Ideally, you will want to create a loop that will iterate 1000 times,
#Observe the example in the earlier code block showing the parameter tuple `myPerson`
#You can duplicate that inside your loop and replace those fields with calls to the appropriate faker provider method
#Execute your statement inside the loop,
#But, don't forget to commit and close your connection when you have finished!
myCursor.execute("SELECT * FROM people")
pprint(myCursor.fetchall())

myConnection.commit()


myConnection.close()
# Out:
# Streaming output truncated to the last 5000 lines.
#   None),
#  (657,
#   'Danielle Garcia',
#   'thomasriley@example.com',
#   '635 Duncan Orchard Apt. 841\nChristianton, AB G3S 7Y6',
#   'South Benjamin',
#   'Manitoba',
#   'Cook Islands',
#   None,
#   None,
#   '2001-04-15',
#   1824,
#   '2022-02-24 04:31:38.735526',
#   '2022-02-24 04:31:38.735527',
#   None),
#  (658,
#   'Marcia Mcfarland',
#   'sturner@example.net',
#   '799 Andrea Walks\nHenryview, NS R6N 6K4',
#   'West Lee',
#   'Northwest Territories',
#   'Mayotte',
#   None,
#   None,
#   '1992-12-16',
#   1168,
#   '2022-02-24 04:31:38.736135',
#   '2022-02-24 04:31:38.736136',
#   None),
#  (659,
#   'Anthony Pratt',
#   'tonya57@example.org',
#   '744 Wagner Summit Suite 412\nNew Joseph, YT R3P3Y2',
#   'North Kathrynmouth',
#   'Alberta',
#   'Norfolk Island',
#   None,
#   None,
#   '1993-04-07',
#   2197,
#   '2022-02-24 04:31:38.736756',
#   '2022-02-24 04:31:38.736757',
#   None),
#  (660,
#   'Francisco Hayes',
#   'smithjacqueline@example.org',
#   '15142 Dominguez Valley\nBakerchester, NS N9G5J5',
#   'West Lance',
#   'Saskatchewan',
#   'Bahamas',
#   None,
#   None,
#   '1994-09-24',
#   1947,
#   '2022-02-24 04:31:38.737485',
#   '2022-02-24 04:31:38.737487',
#   None),
#  (661,
#   'Robert Holland',
#   'kimberlylewis@example.com',
#   '4957 Wilkerson Rue\nLake Alex, PE T6A 8T6',
#   'Russellmouth',
#   'Prince Edward Island',
#   'Kuwait',
#   None,
#   None,
#   '1994-12-11',
#   2012,
#   '2022-02-24 04:31:38.738172',
#   '2022-02-24 04:31:38.738173',
#   None),
#  (662,
#   'Spencer Morales',
#   'uscott@example.net',
#   '781 Spencer Islands\nNorth Wendy, SK T1T 5R5',
#   'Peterfort',
#   'Prince Edward Island',
#   'Cocos (Keeling) Islands',
#   None,
#   None,
#   '2005-07-18',
#   2015,
#   '2022-02-24 04:31:38.738806',
#   '2022-02-24 04:31:38.738807',
#   None),
#  (663,
#   'Kurt Brown',
#   'gomezadriana@example.com',
#   '91166 James Highway\nWest Michaelmouth, SK N8L9P9',
#   'Castrofort',
#   'Saskatchewan',
#   'Rwanda',
#   None,
#   None,
#   '2008-03-28',
#   2225,
#   '2022-02-24 04:31:38.739479',
#   '2022-02-24 04:31:38.739480',
#   None),
#  (664,
#   'Michael Wiley',
#   'angelawheeler@example.org',
#   '100 John Court\nWest Danielfurt, BC P9A 4H8',
#   'South Timothymouth',
#   'Newfoundland and Labrador',
#   'Northern Mariana Islands',
#   None,
#   None,
#   '1985-10-31',
#   1582,
#   '2022-02-24 04:31:38.740099',
#   '2022-02-24 04:31:38.740100',
#   None),
#  (665,
#   'Ross Washington',
#   'brandi30@example.org',
#   '38871 Lowe Port\nLake Robert, MB J2Y3H7',
#   'New Jenniferton',
#   'Ontario',
#   'Angola',
#   None,
#   None,
#   '2019-01-06',
#   1105,
#   '2022-02-24 04:31:38.740696',
#   '2022-02-24 04:31:38.740697',
#   None),
#  (666,
#   'Jennifer Long',
#   'tlozano@example.com',
#   '78325 Kim Tunnel Suite 820\nPort Johnhaven, SK X9P 5Y8',
#   'South Michaeltown',
#   'Prince Edward Island',
#   'Slovenia',
#   None,
#   None,
#   '1979-11-17',
#   1484,
#   '2022-02-24 04:31:38.741346',
#   '2022-02-24 04:31:38.741348',
#   None),
#  (667,
#   'Emily Mathews',
#   'veronicaruiz@example.com',
#   '2086 Jonathan Plaza\nRobinsonbury, ON V3J7A1',
#   'Port Jonathanmouth',
#   'Nunavut',
#   'Hong Kong',
#   None,
#   None,
#   '2007-03-02',
#   1058,
#   '2022-02-24 04:31:38.741996',
#   '2022-02-24 04:31:38.741997',
#   None),
#  (668,
#   'Mark Berry',
#   'gtorres@example.org',
#   '9941 Jacobs Common Apt. 241\nWest Mathew, BC M8Y 7T6',
#   'Schmidtton',
#   'British Columbia',
#   'El Salvador',
#   None,
#   None,
#   '1996-07-10',
#   2225,
#   '2022-02-24 04:31:38.742650',
#   '2022-02-24 04:31:38.742651',
#   None),
#  (669,
#   'Alan Lee',
#   'lbooker@example.net',
#   '925 Daniel Village Apt. 960\nDrakeland, NU R6V9M5',
#   'South Sabrinafort',
#   'Alberta',
#   'Malaysia',
#   None,
#   None,
#   '1972-12-17',
#   1461,
#   '2022-02-24 04:31:38.743265',
#   '2022-02-24 04:31:38.743266',
#   None),
#  (670,
#   'Christina Vaughan',
#   'lopeztiffany@example.net',
#   '89722 Joy Ramp\nEvansland, NU H4M3R6',
#   'West Alisonfurt',
#   'Manitoba',
#   'United Kingdom',
#   None,
#   None,
#   '2018-03-05',
#   1051,
#   '2022-02-24 04:31:38.743933',
#   '2022-02-24 04:31:38.743934',
#   None),
#  (671,
#   'Regina Moore',
#   'jeremy36@example.org',
#   '4795 Bond Meadow\nKellymouth, QC H5P5T5',
#   'North Joseph',
#   'Prince Edward Island',
#   'Faroe Islands',
#   None,
#   None,
#   '2017-07-17',
#   1818,
#   '2022-02-24 04:31:38.744525',
#   '2022-02-24 04:31:38.744526',
#   None),
#  (672,
#   'Timothy Hopkins',
#   'acevedojuan@example.net',
#   '380 Jonathan Trail Suite 167\nPatrickview, NB L1N 4L6',
#   'Karinaside',
#   'Saskatchewan',
#   'Dominican Republic',
#   None,
#   None,
#   '1988-05-11',
#   2407,
#   '2022-02-24 04:31:38.745158',
#   '2022-02-24 04:31:38.745159',
#   None),
#  (673,
#   'Mariah Valencia',
#   'marvinclark@example.com',
#   '16341 Fox Junction\nRichardchester, NU N2T6L3',
#   'Lorichester',
#   'Prince Edward Island',
#   'Niue',
#   None,
#   None,
#   '1976-04-09',
#   1835,
#   '2022-02-24 04:31:38.745837',
#   '2022-02-24 04:31:38.745838',
#   None),
#  (674,
#   'Amanda Proctor',
#   'tabithagray@example.com',
#   '6383 Amy Path Apt. 232\nWest Danaborough, NT E5T4A9',
#   'Kellyport',
#   'Saskatchewan',
#   'Antarctica (the territory South of 60 deg S)',
#   None,
#   None,
#   '2020-06-27',
#   2209,
#   '2022-02-24 04:31:38.746517',
#   '2022-02-24 04:31:38.746518',
#   None),
#  (675,
#   'Danielle Wood',
#   'nsmith@example.org',
#   '31680 Katrina Well\nAllenshire, NS K9E 4S3',
#   'North Jamesbury',
#   'Alberta',
#   'Fiji',
#   None,
#   None,
#   '2007-12-10',
#   2403,
#   '2022-02-24 04:31:38.747133',
#   '2022-02-24 04:31:38.747134',
#   None),
#  (676,
#   'Randy White',
#   'slynch@example.net',
#   '45137 Kiara Rue Suite 680\nBaileystad, NT V7J 8K8',
#   'Ellismouth',
#   'Newfoundland and Labrador',
#   'Tonga',
#   None,
#   None,
#   '2018-09-12',
#   1748,
#   '2022-02-24 04:31:38.747810',
#   '2022-02-24 04:31:38.747811',
#   None),
#  (677,
#   'William Turner',
#   'lewisjason@example.org',
#   '288 Lee Green Apt. 035\nWest Jacobchester, NU S2N6L1',
#   'Anthonyview',
#   'Nova Scotia',
#   'Saint Barthelemy',
#   None,
#   None,
#   '1976-03-01',
#   1908,
#   '2022-02-24 04:31:38.748502',
#   '2022-02-24 04:31:38.748503',
#   None),
#  (678,
#   'Carrie Swanson',
#   'alice57@example.com',
#   '71758 Joseph Drive\nRobinport, NB H4A8B3',
#   'Bobbyfort',
#   'Northwest Territories',
#   'Dominican Republic',
#   None,
#   None,
#   '1988-01-08',
#   2070,
#   '2022-02-24 04:31:38.749045',
#   '2022-02-24 04:31:38.749046',
#   None),
#  (679,
#   'Miranda Reilly',
#   'matthewcontreras@example.net',
#   '42516 Jason Turnpike\nBeckbury, SK A1E7G4',
#   'Ashleymouth',
#   'Saskatchewan',
#   'New Caledonia',
#   None,
#   None,
#   '1985-01-20',
#   1332,
#   '2022-02-24 04:31:38.749720',
#   '2022-02-24 04:31:38.749721',
#   None),
#  (680,
#   'Christopher Zimmerman',
#   'isaiah18@example.net',
#   '335 Hodges Fords Suite 502\nJuanberg, YT G2N8T9',
#   'Danaside',
#   'Quebec',
#   'Dominican Republic',
#   None,
#   None,
#   '2012-08-21',
#   1392,
#   '2022-02-24 04:31:38.750325',
#   '2022-02-24 04:31:38.750326',
#   None),
#  (681,
#   'Eileen Daniels',
#   'karenwilson@example.com',
#   '8123 Deborah Run\nPort Georgestad, QC S9Y1N5',
#   'East Michaelborough',
#   'British Columbia',
#   'Brazil',
#   None,
#   None,
#   '2004-01-18',
#   1859,
#   '2022-02-24 04:31:38.750952',
#   '2022-02-24 04:31:38.750953',
#   None),
#  (682,
#   'Maria Wilcox',
#   'allison70@example.com',
#   '697 Christian Lake Suite 709\nSweeneyview, NL M2V 1P2',
#   'Melissaville',
#   'Alberta',
#   'Zimbabwe',
#   None,
#   None,
#   '2001-01-10',
#   1722,
#   '2022-02-24 04:31:38.751557',
#   '2022-02-24 04:31:38.751558',
#   None),
#  (683,
#   'Jennifer Watts',
#   'obrienjeremy@example.net',
#   '655 Michael Roads\nLopezton, NL V4T 8X1',
#   'Lake Dawnmouth',
#   'Yukon Territory',
#   'Bahrain',
#   None,
#   None,
#   '2002-03-14',
#   1748,
#   '2022-02-24 04:31:38.752205',
#   '2022-02-24 04:31:38.752206',
#   None),
#  (684,
#   'David Brandt',
#   'danielle26@example.org',
#   '6309 Morgan Isle\nNorth Dominic, NS R4Y 7M9',
#   'Jonesberg',
#   'Alberta',
#   'Kenya',
#   None,
#   None,
#   '2003-01-21',
#   2338,
#   '2022-02-24 04:31:38.752793',
#   '2022-02-24 04:31:38.752794',
#   None),
#  (685,
#   'Chelsea Miranda',
#   'nicole17@example.net',
#   '982 Laura Courts\nLake Melissabury, BC V2L5C7',
#   'Robertsonstad',
#   'British Columbia',
#   'Switzerland',
#   None,
#   None,
#   '2018-07-07',
#   2183,
#   '2022-02-24 04:31:38.753388',
#   '2022-02-24 04:31:38.753389',
#   None),
#  (686,
#   'Steven Campbell',
#   'forbesthomas@example.net',
#   '6437 Vickie Lake\nKelseyton, AB H1N8T1',
#   'New Sarah',
#   'Quebec',
#   'Dominica',
#   None,
#   None,
#   '1999-07-28',
#   2433,
#   '2022-02-24 04:31:38.754000',
#   '2022-02-24 04:31:38.754001',
#   None),
#  (687,
#   'Jason Salas MD',
#   'cgonzalez@example.net',
#   '5343 Sloan Light Suite 141\nNew Christopher, NL A5T8S2',
#   'Thomasshire',
#   'Yukon Territory',
#   'Pakistan',
#   None,
#   None,
#   '2007-02-08',
#   2296,
#   '2022-02-24 04:31:38.754668',
#   '2022-02-24 04:31:38.754669',
#   None),
#  (688,
#   'Brian Lynch PhD',
#   'mayjeremy@example.net',
#   '55430 Spencer Wall Apt. 410\nRichardburgh, ON L1Y6E7',
#   'Gabrielleland',
#   'Nunavut',
#   'Fiji',
#   None,
#   None,
#   '1986-04-04',
#   1472,
#   '2022-02-24 04:31:38.755326',
#   '2022-02-24 04:31:38.755328',
#   None),
#  (689,
#   'Katelyn Fowler PhD',
#   'josephrodriguez@example.org',
#   '450 Brewer Lodge\nAndreastad, MB B4R9G6',
#   'East Robertberg',
#   'Prince Edward Island',
#   'Thailand',
#   None,
#   None,
#   '1972-07-07',
#   1102,
#   '2022-02-24 04:31:38.755990',
#   '2022-02-24 04:31:38.755991',
#   None),
#  (690,
#   'Daniel Montes',
#   'millerangela@example.net',
#   '9718 Green Pines\nNorth Peterchester, NS J8S 3X7',
#   'North Angela',
#   'New Brunswick',
#   'Lesotho',
#   None,
#   None,
#   '1978-02-14',
#   1877,
#   '2022-02-24 04:31:38.756767',
#   '2022-02-24 04:31:38.756768',
#   None),
#  (691,
#   'Patrick Parker',
#   'zsmith@example.org',
#   '53539 Tony Common Suite 202\nBonniehaven, QC L6R 3Y2',
#   'Owensmouth',
#   'Manitoba',
#   'Lesotho',
#   None,
#   None,
#   '2014-08-20',
#   2074,
#   '2022-02-24 04:31:38.757467',
#   '2022-02-24 04:31:38.757468',
#   None),
#  (692,
#   'Laura Cochran',
#   'herbert04@example.org',
#   '930 Samuel Drive\nLake Joseph, NB A6B 6S1',
#   'Claudiaborough',
#   'Saskatchewan',
#   'Grenada',
#   None,
#   None,
#   '1981-11-09',
#   2185,
#   '2022-02-24 04:31:38.758048',
#   '2022-02-24 04:31:38.758049',
#   None),
#  (693,
#   'Maria Crawford',
#   'lhughes@example.com',
#   '726 Melissa Dam\nNew Garychester, BC T3K3N1',
#   'Smithhaven',
#   'Yukon Territory',
#   'Isle of Man',
#   None,
#   None,
#   '2009-07-14',
#   1669,
#   '2022-02-24 04:31:38.758686',
#   '2022-02-24 04:31:38.758687',
#   None),
#  (694,
#   'Desiree Edwards',
#   'matthewthomas@example.org',
#   '6803 Fields Light\nMaryhaven, NU A4P 8P4',
#   'Nortontown',
#   'Prince Edward Island',
#   'Martinique',
#   None,
#   None,
#   '1973-12-30',
#   2199,
#   '2022-02-24 04:31:38.759454',
#   '2022-02-24 04:31:38.759456',
#   None),
#  (695,
#   'Natalie Jones',
#   'ojackson@example.com',
#   '2768 White Wells\nJustinside, NB B1S 7C7',
#   'Port John',
#   'British Columbia',
#   'Chile',
#   None,
#   None,
#   '2016-04-14',
#   1335,
#   '2022-02-24 04:31:38.761079',
#   '2022-02-24 04:31:38.761080',
#   None),
#  (696,
#   'Scott Keller',
#   'mcconnelljose@example.com',
#   '9691 David Mission\nLake Robertshire, SK L2N2A4',
#   'Combsside',
#   'Saskatchewan',
#   'Malawi',
#   None,
#   None,
#   '2016-04-24',
#   2303,
#   '2022-02-24 04:31:38.762897',
#   '2022-02-24 04:31:38.762898',
#   None),
#  (697,
#   'Brandon Montes',
#   'smithnancy@example.org',
#   '17652 Anderson Extensions\nNorth Annmouth, MB M4B3G3',
#   'North Ginastad',
#   'Saskatchewan',
#   'Costa Rica',
#   None,
#   None,
#   '2021-11-06',
#   2132,
#   '2022-02-24 04:31:38.764071',
#   '2022-02-24 04:31:38.764073',
#   None),
#  (698,
#   'Troy Walker',
#   'miranda68@example.net',
#   '741 Calhoun Course Suite 077\nPort Katherine, BC Y2B7H8',
#   'Simmonsport',
#   'Ontario',
#   'Liechtenstein',
#   None,
#   None,
#   '1979-03-02',
#   2000,
#   '2022-02-24 04:31:38.765753',
#   '2022-02-24 04:31:38.765757',
#   None),
#  (699,
#   'Richard Jacobs',
#   'thomasandrew@example.org',
#   '9552 Bush Lodge Suite 166\nStephanietown, ON J5V1M7',
#   'Williamland',
#   'British Columbia',
#   'Lithuania',
#   None,
#   None,
#   '1976-12-25',
#   1546,
#   '2022-02-24 04:31:38.767117',
#   '2022-02-24 04:31:38.767119',
#   None),
#  (700,
#   'Brittany Taylor',
#   'angelamaxwell@example.org',
#   '11635 Sexton Greens Suite 230\nFlynnchester, YT S4T5X2',
#   'South Victoria',
#   'Nunavut',
#   'French Polynesia',
#   None,
#   None,
#   '1975-05-26',
#   2112,
#   '2022-02-24 04:31:38.768583',
#   '2022-02-24 04:31:38.768585',
#   None),
#  (701,
#   'Jeremiah Clayton',
#   'lgrant@example.org',
#   '13669 Wendy Shoal Suite 284\nJosehaven, NS Y6Y 7C9',
#   'Anthonymouth',
#   'Northwest Territories',
#   'Maldives',
#   None,
#   None,
#   '2013-07-02',
#   2078,
#   '2022-02-24 04:31:38.769863',
#   '2022-02-24 04:31:38.769865',
#   None),
#  (702,
#   'Amy Moore',
#   'marilyn65@example.net',
#   '085 Daniel Place\nNelsonview, ON B8Y6N5',
#   'West Edward',
#   'Ontario',
#   'Uganda',
#   None,
#   None,
#   '1997-05-17',
#   2116,
#   '2022-02-24 04:31:38.771374',
#   '2022-02-24 04:31:38.771377',
#   None),
#  (703,
#   'Amanda Villarreal',
#   'justinstone@example.com',
#   '5390 Hinton Ferry\nSierraberg, MB R4V 5B1',
#   'Durhamland',
#   'Ontario',
#   'Chile',
#   None,
#   None,
#   '1972-01-14',
#   1153,
#   '2022-02-24 04:31:38.772986',
#   '2022-02-24 04:31:38.772987',
#   None),
#  (704,
#   'Tracy Williams',
#   'alexandersheena@example.org',
#   '5214 Michael Inlet Suite 666\nMichaelburgh, AB S7Y4K8',
#   'New Daniel',
#   'Nunavut',
#   'Vietnam',
#   None,
#   None,
#   '1990-12-19',
#   2396,
#   '2022-02-24 04:31:38.774329',
#   '2022-02-24 04:31:38.774332',
#   None),
#  (705,
#   'Miguel Hayes',
#   'matthewperez@example.org',
#   '649 Joseph Unions Suite 966\nVincenthaven, PE R6T7E2',
#   'North Kristy',
#   'Nova Scotia',
#   'Uzbekistan',
#   None,
#   None,
#   '1986-08-27',
#   2432,
#   '2022-02-24 04:31:38.775777',
#   '2022-02-24 04:31:38.775779',
#   None),
#  (706,
#   'Erica Hoffman',
#   'rachelcunningham@example.com',
#   '973 Crane Knoll Apt. 322\nRojasmouth, BC J7L8V2',
#   'Simonport',
#   'Nova Scotia',
#   'Cyprus',
#   None,
#   None,
#   '2006-08-17',
#   1135,
#   '2022-02-24 04:31:38.777406',
#   '2022-02-24 04:31:38.777408',
#   None),
#  (707,
#   'Nathan Herrera',
#   'shelbygeorge@example.org',
#   '97251 Lauren Harbor Suite 484\nEast Patrick, ON S3L 4Y7',
#   'Garciabury',
#   'Ontario',
#   'Tonga',
#   None,
#   None,
#   '1982-02-04',
#   2403,
#   '2022-02-24 04:31:38.778990',
#   '2022-02-24 04:31:38.778993',
#   None),
#  (708,
#   'Matthew White',
#   'trevormitchell@example.net',
#   '613 Butler Walks\nSouth Elizabeth, NS L9B 4C9',
#   'Conleyville',
#   'British Columbia',
#   'Chad',
#   None,
#   None,
#   '1984-08-29',
#   1685,
#   '2022-02-24 04:31:38.780495',
#   '2022-02-24 04:31:38.780496',
#   None),
#  (709,
#   'Jason Mitchell',
#   'karenshields@example.net',
#   '081 Ricky Creek\nWest Angelamouth, NS X9S4P4',
#   'Mollyshire',
#   'Nova Scotia',
#   'Sweden',
#   None,
#   None,
#   '1999-09-14',
#   1458,
#   '2022-02-24 04:31:38.781632',
#   '2022-02-24 04:31:38.781633',
#   None),
#  (710,
#   'Megan Chambers',
#   'iquinn@example.net',
#   '389 Abbott Lake Apt. 318\nSuzannechester, MB E5G1G9',
#   'Michealtown',
#   'Newfoundland and Labrador',
#   'Uruguay',
#   None,
#   None,
#   '1993-03-02',
#   1067,
#   '2022-02-24 04:31:38.782756',
#   '2022-02-24 04:31:38.782758',
#   None),
#  (711,
#   'James Waller',
#   'danny89@example.org',
#   '278 Murray Shoal\nTorresville, QC C2N8J6',
#   'West Elizabethbury',
#   'British Columbia',
#   'Denmark',
#   None,
#   None,
#   '2008-09-14',
#   1001,
#   '2022-02-24 04:31:38.784347',
#   '2022-02-24 04:31:38.784350',
#   None),
#  (712,
#   'Anthony Peterson',
#   'xbarker@example.org',
#   '249 Lewis Tunnel\nWest Jonathanview, NS Y2K6J8',
#   'North William',
#   'Manitoba',
#   'Palestinian Territory',
#   None,
#   None,
#   '1973-09-24',
#   1505,
#   '2022-02-24 04:31:38.785965',
#   '2022-02-24 04:31:38.785967',
#   None),
#  (713,
#   'Rachel Fernandez',
#   'catherine42@example.com',
#   '2805 Michelle Route\nCrawfordmouth, NT X3Y 4G7',
#   'South Tami',
#   'Nova Scotia',
#   'Kuwait',
#   None,
#   None,
#   '1989-01-14',
#   1981,
#   '2022-02-24 04:31:38.787082',
#   '2022-02-24 04:31:38.787084',
#   None),
#  (714,
#   'Jenny Norton',
#   'michaeldylan@example.com',
#   '280 Lynn Estates\nLoriville, SK K4S8M5',
#   'Port Sherry',
#   'Saskatchewan',
#   'Timor-Leste',
#   None,
#   None,
#   '1987-02-27',
#   1140,
#   '2022-02-24 04:31:38.788216',
#   '2022-02-24 04:31:38.788217',
#   None),
#  (715,
#   'Mary Allen',
#   'jwatson@example.com',
#   '25925 Mann Corner\nMyerstown, PE K7X5T9',
#   'Richardfurt',
#   'Northwest Territories',
#   'Venezuela',
#   None,
#   None,
#   '2005-04-11',
#   1442,
#   '2022-02-24 04:31:38.789413',
#   '2022-02-24 04:31:38.789415',
#   None),
#  (716,
#   'Diane Ruiz',
#   'ireed@example.net',
#   '32244 Jonathon Isle Suite 658\nMccoyshire, SK H3H8V6',
#   'Sanderstown',
#   'Alberta',
#   'Russian Federation',
#   None,
#   None,
#   '1999-05-07',
#   1197,
#   '2022-02-24 04:31:38.790637',
#   '2022-02-24 04:31:38.790639',
#   None),
#  (717,
#   'Deborah Becker',
#   'nelsoncarl@example.org',
#   '58593 Perry Underpass Apt. 690\nLake Christine, NS X4L 9R3',
#   'Martinezmouth',
#   'Manitoba',
#   'Nauru',
#   None,
#   None,
#   '1993-01-18',
#   1951,
#   '2022-02-24 04:31:38.791893',
#   '2022-02-24 04:31:38.791895',
#   None),
#  (718,
#   'Martin Leblanc',
#   'dcochran@example.net',
#   '462 Johnson Courts\nSouth Paulbury, QC X7X 6A6',
#   'Lake James',
#   'Nova Scotia',
#   'Saint Kitts and Nevis',
#   None,
#   None,
#   '1974-01-13',
#   1629,
#   '2022-02-24 04:31:38.793022',
#   '2022-02-24 04:31:38.793024',
#   None),
#  (719,
#   'Michael Sims',
#   'taylorralph@example.org',
#   '50751 Matthew Garden Suite 934\nFrancoberg, NB N5X 8Y3',
#   'Port Jason',
#   'Nunavut',
#   'Uganda',
#   None,
#   None,
#   '1992-09-18',
#   1208,
#   '2022-02-24 04:31:38.794245',
#   '2022-02-24 04:31:38.794247',
#   None),
#  (720,
#   'Derek Matthews',
#   'xho@example.org',
#   '5097 Gutierrez Plain\nLake Lisatown, NT G9N 4X1',
#   'Millershire',
#   'Northwest Territories',
#   'Paraguay',
#   None,
#   None,
#   '2014-11-09',
#   1466,
#   '2022-02-24 04:31:38.795372',
#   '2022-02-24 04:31:38.795374',
#   None),
#  (721,
#   'Tyrone Price',
#   'fbarry@example.org',
#   '885 Potter Plains\nPhillipsburgh, YT C6Y8R6',
#   'Cynthiaport',
#   'Northwest Territories',
#   'Singapore',
#   None,
#   None,
#   '1991-05-01',
#   2429,
#   '2022-02-24 04:31:38.796499',
#   '2022-02-24 04:31:38.796501',
#   None),
#  (722,
#   'Eric Castro',
#   'ejohnson@example.net',
#   '76716 Antonio Centers\nNorth Paulborough, QC L3Y 5K1',
#   'Kevinmouth',
#   'Yukon Territory',
#   'Liechtenstein',
#   None,
#   None,
#   '1997-01-07',
#   1727,
#   '2022-02-24 04:31:38.797551',
#   '2022-02-24 04:31:38.797553',
#   None),
#  (723,
#   'Yvonne Hodge',
#   'lduncan@example.net',
#   '271 Nicholas Well Suite 479\nPort Thomastown, PE P6C 1T7',
#   'South Spencer',
#   'Alberta',
#   'Aruba',
#   None,
#   None,
#   '1973-08-04',
#   1373,
#   '2022-02-24 04:31:38.798645',
#   '2022-02-24 04:31:38.798647',
#   None),
#  (724,
#   'Jerome Jones',
#   'amunoz@example.net',
#   '0797 Rhodes Passage\nLiuport, NL H3A5E6',
#   'Irwinport',
#   'Ontario',
#   'Tajikistan',
#   None,
#   None,
#   '2010-11-01',
#   1188,
#   '2022-02-24 04:31:38.799798',
#   '2022-02-24 04:31:38.799801',
#   None),
#  (725,
#   'Cynthia Willis',
#   'bradfordkaren@example.com',
#   '76006 Christine Square Suite 170\nCatherineburgh, NB M5Y6P8',
#   'New Samantha',
#   'Northwest Territories',
#   'Gambia',
#   None,
#   None,
#   '1998-03-27',
#   2442,
#   '2022-02-24 04:31:38.801041',
#   '2022-02-24 04:31:38.801043',
#   None),
#  (726,
#   'Isaiah Johnson',
#   'jonathan70@example.net',
#   '555 Smith Land Apt. 347\nPorterside, PE H8A8L6',
#   'Port Cynthia',
#   'Quebec',
#   'Bolivia',
#   None,
#   None,
#   '2007-07-23',
#   2304,
#   '2022-02-24 04:31:38.802244',
#   '2022-02-24 04:31:38.802246',
#   None),
#  (727,
#   'Sara Berger',
#   'richardsjane@example.org',
#   '771 Kevin Pines\nEast James, NU B2V4G4',
#   'Cisnerosborough',
#   'Manitoba',
#   'Russian Federation',
#   None,
#   None,
#   '1971-09-29',
#   1830,
#   '2022-02-24 04:31:38.803549',
#   '2022-02-24 04:31:38.803551',
#   None),
#  (728,
#   'Brad Riley',
#   'kyle04@example.org',
#   '367 Jones Ramp Suite 505\nNorth Shanefort, NU N2B 2M7',
#   'Hullchester',
#   'Prince Edward Island',
#   'Bulgaria',
#   None,
#   None,
#   '2006-11-09',
#   1235,
#   '2022-02-24 04:31:38.804769',
#   '2022-02-24 04:31:38.804771',
#   None),
#  (729,
#   'Christopher Reid',
#   'thenry@example.net',
#   '8801 Knight Stream\nEast Crystalchester, MB V2E 7N9',
#   'Johnsonmouth',
#   'Newfoundland and Labrador',
#   'Cape Verde',
#   None,
#   None,
#   '1995-06-14',
#   1935,
#   '2022-02-24 04:31:38.806012',
#   '2022-02-24 04:31:38.806014',
#   None),
#  (730,
#   'Jodi Kim',
#   'courtneychase@example.com',
#   '35880 Morrison Stream\nNew Michael, ON E7Y 2V8',
#   'Ellisborough',
#   'British Columbia',
#   'Belarus',
#   None,
#   None,
#   '1983-08-26',
#   1314,
#   '2022-02-24 04:31:38.807551',
#   '2022-02-24 04:31:38.807553',
#   None),
#  (731,
#   'Benjamin Reed',
#   'tyoung@example.com',
#   '26159 Smith Drives\nHughesside, NB K5G6K7',
#   'Port Michael',
#   'Nunavut',
#   'Gabon',
#   None,
#   None,
#   '2013-12-23',
#   2382,
#   '2022-02-24 04:31:38.809381',
#   '2022-02-24 04:31:38.809382',
#   None),
#  (732,
#   'Aaron Gill',
#   'ulee@example.org',
#   '898 Crystal Stream\nWest Ronaldstad, NB V7G 7R5',
#   'New Janice',
#   'New Brunswick',
#   'Saint Martin',
#   None,
#   None,
#   '1987-06-28',
#   1322,
#   '2022-02-24 04:31:38.810441',
#   '2022-02-24 04:31:38.810443',
#   None),
#  (733,
#   'Miranda Morrison',
#   'charlescarrillo@example.com',
#   '1989 Melissa Walks\nNorth Donna, NL S1P2B9',
#   'Johnbury',
#   'Northwest Territories',
#   'Congo',
#   None,
#   None,
#   '1970-05-06',
#   1109,
#   '2022-02-24 04:31:38.811594',
#   '2022-02-24 04:31:38.811596',
#   None),
#  (734,
#   'David Spencer',
#   'bcarpenter@example.net',
#   '402 Chang Locks Suite 142\nNew Shanemouth, BC L9T 2J8',
#   'Yatesfurt',
#   'Newfoundland and Labrador',
#   'Pakistan',
#   None,
#   None,
#   '1988-01-20',
#   1867,
#   '2022-02-24 04:31:38.812748',
#   '2022-02-24 04:31:38.812751',
#   None),
#  (735,
#   'Veronica Richmond',
#   'terrellwilliam@example.com',
#   '9165 Ronald Unions Suite 274\nElizabethstad, ON J8A4M4',
#   'Kevinmouth',
#   'Manitoba',
#   'Montserrat',
#   None,
#   None,
#   '1997-03-10',
#   1130,
#   '2022-02-24 04:31:38.813929',
#   '2022-02-24 04:31:38.813931',
#   None),
#  (736,
#   'Edward Peters',
#   'williamdrake@example.net',
#   '407 Jason Knoll\nLake Jenniferburgh, ON Y7S8T3',
#   'Lauraburgh',
#   'Northwest Territories',
#   'Jersey',
#   None,
#   None,
#   '1981-10-04',
#   2226,
#   '2022-02-24 04:31:38.815099',
#   '2022-02-24 04:31:38.815101',
#   None),
#  (737,
#   'Joshua Cabrera',
#   'hroberts@example.org',
#   '1351 Burns Summit Suite 100\nNolanshire, BC Y3L 5J2',
#   'Port Richardtown',
#   'Manitoba',
#   'Central African Republic',
#   None,
#   None,
#   '2013-10-01',
#   1214,
#   '2022-02-24 04:31:38.816295',
#   '2022-02-24 04:31:38.816297',
#   None),
#  (738,
#   'Gregory Garner',
#   'lori30@example.net',
#   '15124 Christopher Ramp\nZacharyshire, BC G7N6G4',
#   'New James',
#   'Saskatchewan',
#   'Romania',
#   None,
#   None,
#   '1998-03-15',
#   1964,
#   '2022-02-24 04:31:38.817096',
#   '2022-02-24 04:31:38.817097',
#   None),
#  (739,
#   'Alan Rogers',
#   'peter93@example.net',
#   '2744 Bryant Shoals\nLake Heatherberg, MB E5M 8K7',
#   'Lake Randyhaven',
#   'Northwest Territories',
#   'American Samoa',
#   None,
#   None,
#   '1986-12-28',
#   2036,
#   '2022-02-24 04:31:38.817781',
#   '2022-02-24 04:31:38.817782',
#   None),
#  (740,
#   'Kimberly Wilcox',
#   'paulcraig@example.net',
#   '4560 Santiago Pike Apt. 621\nEast Benjaminshire, NU G2K2C9',
#   'Lindsaymouth',
#   'Nunavut',
#   'Cyprus',
#   None,
#   None,
#   '1992-04-16',
#   1730,
#   '2022-02-24 04:31:38.818571',
#   '2022-02-24 04:31:38.818573',
#   None),
#  (741,
#   'Tonya Higgins',
#   'jonesandrea@example.com',
#   '54775 Bethany Point Suite 247\nJoshuabury, NB B1Y 6Y6',
#   'Lake Laura',
#   'Newfoundland and Labrador',
#   'Morocco',
#   None,
#   None,
#   '1978-07-10',
#   1151,
#   '2022-02-24 04:31:38.819232',
#   '2022-02-24 04:31:38.819233',
#   None),
#  (742,
#   'Shelly Wilson',
#   'jamiegutierrez@example.org',
#   '29283 Mcclain Ferry\nWest Scottmouth, NU M3S 4V6',
#   'North Angelamouth',
#   'Alberta',
#   'Korea',
#   None,
#   None,
#   '2002-04-08',
#   2268,
#   '2022-02-24 04:31:38.819958',
#   '2022-02-24 04:31:38.819959',
#   None),
#  (743,
#   'John Ware',
#   'yedwards@example.com',
#   '2908 Cox Common Apt. 746\nPort Krista, NL B1S5S3',
#   'Lake Joshuaberg',
#   'Nova Scotia',
#   'Antarctica (the territory South of 60 deg S)',
#   None,
#   None,
#   '1987-06-10',
#   2182,
#   '2022-02-24 04:31:38.820658',
#   '2022-02-24 04:31:38.820659',
#   None),
#  (744,
#   'James Baxter',
#   'atkinsonjoseph@example.net',
#   '90767 Larson Plains Suite 054\nJeffreymouth, BC A7Y 5B8',
#   'Lake Kimburgh',
#   'Northwest Territories',
#   'Luxembourg',
#   None,
#   None,
#   '2020-04-09',
#   1899,
#   '2022-02-24 04:31:38.821409',
#   '2022-02-24 04:31:38.821410',
#   None),
#  (745,
#   'Stephanie Small',
#   'james46@example.org',
#   '990 Craig Pine\nSouth James, NS N7G 1P5',
#   'Port Amberfort',
#   'British Columbia',
#   'Mongolia',
#   None,
#   None,
#   '2015-07-07',
#   1483,
#   '2022-02-24 04:31:38.822247',
#   '2022-02-24 04:31:38.822249',
#   None),
#  (746,
#   'Kevin Barber',
#   'ohunter@example.net',
#   '687 Murphy Tunnel\nNorth Soniafurt, NU R1R1G5',
#   'Allenview',
#   'Alberta',
#   'Netherlands Antilles',
#   None,
#   None,
#   '2017-08-10',
#   2340,
#   '2022-02-24 04:31:38.823008',
#   '2022-02-24 04:31:38.823009',
#   None),
#  (747,
#   'Erin Johnson',
#   'brooke34@example.net',
#   '806 Rhodes Lake\nLake Geoffreyport, BC K5B6A9',
#   'West Tiffany',
#   'Saskatchewan',
#   'Northern Mariana Islands',
#   None,
#   None,
#   '1998-11-23',
#   1736,
#   '2022-02-24 04:31:38.823671',
#   '2022-02-24 04:31:38.823673',
#   None),
#  (748,
#   'Daniel Gay',
#   'meltonjessica@example.net',
#   '3619 Miranda Glen Apt. 025\nFreemanmouth, MB V7S9M9',
#   'New John',
#   'Quebec',
#   'Mayotte',
#   None,
#   None,
#   '1986-12-01',
#   2386,
#   '2022-02-24 04:31:38.824390',
#   '2022-02-24 04:31:38.824391',
#   None),
#  (749,
#   'Charles Jones',
#   'hector57@example.com',
#   '2132 Jason Crescent Suite 553\nErinmouth, NT N8V5J6',
#   'Holdenmouth',
#   'Newfoundland and Labrador',
#   'Comoros',
#   None,
#   None,
#   '1987-12-12',
#   2298,
#   '2022-02-24 04:31:38.825177',
#   '2022-02-24 04:31:38.825178',
#   None),
#  (750,
#   'Mario Moon',
#   'mayoterri@example.net',
#   '939 Fischer Manor\nMarthahaven, ON S7P2S4',
#   'Lake Antonioland',
#   'Yukon Territory',
#   'Canada',
#   None,
#   None,
#   '2009-06-12',
#   1916,
#   '2022-02-24 04:31:38.826048',
#   '2022-02-24 04:31:38.826050',
#   None),
#  (751,
#   'Jennifer Saunders',
#   'lauradavis@example.net',
#   '775 Mclean Springs Suite 120\nLake Daniel, NT H5M 8X3',
#   'North Amy',
#   'Manitoba',
#   'Trinidad and Tobago',
#   None,
#   None,
#   '2011-07-10',
#   1052,
#   '2022-02-24 04:31:38.826807',
#   '2022-02-24 04:31:38.826808',
#   None),
#  (752,
#   'Brian Brewer',
#   'trobinson@example.com',
#   '38361 Green Grove Suite 792\nPort Nicole, AB R7N4G8',
#   'Sanderston',
#   'Nova Scotia',
#   'Sri Lanka',
#   None,
#   None,
#   '2003-07-26',
#   1014,
#   '2022-02-24 04:31:38.827527',
#   '2022-02-24 04:31:38.827528',
#   None),
#  (753,
#   'Robyn Roberts',
#   'keithchaney@example.org',
#   '9976 Bonilla View\nGrahamview, NL V1S 5N6',
#   'Leehaven',
#   'Newfoundland and Labrador',
#   'Ecuador',
#   None,
#   None,
#   '2000-05-16',
#   1025,
#   '2022-02-24 04:31:38.828241',
#   '2022-02-24 04:31:38.828242',
#   None),
#  (754,
#   'Timothy Taylor',
#   'vbrooks@example.net',
#   '443 Tiffany Vista Suite 592\nHughesshire, NB H9N1K3',
#   'New Kimberlychester',
#   'Nova Scotia',
#   'United States of America',
#   None,
#   None,
#   '2011-03-23',
#   1439,
#   '2022-02-24 04:31:38.829038',
#   '2022-02-24 04:31:38.829040',
#   None),
#  (755,
#   'Joshua Cox',
#   'smallleslie@example.com',
#   '726 Stephanie Ramp\nEast Courtney, MB Y5A 9G8',
#   'North Hannahside',
#   'Nunavut',
#   'Serbia',
#   None,
#   None,
#   '2018-09-28',
#   1177,
#   '2022-02-24 04:31:38.829713',
#   '2022-02-24 04:31:38.829714',
#   None),
#  (756,
#   'Christian Franklin',
#   'mwright@example.net',
#   '1702 Gibson Throughway Apt. 489\nAllisonborough, NS L2L6J2',
#   'Georgefurt',
#   'Manitoba',
#   'South Africa',
#   None,
#   None,
#   '2021-08-04',
#   1228,
#   '2022-02-24 04:31:38.830373',
#   '2022-02-24 04:31:38.830374',
#   None),
#  (757,
#   'Wayne Reed',
#   'patrickcain@example.com',
#   '5909 Lewis Circles\nMarcusside, NU B9J2S4',
#   'South Logan',
#   'Saskatchewan',
#   'Portugal',
#   None,
#   None,
#   '1981-05-14',
#   2201,
#   '2022-02-24 04:31:38.831018',
#   '2022-02-24 04:31:38.831019',
#   None),
#  (758,
#   'Derrick Miller',
#   'riverajoyce@example.org',
#   '230 Jennifer Isle\nCunninghamville, NU M9J9S2',
#   'Lake Meganshire',
#   'Saskatchewan',
#   'Liechtenstein',
#   None,
#   None,
#   '1998-12-22',
#   2262,
#   '2022-02-24 04:31:38.831687',
#   '2022-02-24 04:31:38.831688',
#   None),
#  (759,
#   'Charles Shepherd',
#   'rhurley@example.org',
#   '203 Fisher Trafficway Suite 301\nLake Adam, AB K7A 6G8',
#   'Evansstad',
#   'Nova Scotia',
#   'Mauritius',
#   None,
#   None,
#   '1996-11-06',
#   2244,
#   '2022-02-24 04:31:38.832347',
#   '2022-02-24 04:31:38.832348',
#   None),
#  (760,
#   'Courtney Montgomery',
#   'smitheric@example.net',
#   '30573 Ryan Mount Apt. 865\nJennifermouth, NU J3P2B1',
#   'North Jacqueline',
#   'New Brunswick',
#   'Mexico',
#   None,
#   None,
#   '1991-09-04',
#   1303,
#   '2022-02-24 04:31:38.832998',
#   '2022-02-24 04:31:38.832999',
#   None),
#  (761,
#   'Keith Gutierrez',
#   'cunninghamjames@example.com',
#   '18425 Sandra Gardens Suite 656\nNew Shawn, BC E2E 6T1',
#   'New Edwinfort',
#   'Yukon Territory',
#   'Micronesia',
#   None,
#   None,
#   '1994-07-14',
#   1925,
#   '2022-02-24 04:31:38.833667',
#   '2022-02-24 04:31:38.833668',
#   None),
#  (762,
#   'Joseph Davis',
#   'victor45@example.org',
#   '988 James Shores\nLake Dennisview, AB T8S 1X9',
#   'New Andrew',
#   'Alberta',
#   'Bangladesh',
#   None,
#   None,
#   '2019-06-19',
#   1649,
#   '2022-02-24 04:31:38.834215',
#   '2022-02-24 04:31:38.834216',
#   None),
#  (763,
#   'Kimberly Jensen',
#   'joy31@example.com',
#   '6403 Kelly Stream\nMichaelshire, NL X2N 4A9',
#   'Hillmouth',
#   'Prince Edward Island',
#   'San Marino',
#   None,
#   None,
#   '1997-03-23',
#   1296,
#   '2022-02-24 04:31:38.834814',
#   '2022-02-24 04:31:38.834815',
#   None),
#  (764,
#   'Douglas Davis',
#   'vlong@example.com',
#   '806 Karen Dale Suite 578\nElizabethshire, AB A9A2K9',
#   'Boydberg',
#   'Northwest Territories',
#   'Somalia',
#   None,
#   None,
#   '1987-12-30',
#   1138,
#   '2022-02-24 04:31:38.835439',
#   '2022-02-24 04:31:38.835440',
#   None),
#  (765,
#   'Jennifer Johnson',
#   'ubell@example.net',
#   '64510 Jennifer Valley\nHernandezton, NL R8S6X1',
#   'Alejandraport',
#   'Ontario',
#   'Saudi Arabia',
#   None,
#   None,
#   '2002-05-30',
#   1671,
#   '2022-02-24 04:31:38.836051',
#   '2022-02-24 04:31:38.836052',
#   None),
#  (766,
#   'Karl Everett',
#   'chelseasmith@example.com',
#   '05227 Perkins Turnpike\nSouth Sarahtown, NT N3A 7Y3',
#   'New Whitneybury',
#   'Nunavut',
#   'Ethiopia',
#   None,
#   None,
#   '2004-10-10',
#   2477,
#   '2022-02-24 04:31:38.836732',
#   '2022-02-24 04:31:38.836733',
#   None),
#  (767,
#   'Erin Smith',
#   'chrisdougherty@example.net',
#   '349 Harrell Ports Apt. 341\nNorth Monica, QC M1T 6P9',
#   'Kevinton',
#   'British Columbia',
#   'Australia',
#   None,
#   None,
#   '1975-12-30',
#   1431,
#   '2022-02-24 04:31:38.837419',
#   '2022-02-24 04:31:38.837420',
#   None),
#  (768,
#   'David Reed',
#   'salasaaron@example.net',
#   '39511 William River Suite 593\nEast Lauren, ON L1Y 3B4',
#   'Tammyborough',
#   'Quebec',
#   'Malaysia',
#   None,
#   None,
#   '2005-02-02',
#   1922,
#   '2022-02-24 04:31:38.838084',
#   '2022-02-24 04:31:38.838085',
#   None),
#  (769,
#   'Terri Huffman',
#   'lejennifer@example.com',
#   '274 Bailey Rapid Suite 198\nTiffanyborough, YT E6Y5K9',
#   'Port William',
#   'Saskatchewan',
#   'Greece',
#   None,
#   None,
#   '1984-07-23',
#   1984,
#   '2022-02-24 04:31:38.838770',
#   '2022-02-24 04:31:38.838771',
#   None),
#  (770,
#   'Eric Watson',
#   'urobinson@example.org',
#   '470 Marquez Stream Suite 719\nJuliahaven, PE M1N5S9',
#   'West Dianeburgh',
#   'British Columbia',
#   'Solomon Islands',
#   None,
#   None,
#   '2008-06-06',
#   1228,
#   '2022-02-24 04:31:38.839451',
#   '2022-02-24 04:31:38.839453',
#   None),
#  (771,
#   'Krista Stewart',
#   'ashleyrice@example.com',
#   '6272 Erin Dam Suite 481\nDalefort, NT X2S5E6',
#   'South Staceyfort',
#   'British Columbia',
#   'Uzbekistan',
#   None,
#   None,
#   '2006-06-17',
#   1912,
#   '2022-02-24 04:31:38.840124',
#   '2022-02-24 04:31:38.840125',
#   None),
#  (772,
#   'Benjamin Weber',
#   'qreynolds@example.org',
#   '3663 Pratt Light\nLake Christopher, QC P7C 2S8',
#   'Lake Michaelview',
#   'Nova Scotia',
#   'Serbia',
#   None,
#   None,
#   '1986-08-03',
#   1904,
#   '2022-02-24 04:31:38.840792',
#   '2022-02-24 04:31:38.840793',
#   None),
#  (773,
#   'Frank Wallace',
#   'laurabarnett@example.org',
#   '2099 Krista Trace\nMayohaven, PE H1R8N5',
#   'East Elizabethfort',
#   'British Columbia',
#   'Iceland',
#   None,
#   None,
#   '1997-06-24',
#   1430,
#   '2022-02-24 04:31:38.841475',
#   '2022-02-24 04:31:38.841476',
#   None),
#  (774,
#   'Jessica Harris',
#   'sarah91@example.org',
#   '2461 Donald Stream\nPort Christopherfurt, NT K8L9G3',
#   'Abigailshire',
#   'Nova Scotia',
#   'Lebanon',
#   None,
#   None,
#   '1971-02-10',
#   1330,
#   '2022-02-24 04:31:38.842029',
#   '2022-02-24 04:31:38.842030',
#   None),
#  (775,
#   'Tracy Aguilar',
#   'simonmichael@example.org',
#   '692 Jeffrey Ferry\nSmithfort, NL C3T 9G1',
#   'Robbinsberg',
#   'British Columbia',
#   'Czech Republic',
#   None,
#   None,
#   '1995-12-08',
#   2463,
#   '2022-02-24 04:31:38.842736',
#   '2022-02-24 04:31:38.842737',
#   None),
#  (776,
#   'Nicole Carney',
#   'kristagross@example.org',
#   '26820 Jones Points Apt. 462\nChristinaville, SK A4B 5J9',
#   'Lake Joseph',
#   'Nova Scotia',
#   'Honduras',
#   None,
#   None,
#   '1993-11-12',
#   1002,
#   '2022-02-24 04:31:38.843419',
#   '2022-02-24 04:31:38.843420',
#   None),
#  (777,
#   'Janice Martin',
#   'taylorturner@example.net',
#   '569 Mackenzie Harbor\nPort Samantha, NT S5X8L5',
#   'Willisfurt',
#   'Ontario',
#   'Costa Rica',
#   None,
#   None,
#   '2014-09-24',
#   2283,
#   '2022-02-24 04:31:38.844073',
#   '2022-02-24 04:31:38.844074',
#   None),
#  (778,
#   'Bruce Martin',
#   'eward@example.com',
#   '529 Rodriguez Corner Apt. 024\nPerezchester, NL Y7Y 4C7',
#   'Robinstad',
#   'Manitoba',
#   'Turks and Caicos Islands',
#   None,
#   None,
#   '1984-12-21',
#   1787,
#   '2022-02-24 04:31:38.844725',
#   '2022-02-24 04:31:38.844726',
#   None),
#  (779,
#   'Matthew Blankenship',
#   'bdominguez@example.net',
#   '22280 Katie Estates Apt. 937\nEast Marybury, QC E7S 4L1',
#   'East Patrickshire',
#   'Quebec',
#   'Philippines',
#   None,
#   None,
#   '1996-10-08',
#   1403,
#   '2022-02-24 04:31:38.845349',
#   '2022-02-24 04:31:38.845350',
#   None),
#  (780,
#   'Shirley Sanders',
#   'lisa45@example.net',
#   '00626 Phillips Via Suite 141\nEast Julie, BC S1H2X5',
#   'Robertchester',
#   'Nunavut',
#   'Slovenia',
#   None,
#   None,
#   '1979-01-04',
#   1168,
#   '2022-02-24 04:31:38.845944',
#   '2022-02-24 04:31:38.845945',
#   None),
#  (781,
#   'Nicholas James',
#   'tracyfisher@example.net',
#   '39267 Erica Lights\nThomasfurt, NU H2S5C9',
#   'South Matthewchester',
#   'Yukon Territory',
#   'Timor-Leste',
#   None,
#   None,
#   '1976-03-23',
#   2062,
#   '2022-02-24 04:31:38.846588',
#   '2022-02-24 04:31:38.846589',
#   None),
#  (782,
#   'Richard Perez',
#   'wbrown@example.net',
#   '93589 Jessica Prairie\nWest Jaime, NL X9J 8N5',
#   'Chaneyview',
#   'Quebec',
#   'Nepal',
#   None,
#   None,
#   '1977-11-27',
#   2246,
#   '2022-02-24 04:31:38.847183',
#   '2022-02-24 04:31:38.847184',
#   None),
#  (783,
#   'Chad Young',
#   'reyesdebbie@example.com',
#   '5706 Jennifer Glens\nDominguezland, YT N3S1A8',
#   'Nicholstown',
#   'Yukon Territory',
#   'Dominica',
#   None,
#   None,
#   '1982-05-17',
#   2408,
#   '2022-02-24 04:31:38.847881',
#   '2022-02-24 04:31:38.847882',
#   None),
#  (784,
#   'John Baker',
#   'xbender@example.com',
#   '9581 Keith Pines Apt. 565\nEdwardtown, AB X5Y5E4',
#   'East Brianbury',
#   'Yukon Territory',
#   'Bouvet Island (Bouvetoya)',
#   None,
#   None,
#   '1978-01-26',
#   1288,
#   '2022-02-24 04:31:38.848488',
#   '2022-02-24 04:31:38.848489',
#   None),
#  (785,
#   'Rachel Caldwell',
#   'shelly62@example.com',
#   '9823 Hannah Fords Apt. 102\nSouth Isaac, SK J9X2J8',
#   'North Williamton',
#   'Prince Edward Island',
#   'Jersey',
#   None,
#   None,
#   '2016-12-23',
#   1939,
#   '2022-02-24 04:31:38.849064',
#   '2022-02-24 04:31:38.849065',
#   None),
#  (786,
#   'Jenna Hayes',
#   'mackamber@example.net',
#   '1534 Steven Alley Suite 117\nLake Kimberlyfort, YT P3S8E1',
#   'West Theresa',
#   'Alberta',
#   'Tonga',
#   None,
#   None,
#   '1992-01-14',
#   1876,
#   '2022-02-24 04:31:38.849726',
#   '2022-02-24 04:31:38.849727',
#   None),
#  (787,
#   'Debbie Barton',
#   'uvalencia@example.net',
#   '2885 Grace Trafficway Apt. 343\nDorisstad, QC X2L9J7',
#   'Thompsonborough',
#   'Yukon Territory',
#   'Georgia',
#   None,
#   None,
#   '1995-02-09',
#   2429,
#   '2022-02-24 04:31:38.850359',
#   '2022-02-24 04:31:38.850360',
#   None),
#  (788,
#   'Rebecca Williams',
#   'gabriel22@example.net',
#   '715 Matthew Green Apt. 215\nPort Patricia, QC L9X6G9',
#   'East Jimmyton',
#   'Alberta',
#   'Malaysia',
#   None,
#   None,
#   '1992-12-27',
#   1294,
#   '2022-02-24 04:31:38.850964',
#   '2022-02-24 04:31:38.850965',
#   None),
#  (789,
#   'Joshua Melendez',
#   'davisapril@example.org',
#   '549 Harvey Greens Apt. 422\nGreenport, YT J7A 5C8',
#   'Masonborough',
#   'Northwest Territories',
#   'Portugal',
#   None,
#   None,
#   '1981-06-02',
#   2351,
#   '2022-02-24 04:31:38.851696',
#   '2022-02-24 04:31:38.851697',
#   None),
#  (790,
#   'Adriana Schultz',
#   'elizabeth59@example.net',
#   '63463 Bean Divide Suite 214\nPort Autumntown, AB T1P8T5',
#   'Fosterberg',
#   'New Brunswick',
#   'Saint Vincent and the Grenadines',
#   None,
#   None,
#   '2000-07-10',
#   1235,
#   '2022-02-24 04:31:38.852343',
#   '2022-02-24 04:31:38.852344',
#   None),
#  (791,
#   'David Romero',
#   'justinfreeman@example.org',
#   '46084 Tina Plaza\nNorth John, AB N1S 9S7',
#   'North William',
#   'Northwest Territories',
#   'Malaysia',
#   None,
#   None,
#   '1993-03-25',
#   2452,
#   '2022-02-24 04:31:38.852983',
#   '2022-02-24 04:31:38.852984',
#   None),
#  (792,
#   'Cesar Freeman',
#   'krista32@example.org',
#   '9326 Cole Isle\nWest Stephaniefort, BC L8X 9C5',
#   'Oliviastad',
#   'Northwest Territories',
#   'Panama',
#   None,
#   None,
#   '2019-09-18',
#   2420,
#   '2022-02-24 04:31:38.853593',
#   '2022-02-24 04:31:38.853594',
#   None),
#  (793,
#   'Brendan Hart',
#   'bridgetmason@example.net',
#   '435 Williams Lights Apt. 436\nSouth Brandonshire, YT L7Y3B9',
#   'Timothyborough',
#   'Alberta',
#   'Niger',
#   None,
#   None,
#   '1970-05-30',
#   2443,
#   '2022-02-24 04:31:38.854257',
#   '2022-02-24 04:31:38.854258',
#   None),
#  (794,
#   'Jennifer Mcfarland',
#   'jmarshall@example.com',
#   '08519 West Forges\nHarrellberg, PE H3E1A9',
#   'North Jasontown',
#   'Prince Edward Island',
#   'Estonia',
#   None,
#   None,
#   '2006-06-30',
#   2299,
#   '2022-02-24 04:31:38.854923',
#   '2022-02-24 04:31:38.854924',
#   None),
#  (795,
#   'Mr. Frederick Gordon',
#   'millererika@example.net',
#   '141 Spencer Wall Suite 326\nWest Elizabeth, BC A8X9E2',
#   'South Christinestad',
#   'Manitoba',
#   'Uganda',
#   None,
#   None,
#   '2016-04-02',
#   1746,
#   '2022-02-24 04:31:38.856106',
#   '2022-02-24 04:31:38.856117',
#   None),
#  (796,
#   'Adrienne Taylor',
#   'nguyenemily@example.com',
#   '5266 Madeline Mission Suite 384\nDavisborough, NL V1A6P4',
#   'Ericside',
#   'British Columbia',
#   'Saint Pierre and Miquelon',
#   None,
#   None,
#   '1977-12-17',
#   1330,
#   '2022-02-24 04:31:38.857387',
#   '2022-02-24 04:31:38.857388',
#   None),
#  (797,
#   'Joseph Hogan',
#   'allisongray@example.net',
#   '479 Chaney Course\nPort Christophermouth, MB L5K4A5',
#   'Matthewmouth',
#   'Nova Scotia',
#   'Myanmar',
#   None,
#   None,
#   '2001-05-15',
#   1629,
#   '2022-02-24 04:31:38.858152',
#   '2022-02-24 04:31:38.858153',
#   None),
#  (798,
#   'Stephanie King',
#   'zhall@example.com',
#   '6448 Lee Glen Suite 841\nPort Christina, NB E6L 5X1',
#   'Washingtonshire',
#   'Ontario',
#   'Oman',
#   None,
#   None,
#   '2005-05-10',
#   2368,
#   '2022-02-24 04:31:38.858893',
#   '2022-02-24 04:31:38.858894',
#   None),
#  (799,
#   'Ms. Barbara Allison MD',
#   'kathrynrichardson@example.net',
#   '6285 Flores Crest\nKennedyfort, BC C1J 1L1',
#   'New Christianland',
#   'Northwest Territories',
#   'Vietnam',
#   None,
#   None,
#   '2001-11-13',
#   2276,
#   '2022-02-24 04:31:38.859723',
#   '2022-02-24 04:31:38.859724',
#   None),
#  (800,
#   'Wayne Smith',
#   'jennapotter@example.net',
#   '4739 Shawn Field Apt. 793\nDoughertyport, NB M4C2H5',
#   'Lake Amandachester',
#   'Alberta',
#   'Liechtenstein',
#   None,
#   None,
#   '1985-03-28',
#   1028,
#   '2022-02-24 04:31:38.860497',
#   '2022-02-24 04:31:38.860498',
#   None),
#  (801,
#   'Chad Hunter',
#   'johnreyes@example.org',
#   '04666 Ayala Circle\nLake Renee, AB T1G5Y7',
#   'Lynnfort',
#   'Manitoba',
#   'Bhutan',
#   None,
#   None,
#   '2004-01-26',
#   2393,
#   '2022-02-24 04:31:38.861212',
#   '2022-02-24 04:31:38.861213',
#   None),
#  (802,
#   'Karen Pittman',
#   'donaldshaw@example.com',
#   '04130 Jason Plains Suite 857\nHuntertown, PE N2N4N2',
#   'Jodyport',
#   'New Brunswick',
#   'Greece',
#   None,
#   None,
#   '1978-12-19',
#   2211,
#   '2022-02-24 04:31:38.862021',
#   '2022-02-24 04:31:38.862022',
#   None),
#  (803,
#   'Phillip Rosales',
#   'njordan@example.com',
#   '040 Martin Forest Apt. 469\nEdwardmouth, PE V3E 1R2',
#   'West Lisaland',
#   'Quebec',
#   'Canada',
#   None,
#   None,
#   '1992-08-27',
#   2466,
#   '2022-02-24 04:31:38.862779',
#   '2022-02-24 04:31:38.862780',
#   None),
#  (804,
#   'Kirk Franco',
#   'howellashley@example.org',
#   '100 James Motorway\nBushberg, SK S8A9C8',
#   'New Lauren',
#   'Alberta',
#   'Switzerland',
#   None,
#   None,
#   '2004-05-26',
#   1415,
#   '2022-02-24 04:31:38.863457',
#   '2022-02-24 04:31:38.863458',
#   None),
#  (805,
#   'Stephanie Cook',
#   'mark77@example.com',
#   '9701 Shelton Views Apt. 362\nPort Rebeccaberg, NL T7B 2E5',
#   'West Jonathanfurt',
#   'Yukon Territory',
#   'Ecuador',
#   None,
#   None,
#   '1981-01-04',
#   1649,
#   '2022-02-24 04:31:38.864078',
#   '2022-02-24 04:31:38.864079',
#   None),
#  (806,
#   'Ashley Ramirez',
#   'rogersmelody@example.com',
#   '7506 Jordan Mill Suite 006\nNew Jeffery, NB G3B 6K9',
#   'South Teresa',
#   'Nova Scotia',
#   'Andorra',
#   None,
#   None,
#   '2020-05-11',
#   1992,
#   '2022-02-24 04:31:38.865081',
#   '2022-02-24 04:31:38.865082',
#   None),
#  (807,
#   'Michael Lindsey',
#   'fosterwayne@example.com',
#   '268 Alan Road\nEast Carol, NL T6G 3P4',
#   'Annetteport',
#   'Yukon Territory',
#   'Turks and Caicos Islands',
#   None,
#   None,
#   '1982-04-08',
#   2316,
#   '2022-02-24 04:31:38.865823',
#   '2022-02-24 04:31:38.865824',
#   None),
#  (808,
#   'Philip Morris',
#   'simscarol@example.org',
#   '73215 Jackson Mount Suite 430\nPort Nina, NL V4X 7H6',
#   'Lake Jamestown',
#   'Nova Scotia',
#   'Mali',
#   None,
#   None,
#   '2014-11-14',
#   1633,
#   '2022-02-24 04:31:38.866587',
#   '2022-02-24 04:31:38.866588',
#   None),
#  (809,
#   'Rebecca Taylor',
#   'michele14@example.org',
#   '27262 Samantha Loaf Suite 724\nAndrewside, MB J2P5Y2',
#   'East Michelle',
#   'Ontario',
#   'Bahrain',
#   None,
#   None,
#   '1981-10-09',
#   1618,
#   '2022-02-24 04:31:38.867220',
#   '2022-02-24 04:31:38.867221',
#   None),
#  (810,
#   'Joy Torres',
#   'dburnett@example.org',
#   '2658 Rhodes Drive Apt. 013\nDonovanton, QC N8P8C3',
#   'Merrittport',
#   'Ontario',
#   'Samoa',
#   None,
#   None,
#   '1978-11-23',
#   1151,
#   '2022-02-24 04:31:38.867942',
#   '2022-02-24 04:31:38.867944',
#   None),
#  (811,
#   'Michael Morris',
#   'zmercado@example.org',
#   '94495 Turner Stravenue\nStoutview, ON A3E6J2',
#   'Port Tyler',
#   'Nunavut',
#   'Sudan',
#   None,
#   None,
#   '1989-11-21',
#   1351,
#   '2022-02-24 04:31:38.868627',
#   '2022-02-24 04:31:38.868628',
#   None),
#  (812,
#   'Jeffrey Hernandez',
#   'jesse26@example.net',
#   '994 Mitchell Centers\nNew Duane, NL Y1S 8G7',
#   'West Tony',
#   'New Brunswick',
#   'New Caledonia',
#   None,
#   None,
#   '1983-04-25',
#   2441,
#   '2022-02-24 04:31:38.869216',
#   '2022-02-24 04:31:38.869217',
#   None),
#  (813,
#   'Heidi Reynolds',
#   'rwolf@example.net',
#   '200 Turner Crossing\nKimview, PE J4M7M3',
#   'Michaelfurt',
#   'New Brunswick',
#   'Swaziland',
#   None,
#   None,
#   '1991-02-26',
#   1674,
#   '2022-02-24 04:31:38.869888',
#   '2022-02-24 04:31:38.869889',
#   None),
#  (814,
#   'Courtney Green',
#   'qrivas@example.com',
#   '79563 Rachael Greens\nPort Jessica, NU V1C 5T5',
#   'North Leslie',
#   'Ontario',
#   'Cape Verde',
#   None,
#   None,
#   '1998-05-18',
#   1089,
#   '2022-02-24 04:31:38.870494',
#   '2022-02-24 04:31:38.870495',
#   None),
#  (815,
#   'Linda Burke',
#   'dsavage@example.com',
#   '7931 Kristin Ford Suite 337\nLake Mandy, MB C6G1S1',
#   'Lake Robertmouth',
#   'Yukon Territory',
#   'Tajikistan',
#   None,
#   None,
#   '1977-03-10',
#   1188,
#   '2022-02-24 04:31:38.871104',
#   '2022-02-24 04:31:38.871105',
#   None),
#  (816,
#   'Tanner Brown',
#   'olivia65@example.net',
#   '36756 Christian Views\nKingberg, PE P1X2Y8',
#   'West Bradleyview',
#   'Manitoba',
#   'Barbados',
#   None,
#   None,
#   '1980-03-06',
#   2182,
#   '2022-02-24 04:31:38.871723',
#   '2022-02-24 04:31:38.871724',
#   None),
#  (817,
#   'Mr. Jason Frost',
#   'juliasmith@example.net',
#   '9267 Jacqueline Walk Apt. 416\nWest Kristinaland, AB T9P 1Y3',
#   'Karaburgh',
#   'Saskatchewan',
#   'Malaysia',
#   None,
#   None,
#   '2020-04-16',
#   1990,
#   '2022-02-24 04:31:38.872418',
#   '2022-02-24 04:31:38.872419',
#   None),
#  (818,
#   'Bonnie Gentry',
#   'wdunn@example.com',
#   '9687 Rita Ridge\nBenjaminport, QC M9B 9T7',
#   'Lake Johnton',
#   'Quebec',
#   'Italy',
#   None,
#   None,
#   '2020-09-04',
#   1794,
#   '2022-02-24 04:31:38.873000',
#   '2022-02-24 04:31:38.873001',
#   None),
#  (819,
#   'Billy Murray',
#   'fowlersandra@example.net',
#   '983 William Mountains\nHeatherport, MB T7J 6N2',
#   'West Kaylaberg',
#   'Quebec',
#   'Falkland Islands (Malvinas)',
#   None,
#   None,
#   '1976-09-05',
#   1367,
#   '2022-02-24 04:31:38.873648',
#   '2022-02-24 04:31:38.873649',
#   None),
#  (820,
#   'Christopher Sherman',
#   'benderjimmy@example.org',
#   '58671 Brittany Road Apt. 518\nHerreraview, YT J1H2P2',
#   'Sotoshire',
#   'Newfoundland and Labrador',
#   'Sweden',
#   None,
#   None,
#   '1972-05-18',
#   1596,
#   '2022-02-24 04:31:38.874468',
#   '2022-02-24 04:31:38.874473',
#   None),
#  (821,
#   'Benjamin Collier',
#   'wyattjessica@example.net',
#   '094 Cole Village\nJosephton, BC H9R1E7',
#   'New Christinashire',
#   'Northwest Territories',
#   'Puerto Rico',
#   None,
#   None,
#   '2021-02-07',
#   1385,
#   '2022-02-24 04:31:38.875581',
#   '2022-02-24 04:31:38.875582',
#   None),
#  (822,
#   'Louis Castro',
#   'mcculloughtaylor@example.org',
#   '735 Michael Lock\nSmithbury, QC A4L 8E8',
#   'Grantborough',
#   'Northwest Territories',
#   'Macao',
#   None,
#   None,
#   '2007-01-14',
#   1941,
#   '2022-02-24 04:31:38.876291',
#   '2022-02-24 04:31:38.876292',
#   None),
#  (823,
#   'Tammy Cline',
#   'murphyantonio@example.net',
#   '4924 Morris Locks Apt. 233\nWilliambury, NB N5S4K4',
#   'Ramirezport',
#   'Saskatchewan',
#   'Uganda',
#   None,
#   None,
#   '1981-06-29',
#   1168,
#   '2022-02-24 04:31:38.877078',
#   '2022-02-24 04:31:38.877080',
#   None),
#  (824,
#   'Steven Daniels',
#   'justinpowell@example.net',
#   '092 Jason Manors\nGrossport, YT G9J 5B3',
#   'West Tyler',
#   'Nunavut',
#   'Israel',
#   None,
#   None,
#   '1971-08-05',
#   1610,
#   '2022-02-24 04:31:38.877805',
#   '2022-02-24 04:31:38.877806',
#   None),
#  (825,
#   'Jordan Cohen',
#   'graypaul@example.com',
#   '02965 Davis Lane Suite 423\nSouth Phillip, YT E3B4A3',
#   'Richardsburgh',
#   'Ontario',
#   'Iran',
#   None,
#   None,
#   '1986-04-01',
#   2258,
#   '2022-02-24 04:31:38.878579',
#   '2022-02-24 04:31:38.878580',
#   None),
#  (826,
#   'Brian Hartman',
#   'josephrobinson@example.com',
#   '056 Moore Center\nMichellechester, SK N9J8H8',
#   'Andersonchester',
#   'Northwest Territories',
#   'Cook Islands',
#   None,
#   None,
#   '2000-02-01',
#   1843,
#   '2022-02-24 04:31:38.879265',
#   '2022-02-24 04:31:38.879266',
#   None),
#  (827,
#   'Pamela Anderson',
#   'jsullivan@example.net',
#   '53988 Spencer Hill\nSouth Raymond, NU H2Y8V3',
#   'New Angelicafort',
#   'Quebec',
#   'Heard Island and McDonald Islands',
#   None,
#   None,
#   '1986-12-08',
#   1958,
#   '2022-02-24 04:31:38.879931',
#   '2022-02-24 04:31:38.879933',
#   None),
#  (828,
#   'Barbara Murphy',
#   'jonespatricia@example.net',
#   '3060 Hurst Terrace\nCraighaven, NT L7A5P5',
#   'Bryantshire',
#   'Newfoundland and Labrador',
#   'United States of America',
#   None,
#   None,
#   '1987-06-17',
#   1811,
#   '2022-02-24 04:31:38.880654',
#   '2022-02-24 04:31:38.880655',
#   None),
#  (829,
#   'Amanda Ruiz',
#   'rivasrandy@example.org',
#   '22506 Jenkins Drive\nHamptontown, NT P8H 8M6',
#   'Port Paulberg',
#   'New Brunswick',
#   'France',
#   None,
#   None,
#   '1991-05-06',
#   2235,
#   '2022-02-24 04:31:38.881349',
#   '2022-02-24 04:31:38.881350',
#   None),
#  (830,
#   'Lori Stein',
#   'tiffany39@example.com',
#   '635 Carlson Key\nDustinshire, AB R3S 8K7',
#   'Lake Daniel',
#   'British Columbia',
#   'Algeria',
#   None,
#   None,
#   '1996-05-15',
#   1213,
#   '2022-02-24 04:31:38.881946',
#   '2022-02-24 04:31:38.881947',
#   None),
#  (831,
#   'Christine Moore',
#   'jamesmegan@example.net',
#   '28912 Ashley Mall\nHeathermouth, MB B4R 3L2',
#   'West Marybury',
#   'New Brunswick',
#   'Sao Tome and Principe',
#   None,
#   None,
#   '2010-02-02',
#   1229,
#   '2022-02-24 04:31:38.882607',
#   '2022-02-24 04:31:38.882608',
# ...
#   'Nunavut',
#   'Papua New Guinea',
#   None,
#   None,
#   '1994-03-08',
#   1882,
#   '2022-02-24 04:31:38.966912',
#   '2022-02-24 04:31:38.966913',
#   None),
#  (957,
#   'Shaun Howe',
#   'johnny31@example.net',
#   '2953 Thompson Throughway\nNew Eddie, BC H3H8M9',
#   'Floresport',
#   'Nova Scotia',
#   'Serbia',
#   None,
#   None,
#   '2019-04-29',
#   1528,
#   '2022-02-24 04:31:38.967527',
#   '2022-02-24 04:31:38.967528',
#   None),
#  (958,
#   'Christopher Price',
#   'smithmary@example.org',
#   '3773 Kevin Point\nLisabury, NT E1V8T7',
#   'Carolinechester',
#   'Nunavut',
#   'Northern Mariana Islands',
#   None,
#   None,
#   '2004-06-08',
#   1882,
#   '2022-02-24 04:31:38.968139',
#   '2022-02-24 04:31:38.968140',
#   None),
#  (959,
#   'Kelly Spencer',
#   'angelaho@example.com',
#   '01477 Mckenzie Parkways Apt. 292\nWilliamsshire, MB X9X6N8',
#   'Lake Michaelhaven',
#   'Manitoba',
#   'Morocco',
#   None,
#   None,
#   '2003-10-23',
#   2292,
#   '2022-02-24 04:31:38.968826',
#   '2022-02-24 04:31:38.968827',
#   None),
#  (960,
#   'Claudia Montgomery',
#   'jacksonronald@example.net',
#   '37395 Acosta Key Apt. 122\nCalvinton, NU P7L 8E6',
#   'South Stephanie',
#   'Northwest Territories',
#   'Portugal',
#   None,
#   None,
#   '2008-07-19',
#   1124,
#   '2022-02-24 04:31:38.969502',
#   '2022-02-24 04:31:38.969503',
#   None),
#  (961,
#   'Alejandro Griffin',
#   'stephen02@example.org',
#   '121 Pratt Mission Apt. 281\nLangmouth, AB P6S 7E6',
#   'Nicoleview',
#   'Ontario',
#   'Norway',
#   None,
#   None,
#   '1986-04-28',
#   1957,
#   '2022-02-24 04:31:38.970099',
#   '2022-02-24 04:31:38.970100',
#   None),
#  (962,
#   'Claudia Cline',
#   'eholt@example.net',
#   '28180 Higgins Fork\nLewiston, NT R5A 5K6',
#   'Tarachester',
#   'Ontario',
#   'Philippines',
#   None,
#   None,
#   '1980-11-04',
#   1127,
#   '2022-02-24 04:31:38.970812',
#   '2022-02-24 04:31:38.970813',
#   None),
#  (963,
#   'Donald Clark',
#   'garretterik@example.org',
#   '8290 Caldwell Cape\nClarkhaven, NS K1E7A4',
#   'South Christina',
#   'Quebec',
#   'Palestinian Territory',
#   None,
#   None,
#   '1974-08-11',
#   1889,
#   '2022-02-24 04:31:38.971521',
#   '2022-02-24 04:31:38.971522',
#   None),
#  (964,
#   'Justin Davis',
#   'brightbrittany@example.com',
#   '214 Joseph Meadows\nWest Robert, NU G8R 1J4',
#   'Lake Grace',
#   'Yukon Territory',
#   'Taiwan',
#   None,
#   None,
#   '2016-02-14',
#   1565,
#   '2022-02-24 04:31:38.972138',
#   '2022-02-24 04:31:38.972139',
#   None),
#  (965,
#   'Rhonda Kim',
#   'reedshawn@example.net',
#   '0674 Wanda Forge Suite 616\nVirginiaborough, AB C2V 3R4',
#   'Millershire',
#   'Quebec',
#   'Cameroon',
#   None,
#   None,
#   '2011-02-27',
#   1283,
#   '2022-02-24 04:31:38.972823',
#   '2022-02-24 04:31:38.972824',
#   None),
#  (966,
#   'Randy Gaines',
#   'lchandler@example.org',
#   '9782 Stacy Inlet\nNorth Bonnie, NS Y6A 3C2',
#   'Huertaberg',
#   'Prince Edward Island',
#   'Cocos (Keeling) Islands',
#   None,
#   None,
#   '1975-03-30',
#   1687,
#   '2022-02-24 04:31:38.973485',
#   '2022-02-24 04:31:38.973486',
#   None),
#  (967,
#   'Tommy Weaver',
#   'phillipsannette@example.net',
#   '2427 Timothy Plaza\nLake Brandonburgh, NT A8N 8L1',
#   'North Gregory',
#   'Newfoundland and Labrador',
#   'Holy See (Vatican City State)',
#   None,
#   None,
#   '2021-03-23',
#   2124,
#   '2022-02-24 04:31:38.974108',
#   '2022-02-24 04:31:38.974109',
#   None),
#  (968,
#   'Ryan Bell',
#   'jennifer43@example.com',
#   '352 Richard Flat\nChristophermouth, BC P5S 9A9',
#   'Lake Theresaport',
#   'Saskatchewan',
#   'Lesotho',
#   None,
#   None,
#   '1992-08-21',
#   1621,
#   '2022-02-24 04:31:38.974677',
#   '2022-02-24 04:31:38.974678',
#   None),
#  (969,
#   'Kevin Nguyen',
#   'mwalton@example.net',
#   '0958 Chavez Knolls\nGriffinhaven, QC P3M 6J7',
#   'South April',
#   'Newfoundland and Labrador',
#   'Tajikistan',
#   None,
#   None,
#   '2008-12-25',
#   1512,
#   '2022-02-24 04:31:38.975284',
#   '2022-02-24 04:31:38.975285',
#   None),
#  (970,
#   'Bethany Hines',
#   'davidjones@example.org',
#   '0018 Jaclyn Port\nLake Brittanyborough, YT T3M 5X1',
#   'Ballland',
#   'New Brunswick',
#   'Cook Islands',
#   None,
#   None,
#   '1981-01-17',
#   2055,
#   '2022-02-24 04:31:38.975972',
#   '2022-02-24 04:31:38.975973',
#   None),
#  (971,
#   'Jamie Payne',
#   'allenwilliam@example.org',
#   '21838 Kendra Crest Suite 487\nPayneville, NU N1J2V4',
#   'Port Tammyville',
#   'Ontario',
#   'Oman',
#   None,
#   None,
#   '1972-09-22',
#   1856,
#   '2022-02-24 04:31:38.976665',
#   '2022-02-24 04:31:38.976666',
#   None),
#  (972,
#   'David Sullivan',
#   'gabriella14@example.org',
#   '4127 Harvey Hills Apt. 157\nEast Thomas, ON T5T 8Y5',
#   'Cummingsshire',
#   'Alberta',
#   'Czech Republic',
#   None,
#   None,
#   '2000-03-23',
#   1458,
#   '2022-02-24 04:31:38.977273',
#   '2022-02-24 04:31:38.977274',
#   None),
#  (973,
#   'Mary Graves',
#   'petersharp@example.org',
#   '57333 Malone Overpass\nSouth Stephanieberg, AB N7A 3Y3',
#   'South Joseph',
#   'Northwest Territories',
#   'Pakistan',
#   None,
#   None,
#   '1999-02-10',
#   2265,
#   '2022-02-24 04:31:38.977970',
#   '2022-02-24 04:31:38.977971',
#   None),
#  (974,
#   'Katherine Smith',
#   'tatethomas@example.com',
#   '9318 Daniel Garden\nSouth Jamiechester, PE L9Y8P4',
#   'South Anthonyton',
#   'Saskatchewan',
#   'Heard Island and McDonald Islands',
#   None,
#   None,
#   '2005-05-14',
#   2109,
#   '2022-02-24 04:31:38.978719',
#   '2022-02-24 04:31:38.978720',
#   None),
#  (975,
#   'Christine Goodman',
#   'paulfox@example.org',
#   '54747 Stacy Streets Suite 376\nRichardsonview, NS R4P5A8',
#   'Lake Adrienneview',
#   'Alberta',
#   'Korea',
#   None,
#   None,
#   '1970-06-12',
#   1085,
#   '2022-02-24 04:31:38.979432',
#   '2022-02-24 04:31:38.979433',
#   None),
#  (976,
#   'Pamela Hodges',
#   'sean53@example.net',
#   '76023 Hines Throughway\nSouth Patrickberg, NS Y5V1B9',
#   'South Alexandrabury',
#   'Saskatchewan',
#   'Germany',
#   None,
#   None,
#   '1990-12-21',
#   1726,
#   '2022-02-24 04:31:38.980012',
#   '2022-02-24 04:31:38.980013',
#   None),
#  (977,
#   'Wendy Reyes',
#   'holly42@example.net',
#   '40898 George Vista Suite 810\nWilliamberg, AB J5E 1L8',
#   'East Joseph',
#   'Manitoba',
#   'South Africa',
#   None,
#   None,
#   '2017-05-07',
#   1072,
#   '2022-02-24 04:31:38.980590',
#   '2022-02-24 04:31:38.980591',
#   None),
#  (978,
#   'Michele Ward',
#   'russellcruz@example.net',
#   '2981 Wolfe Summit Apt. 736\nLake Joshua, SK V8G4C9',
#   'Angelicamouth',
#   'Newfoundland and Labrador',
#   'Bouvet Island (Bouvetoya)',
#   None,
#   None,
#   '2006-07-15',
#   1418,
#   '2022-02-24 04:31:38.981244',
#   '2022-02-24 04:31:38.981245',
#   None),
#  (979,
#   'Deborah Phillips',
#   'karen66@example.net',
#   '7542 Jamie Junctions\nGreenmouth, YT L5X 6X3',
#   'Ramirezport',
#   'Quebec',
#   'Ecuador',
#   None,
#   None,
#   '1987-04-13',
#   2168,
#   '2022-02-24 04:31:38.981862',
#   '2022-02-24 04:31:38.981863',
#   None),
#  (980,
#   'Keith Smith',
#   'perkinsyolanda@example.com',
#   '400 Kelly Land Apt. 649\nCharlesstad, BC L5T4N5',
#   'West Dawnstad',
#   'Northwest Territories',
#   'Belgium',
#   None,
#   None,
#   '1976-10-25',
#   1797,
#   '2022-02-24 04:31:38.982532',
#   '2022-02-24 04:31:38.982533',
#   None),
#  (981,
#   'Zachary Frye',
#   'christina11@example.com',
#   '7748 Johnson Mill\nNorth Karen, PE A8C3A9',
#   'East Daniel',
#   'Ontario',
#   'Guatemala',
#   None,
#   None,
#   '2003-12-17',
#   2076,
#   '2022-02-24 04:31:38.983099',
#   '2022-02-24 04:31:38.983100',
#   None),
#  (982,
#   'Derrick Santos',
#   'angela69@example.org',
#   '46446 Rebecca Landing Suite 057\nScottfurt, NT A8J 2E6',
#   'Port Sarah',
#   'Northwest Territories',
#   'Honduras',
#   None,
#   None,
#   '1985-12-08',
#   1772,
#   '2022-02-24 04:31:38.983684',
#   '2022-02-24 04:31:38.983685',
#   None),
#  (983,
#   'Mrs. Lauren Nguyen',
#   'frank52@example.org',
#   '50549 Moyer Groves Apt. 259\nSouth Allenberg, AB V9N3S4',
#   'Bethmouth',
#   'Alberta',
#   'Estonia',
#   None,
#   None,
#   '1990-06-12',
#   1703,
#   '2022-02-24 04:31:38.984291',
#   '2022-02-24 04:31:38.984292',
#   None),
#  (984,
#   'John Cortez',
#   'david72@example.org',
#   '41465 Preston Flat\nMichellemouth, QC Y5Y6L4',
#   'East Thomas',
#   'New Brunswick',
#   'Equatorial Guinea',
#   None,
#   None,
#   '1978-10-24',
#   1290,
#   '2022-02-24 04:31:38.984885',
#   '2022-02-24 04:31:38.984886',
#   None),
#  (985,
#   'Kendra Gilbert',
#   'zjones@example.org',
#   '635 Kirk Overpass Suite 090\nNorth Christopherhaven, NT Y9X2K1',
#   'West Davidstad',
#   'New Brunswick',
#   'Burkina Faso',
#   None,
#   None,
#   '1979-08-03',
#   1566,
#   '2022-02-24 04:31:38.985498',
#   '2022-02-24 04:31:38.985499',
#   None),
#  (986,
#   'Jeffery Vargas',
#   'hilljohn@example.net',
#   '804 Kathryn Brook Suite 598\nNorth Christopherhaven, QC T4L4G3',
#   'East Anthony',
#   'Alberta',
#   'Czech Republic',
#   None,
#   None,
#   '1986-12-25',
#   1789,
#   '2022-02-24 04:31:38.986124',
#   '2022-02-24 04:31:38.986125',
#   None),
#  (987,
#   'Cindy Little',
#   'benjamingibson@example.net',
#   '249 Karina Court Apt. 798\nNew Hollyville, NB J1E 8B8',
#   'Port Jasonfurt',
#   'Prince Edward Island',
#   'Somalia',
#   None,
#   None,
#   '1979-07-02',
#   1979,
#   '2022-02-24 04:31:38.986843',
#   '2022-02-24 04:31:38.986844',
#   None),
#  (988,
#   'Linda Barr',
#   'vasquezvernon@example.net',
#   '301 Black Rue\nJonathanside, PE P5V9B9',
#   'Priceville',
#   'Yukon Territory',
#   'Chad',
#   None,
#   None,
#   '2003-06-27',
#   1145,
#   '2022-02-24 04:31:38.987585',
#   '2022-02-24 04:31:38.987586',
#   None),
#  (989,
#   'Charles Chavez',
#   'gibsonbrandi@example.org',
#   '917 Brown Light Suite 317\nSouth Robert, PE N8A 6N8',
#   'Martinshire',
#   'Alberta',
#   'Yemen',
#   None,
#   None,
#   '2016-09-14',
#   1942,
#   '2022-02-24 04:31:38.988263',
#   '2022-02-24 04:31:38.988265',
#   None),
#  (990,
#   'Maurice Ellis',
#   'mmoran@example.net',
#   '89135 Johnson Glen\nShannonland, NU X6H2N7',
#   'Angelaborough',
#   'New Brunswick',
#   'Guadeloupe',
#   None,
#   None,
#   '1987-07-11',
#   2463,
#   '2022-02-24 04:31:38.988901',
#   '2022-02-24 04:31:38.988902',
#   None),
#  (991,
#   'Russell Marshall',
#   'chaveztammie@example.com',
#   '96657 Hernandez Port Apt. 353\nAnnastad, QC M4Y6S3',
#   'South Jeremybury',
#   'Alberta',
#   'Singapore',
#   None,
#   None,
#   '1988-02-11',
#   2048,
#   '2022-02-24 04:31:38.989580',
#   '2022-02-24 04:31:38.989581',
#   None),
#  (992,
#   'Amanda Brown',
#   'hsanders@example.com',
#   '1084 Wiggins Divide Apt. 913\nSouth Paulbury, PE G5J2C9',
#   'Port Benjaminshire',
#   'Alberta',
#   'Sierra Leone',
#   None,
#   None,
#   '2011-01-25',
#   2466,
#   '2022-02-24 04:31:38.990194',
#   '2022-02-24 04:31:38.990195',
#   None),
#  (993,
#   'Tiffany Sandoval',
#   'kaneamanda@example.org',
#   '303 Lisa Spurs\nSouth Charlotteland, NL C7S 2T6',
#   'Bradfort',
#   'Ontario',
#   'Solomon Islands',
#   None,
#   None,
#   '2016-04-12',
#   1174,
#   '2022-02-24 04:31:38.990840',
#   '2022-02-24 04:31:38.990842',
#   None),
#  (994,
#   'Mr. Paul Hernandez',
#   'vegaaaron@example.com',
#   '533 Robert Loaf Apt. 764\nYoungbury, NT N3B7Y2',
#   'Hollymouth',
#   'Quebec',
#   'Macao',
#   None,
#   None,
#   '2014-12-31',
#   1013,
#   '2022-02-24 04:31:38.991527',
#   '2022-02-24 04:31:38.991528',
#   None),
#  (995,
#   'Suzanne Lee',
#   'oblevins@example.net',
#   '1388 Thomas Shoal\nKaitlinmouth, AB H6V5A6',
#   'West Henry',
#   'Northwest Territories',
#   'Uruguay',
#   None,
#   None,
#   '1995-11-29',
#   1947,
#   '2022-02-24 04:31:38.992092',
#   '2022-02-24 04:31:38.992093',
#   None),
#  (996,
#   'Alicia Fox',
#   'rsimon@example.net',
#   '16959 Anne Hollow Apt. 096\nLake Melissafurt, SK H2C 4B8',
#   'Michelleburgh',
#   'Nova Scotia',
#   'Egypt',
#   None,
#   None,
#   '1979-05-27',
#   2282,
#   '2022-02-24 04:31:38.992709',
#   '2022-02-24 04:31:38.992710',
#   None),
#  (997,
#   'Raymond Johnson',
#   'johnhernandez@example.org',
#   '1410 Nathaniel Plaza Suite 726\nBautistachester, NT H9A3R1',
#   'Lake Katherine',
#   'Saskatchewan',
#   'British Indian Ocean Territory (Chagos Archipelago)',
#   None,
#   None,
#   '2017-09-30',
#   1048,
#   '2022-02-24 04:31:38.993382',
#   '2022-02-24 04:31:38.993383',
#   None),
#  (998,
#   'Juan Elliott',
#   'whitemark@example.net',
#   '321 Christine Wall\nJeffreyview, BC R6C7L7',
#   'West Kristyburgh',
#   'Quebec',
#   'India',
#   None,
#   None,
#   '1996-09-10',
#   1325,
#   '2022-02-24 04:31:38.993997',
#   '2022-02-24 04:31:38.993998',
#   None),
#  (999,
#   'Lindsey Ochoa',
#   'hannahlowe@example.net',
#   '652 Austin Valley\nSerranomouth, NB Y2L 9E4',
#   'South Connorton',
#   'Nunavut',
#   'Zambia',
#   None,
#   None,
#   '2014-08-13',
#   1058,
#   '2022-02-24 04:31:38.994663',
#   '2022-02-24 04:31:38.994664',
#   None),
#  (1000,
#   'James Bird',
#   'grantryan@example.com',
#   '2856 Anthony Orchard Suite 882\nKellershire, YT G1S5M5',
#   'Sergioton',
#   'Northwest Territories',
#   'Madagascar',
#   None,
#   None,
#   '1994-06-09',
#   1997,
#   '2022-02-24 04:31:38.995320',
#   '2022-02-24 04:31:38.995322',
#   None),
#  (1001,
#   'Thomas Jones',
#   'charles45@example.net',
#   '1880 Robert Spur\nDuranland, NS M2V5H4',
#   'Jakebury',
#   'Newfoundland and Labrador',
#   'Kenya',
#   None,
#   None,
#   '2021-02-18',
#   1056,
#   '2022-02-24 04:31:38.995909',
#   '2022-02-24 04:31:38.995910',
#   None),
#  (1002,
#   'Cheryl Beard',
#   'tsantana@example.org',
#   '125 Allen Crossing\nHillburgh, AB Y8B3C5',
#   'Timothybury',
#   'Yukon Territory',
#   'Mauritius',
#   None,
#   None,
#   '2022-01-30',
#   1221,
#   '2022-02-24 04:31:38.996520',
#   '2022-02-24 04:31:38.996522',
#   None),
#  (1003,
#   'Sarah Alvarez',
#   'kristichambers@example.net',
#   '92241 Rivera Light Suite 298\nEmilyfort, NU P1G 1L1',
#   'Walkerside',
#   'Nunavut',
#   'Korea',
#   None,
#   None,
#   '1983-10-02',
#   2332,
#   '2022-02-24 04:31:38.997202',
#   '2022-02-24 04:31:38.997203',
#   None),
#  (1004,
#   'Jennifer Nichols',
#   'amy28@example.org',
#   '965 Kathy Trafficway\nVictorland, YT M3S4G7',
#   'East Laurentown',
#   'Nunavut',
#   'Croatia',
#   None,
#   None,
#   '2006-07-22',
#   1182,
#   '2022-02-24 04:31:38.997912',
#   '2022-02-24 04:31:38.997913',
#   None),
#  (1005,
#   'Alexander Becker',
#   'debbieallen@example.net',
#   '746 Johnson Field\nNorth Laurastad, YT T1N 2K5',
#   'Marksstad',
#   'Yukon Territory',
#   'Mali',
#   None,
#   None,
#   '2013-07-28',
#   2309,
#   '2022-02-24 04:31:38.998645',
#   '2022-02-24 04:31:38.998646',
#   None),
#  (1006,
#   'Jessica Smith',
#   'youngwillie@example.com',
#   '22124 Veronica Junctions\nNorth Nina, NT H2T1X7',
#   'Richardsborough',
#   'Nunavut',
#   'Saint Martin',
#   None,
#   None,
#   '2012-02-25',
#   1290,
#   '2022-02-24 04:31:38.999294',
#   '2022-02-24 04:31:38.999295',
#   None),
#  (1007,
#   'Megan Smith',
#   'anthony59@example.com',
#   '5150 Coffey Corners Apt. 189\nSouth Lanceton, AB J9K4A7',
#   'Marshallfurt',
#   'Quebec',
#   'Cameroon',
#   None,
#   None,
#   '1975-01-23',
#   2092,
#   '2022-02-24 04:31:39.000053',
#   '2022-02-24 04:31:39.000054',
#   None),
#  (1008,
#   'Angela Leonard',
#   'nicholeturner@example.net',
#   '963 Stacey Course\nCarterfort, SK X3P 3N7',
#   'Philliptown',
#   'Nunavut',
#   'Argentina',
#   None,
#   None,
#   '2019-07-29',
#   1343,
#   '2022-02-24 04:31:39.000817',
#   '2022-02-24 04:31:39.000818',
#   None),
#  (1009,
#   'William Anderson',
#   'smithdorothy@example.net',
#   '1282 Emily Prairie\nSarahville, BC E7N 2C6',
#   'Hubbardfurt',
#   'Yukon Territory',
#   'Haiti',
#   None,
#   None,
#   '2019-05-25',
#   1817,
#   '2022-02-24 04:31:39.001499',
#   '2022-02-24 04:31:39.001500',
#   None),
#  (1010,
#   'Steven Bradford',
#   'potterjoseph@example.org',
#   '84334 Andrea Loaf Suite 345\nSouth Nicholas, BC N6Y1A7',
#   'North Jennifer',
#   'Newfoundland and Labrador',
#   'Martinique',
#   None,
#   None,
#   '2004-01-07',
#   1095,
#   '2022-02-24 04:31:39.002149',
#   '2022-02-24 04:31:39.002150',
#   None),
#  (1011,
#   'Dr. Austin Brooks',
#   'nicholasfoster@example.com',
#   '979 Gates Forks\nLake Debraberg, PE Y7A 7Y1',
#   'Anthonyville',
#   'Nunavut',
#   'Niger',
#   None,
#   None,
#   '1973-06-02',
#   1564,
#   '2022-02-24 04:31:39.002891',
#   '2022-02-24 04:31:39.002892',
#   None),
#  (1012,
#   'Norma Singleton',
#   'rhampton@example.com',
#   '9140 Wheeler Trafficway Apt. 425\nKellyview, PE J1J 5G1',
#   'New Roger',
#   'Yukon Territory',
#   'Norfolk Island',
#   None,
#   None,
#   '2005-03-04',
#   2144,
#   '2022-02-24 04:31:39.003566',
#   '2022-02-24 04:31:39.003567',
#   None),
#  (1013,
#   'Michael Evans',
#   'nathanstewart@example.org',
#   '8950 Brown Fork Apt. 139\nLake Justintown, AB M8X 9H5',
#   'West Robin',
#   'Alberta',
#   'Saint Barthelemy',
#   '1 (858) 461-4218',
#   'Asperiores optio voluptates error. Ex totam quam voluptatibus consequatur '
#   'vitae officiis. Optio unde quae numquam animi illo.',
#   '1984-08-22',
#   1584,
#   '2022-02-24 04:47:31.514258',
#   '2022-02-24 04:47:31.514259',
#   '107.202.139.26')]

# %% [markdown]
# Finally, the last step,
# Using the code block below, combined with what you have learned above, and the Lecture notes,
# Craft a SQL Query that will return the `name` of no more than `20` `people` with a `heatmap` greater than `1500`

# %%
import sqlite3
import pprint
#Retreive the Connection object
myConnection = sqlite3.connect('social_network.db')

#Once we have a Connection object, we can generate a Cursor object, and use that to run our SQL Queries
myCursor = myConnection.cursor()

selectStatement = """SELECT ... """

#myCursor.execute( ... )
#results = myCursor.fetchall()
#pprint(results)

# %% [markdown]
# Your submission will contain, as usual, a link to your completed colab notebook, but in addition to that, you will download a copy of your social_network.db file and upload it to D2L. To download the file, right click it from the Files menu on the left of the Notebook.
